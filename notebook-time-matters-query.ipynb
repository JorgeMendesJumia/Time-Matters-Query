# %% [markdown]
# <b><center><font size="4">Time Matters Query</font></center></b>
# <hr>

# %% [markdown]
# **Notebook Developed by**: [Ricardo Campos](http://www.ccc.ipt.pt/~ricardo)<br>
# **email:**  ricardo.campos@ipt.pt<br>
# **Affiliation:** *Assistant Professor* @ [Polytechnic Institute of Tomar](http://portal2.ipt.pt/en/);
# *Researcher* @ [LIAAD](https://www.inesctec.pt/en/centres/liaad)-[INESC TEC](https://www.inesctec.pt/en)
#
# <hr>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Time-Matters-Query" data-toc-modified-id="Time-Matters-Query-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Time-Matters-Query</a></span><ul class="toc-item"><li><span><a href="#What-is-Time-Matters-Query?" data-toc-modified-id="What-is-Time-Matters-Query?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>What is Time-Matters-Query?</a></span></li><li><span><a href="#Who-developed-this-package?" data-toc-modified-id="Who-developed-this-package?-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Who developed this package?</a></span></li><li><span><a href="#Where-can-I-find-Time-Matters?" data-toc-modified-id="Where-can-I-find-Time-Matters?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Where can I find Time-Matters?</a></span></li><li><span><a href="#Installation" data-toc-modified-id="Installation-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Installation</a></span></li><li><span><a href="#Usage" data-toc-modified-id="Usage-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Usage</a></span><ul class="toc-item"><li><span><a href="#Arquivo.pt" data-toc-modified-id="Arquivo.pt-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Arquivo.pt</a></span><ul class="toc-item"><li><span><a href="#By-Query" data-toc-modified-id="By-Query-1.5.1.1"><span class="toc-item-num">1.5.1.1&nbsp;&nbsp;</span>By Query</a></span><ul class="toc-item"><li><span><a href="#fullContentLenght_Arquivo" data-toc-modified-id="fullContentLenght_Arquivo-1.5.1.1.1"><span class="toc-item-num">1.5.1.1.1&nbsp;&nbsp;</span>fullContentLenght_Arquivo</a></span></li><li><span><a href="#snippet" data-toc-modified-id="snippet-1.5.1.1.2"><span class="toc-item-num">1.5.1.1.2&nbsp;&nbsp;</span>snippet</a></span></li><li><span><a href="#title" data-toc-modified-id="title-1.5.1.1.3"><span class="toc-item-num">1.5.1.1.3&nbsp;&nbsp;</span>title</a></span></li><li><span><a href="#crawledDate" data-toc-modified-id="crawledDate-1.5.1.1.4"><span class="toc-item-num">1.5.1.1.4&nbsp;&nbsp;</span>crawledDate</a></span></li><li><span><a href="#url" data-toc-modified-id="url-1.5.1.1.5"><span class="toc-item-num">1.5.1.1.5&nbsp;&nbsp;</span>url</a></span></li><li><span><a href="#domain" data-toc-modified-id="domain-1.5.1.1.6"><span class="toc-item-num">1.5.1.1.6&nbsp;&nbsp;</span>domain</a></span></li></ul></li><li><span><a href="#By-Query---Newspaper3k-=-True" data-toc-modified-id="By-Query---Newspaper3k-=-True-1.5.1.2"><span class="toc-item-num">1.5.1.2&nbsp;&nbsp;</span>By Query - Newspaper3k = True</a></span><ul class="toc-item"><li><span><a href="#fullContentLenght_Newspaper3K" data-toc-modified-id="fullContentLenght_Newspaper3K-1.5.1.2.1"><span class="toc-item-num">1.5.1.2.1&nbsp;&nbsp;</span>fullContentLenght_Newspaper
2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Time-Matters (Multiple Docs)</a></span><ul class="toc-item"><li><span><a href="#Score" data-toc-modified-id="Score-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Score</a></span><ul class="toc-item"><li><span><a href="#ByCorpus" data-toc-modified-id="ByCorpus-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>ByCorpus</a></span></li><li><span><a href="#ByDoc" data-toc-modified-id="ByDoc-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>ByDoc</a></span></li><li><span><a href="#ByDocSentence" data-toc-modified-id="ByDocSentence-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>ByDocSentence</a></span></li></ul></li><li><span><a href="#Temporal-Expressions" data-toc-modified-id="Temporal-Expressions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Temporal Expressions</a></span></li><li><span><a href="#Relevant-Keywords" data-toc-modified-id="Relevant-Keywords-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Relevant Keywords</a></span></li><li><span><a href="#Text-Normalized" data-toc-modified-id="Text-Normalized-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Text Normalized</a></span></li><li><span><a href="#Text-Tokens" data-toc-modified-id="Text-Tokens-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Text Tokens</a></span></li><li><span><a href="#Sentences-Normalized" data-toc-modified-id="Sentences-Normalized-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Sentences Normalized</a></span></li><li><span><a href="#Sentences-Tokens" data-toc-modified-id="Sentences-Tokens-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Sentences Tokens</a></span></li><li><span><a href="#Optional-Parameters" data-toc-modified-id="Optional-Parameters-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Optional Parameters</a></span><ul class="toc-item"><li><span><a href="#Temporal-Tagger" data-toc-modified-id="Temporal-Tagger-2.8.1"><span class="toc-item-num">2.8.1&nbsp;&nbsp;</span>Temporal Tagger</a></span></li><li><span><a href="#Time-Matters" data-toc-modified-id="Time-Matters-2.8.2"><span class="toc-item-num">2.8.2&nbsp;&nbsp;</span>Time Matters</a></span></li></ul></li><li><span><a href="#Debug" data-toc-modified-id="Debug-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Debug</a></span><ul class="toc-item"><li><span><a href="#Inverted-Index" data-toc-modified-id="Inverted-Index-2.9.1"><span class="toc-item-num">2.9.1&nbsp;&nbsp;</span>Inverted Index</a></span></li><li><span><a href="#Dice-Matrix" data-toc-modified-id="Dice-Matrix-2.9.2"><span class="toc-item-num">2.9.2&nbsp;&nbsp;</span>Dice Matrix</a></span></li><li><span><a href="#Execution-Time" data-toc-modified-id="Execution-Time-2.9.3"><span class="toc-item-num">2.9.3&nbsp;&nbsp;</span>Execution Time</a></span></li></ul></li></ul></li><li><span><a href="#Related-Projects" data-toc-modified-id="Related-Projects-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Related Projects</a></span></li><li><span><a href="#References" data-toc-modified-id="References-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# ## Time-Matters-Query

# %% [markdown]
# ### What is Time-Matters-Query?

# %% [markdown]
# Time matters query is a [python package](https://github.com/LIAAD/Time-Matters-Query) that aims to score the relevance of temporal expressions found (through time matters [package](https://github.com/LIAAD/Time-Matters)) within a set of texts. To get these texts, users are given the chance to query a system. The current version of this package offers users the chance to get results from the [Arquivo.pt](http://arquivo.pt), portuguese web archive, yet other systems may be easily added.

# %% [markdown]
# ### Who developed this package?

# %% [markdown]
# Time matters query is the result of a research conducted by Ricardo Campos during his [PhD](http://www.ccc.ipt.pt/~ricardo/ficheiros/PhDThesis_RCampos.pdf) at the [University of Porto](https://www.up.pt/). It builds on top of Time matters algorithm, which was originally implemented in C#. Current version, however, is now available as a Python package, developed by [Jorge Mendes](https://github.com/JMendes1995) under the supervision of [Professor Ricardo Campos](http://www.ccc.ipt.pt/~ricardo/) in the scope of the Final Project of the Computer Science degree of the [Polytechnic Institute of Tomar](http://portal2.ipt.pt/), Portugal.

# %% [markdown]
# ### Where can I find Time-Matters?

# %% [markdown]
# `Time-Matters-Query` can be found as a standalone installation on [github](https://github.com/LIAAD/Time-Matters-Query) and as an API [http://time-matters-query.inesctec.pt/api].

# %% [markdown]
# ### Installation

# %% [markdown]
# If you want to use Time-Matters-Query please refer to the installation instructions [here](https://github.com/LIAAD/Time-Matters-Query#How-to-Install-Time-Matters) defined.

# %% [markdown]
# ### Usage

# %% [markdown]
# In the following, we show how to consume results obtained from the [Arquivo.pt](http://arquivo.pt) portuguese web archive.

# %% [markdown]
# #### Arquivo.pt

# %% [markdown]
# User's are offered the chance to either issue a query (ByQuery section) or to provide an URL (ByURL section) where to look for information. To make this happen, we make use of the textsearch and of the versionHistory feature provided by Arquivo.pt (a description of both APIs is available [here](https://github.com/arquivo/pwa-technologies/wiki/Arquivo.pt-API-v.0.2)).

# %% [markdown]
# ##### By Query

# %% [markdown]
# The following code enables one to make use of the Arquivo.pt textSearch feature (e.g. https://arquivo.pt/textsearch?q=guerra%20na%20s%C3%ADria) assuming its default parameters. Executing this code allows full-text search and accessing preserved web content together with related metadata.

# %%
from Time_Matters_Query import Query

q = 'guerra na síria'
query = Query()
results = query.arquivo_pt(q)

# %% [markdown]
# `results` is a list with 2 positions. The first, is a dictionary with general information regarding the execution time, number of docs retrieved, number of unique domains and list of domains. The second, is a list with as much items as the number of texts retrieved by the Arquivo.pt (which in the case of the default parameters, is 50 max_items).

# %% [markdown]
# In addition to this, user's may opt to specify some parameters, in particular:
# - `max_items`: maximum number of items to retrieve (default number is 50, maximum number is 2000);
# - `offset`: the position of the text indices where the search begins (default is 0);
# - `newspaper3k`: flag variable that determines whether to rely on the arquivo.pt API results (default is newspaper3k=False) or on the [newspaper3k](https://newspaper.readthedocs.io/en/latest/) library to extract the contents of a web page (in whihc case newspaper3k is set to true). The first is quicker. The latter extracts a cleaner text;
# - `domains`: limits the search within a given site (e.g., ['http://publico.pt/']) or sites (e.g., ['http://publico.pt/', 'http://www.jn.pt/']). Doing the latter, means that the specified number of `max_items` will be retrieved for each domain (default is searching within the entire index);
# - `beginDate`: Set an initial date for the time span of the search. Format: YYYYMMDDHHMMSS, also accepts a shorter date fotmat, e.g. (YYYY). Default: 1996;
# - `endDate`: Set a end date for the time span of the search. Format: YYYYMMDDHHMMSS, also accepts a shorter date format, for example (YYYY). Default: Current Year-1

# %% [markdown]
# In the following, we aim to obtain 30 results in total (15 for the `publico.pt` domain and another 15 for the `jn.pt`) for the query `guerra na síria` ranging from `2000` until `2009`. Setting `newspaper3k` to `False` means that we will rely on the results retrieved by the arquivo.pt API. Also note that the fact that we require 15 items per domain, doesn't necessarily mean that we will get them, as that number of items may not be available in the Arquivo.pt web archive indexes under the conditions set.

# %%
from Time_Matters_Query import Query

max_items=15
offset=0
query = Query(max_items, offset, newspaper3k=False)
domains = ['http://publico.pt/', 'http://www.jn.pt/']
beginDate = '2009'
endDate = '2020'
q = 'guerra na síria'
results = query.arquivo_pt(q,domains, beginDate, endDate)

# %% [markdown]
# The output as previously referred is a list consisting of two positions. The first, is a dictionary with general information regarding the execution time, number of docs retrieved, number of unique domains and list of domains.

# %%
results[0]
# Out:
# {'time': 5.640901327133179,
#  'n_docs': 26,
#  'n_domains': 2,
#  'domains': ['publico.pt', 'www.jn.pt']}

# %% [markdown]
# The second, is a list with as much items as the number of texts set by the user and found by the Arquivo.pt in their indexes. In this code example, we ask for 15 items (per domain), yet Arquivo.pt only found x for the `publico.pt` domain and another y for the `jn.pt`. The total number of retrieved results is thus x + y.

# %%
len(results[1])
# Out:
# 30

# %% [markdown]
# Each item returned contains a dictionary with the following information:
# - `fullContentLenght_Arquivo`: full text as returned by the Arquivo.pt API;
# - `snippet`: a short snippet of the text retrieved  by the Arquivo.pt API;
# - `crawledDate`: crawling date time of the Arquivo.pt API;
# - `title`: title of the web page  by the Arquivo.pt API;
# - `url`: url of the archived web page  by the Arquivo.pt API;
# - `domain`: absolut domain of the web page  by the Arquivo.pt API. For instance `https://arquivo.pt/wayback/20000613173529/http://www.jn.pt/textos/out1061.htm` correponds to `http://www.jn.pt/`.

# %%
results[1][0]
# Out:
# {'fullContentLenght_Arquivo': 'A guerra na Síria - PÚBLICO Saltar para a navegação principal Saltar para o conteúdo × Este site utiliza cookies. Ao navegar no site, está a consentir a sua utilização. Saiba mais sobre o uso de cookies. Público Serviços Saltar para o conteúdo Edição Impressa Loja Imobiliário Serviços Meteorologia Emprego Jogos TV Classificados Iniciativas Classificados Lisboa 21 ° C Alterar localização Localidade Definir Iniciar sessão Entrar com o Facebook Entrar com o Twitter Ou Palavra-chave Lembrar-se de mim Esqueceu-se da sua palavra-chave? Registar Pesquisa: Pesquisar Secções Saltar para o conteúdo Portugal Portugal Economia Economia Mundo Mundo Cultura-Ípsilon Cultura-Ípsilon Desporto Desporto Ciência Ciência Tecnologia Tecnologia Opinião Opinião Multimédia Multimédia Mais Mais A guerra na Síria Todos os tópic
#  'Armas do leste europeu acabam na guerra síria via Arábia Saudita Armas do leste europeu acabam na guerra síria via Arábia Saudita Países do centro e leste europeu exportaram desde 2012 armas e ...  refere-se à existência de provas de que parte desse armamento termina na Síria e nas mãos de milícias ... ',
#  'Guerra na Síria arrasa locais classificados como património cultural Jornal de Notícias Abrir menu ...  Mundo Insólito Últimas Mais Vistas Facebook Twitter WhatsApp Partilhar Síria Guerra na Síria arrasa ... 2014às10:11 Facebook Twitter Partilhar Comentar Tópicos Mundo UNESCO Monumentos ONU Guerra na Síria ... ',
#  'Guerra na Síria matou em média uma criança por hora este ano Jornal de Notícias Abrir menu Secções ...  – Manchester City 2 1 Manchester United Unicef Guerra na Síria matou em média uma criança por hora este ... às17:21 Facebook Twitter Comentar Tópicos Internacional Guerra Síria Mundo Guerra na Síria matou em ... ',
#  'Guerra na Síria matou em média uma criança por hora este ano Jornal de Notícias Abrir menu Secções ...  Insólito Últimas Mais Vistas Facebook Twitter WhatsApp Unicef Guerra na Síria matou em média uma criança ...  Hojeàs17:21 Facebook Twitter Comentar Tópicos Internacional Guerra Síria Mundo Guerra na Síria ... ',
#  ' Guerra Hospitais na Síria fechados devido à intensificação dos ataques Rússia adverte EUA de que ...  "apagar" guerra na Síria Hospitais na Síria fechados devido à intensificação dos ataques Síria ...  violência no YouTube pode "apagar" guerra na Síria Ensino Governo patrocina 12 bolsas ... ',
#  ' Guerra Ataque aéreo matou 20 civis que fugiam de combates na Síria Confirmado uso de gás sarin ...  Químicas. Ataque aéreo matou 20 civis que fugiam de combates na Síria Guerra Hospitais na Síria fechados ...  Internet Controlo da violência no YouTube pode "apagar" guerra na Síria Ataque aéreo matou 20 civis ... ',
#  ' Raqa Guerra Ataque aéreo matou 20 civis que fugiam de combates na Síria Confirmado uso de gás sarin ...  Ataque aéreo matou 20 civis que fugiam de combates na Síria Guerra Hospitais na Síria fechados devido à ... " guerra na Síria Ataque aéreo matou 20 civis que fugiam de combates na Síria Síria Aliança árabe-curda ... ']

# %% [markdown]
# ###### title

# %%
title = results[1][0]['title']
title
# Out:
# 'A guerra na Síria - PÚBLICO'

# %% [markdown]
# Ter acesso à totalidade dos titles é possível a partir do seguinte código:

# %%
ListOfTexts = [result['title'] for result in results[1]]
ListOfTexts
# Out:
# ['A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'A guerra na Síria - PÚBLICO',
#  'EUA acusam a Rússia de interferir na guerra síria - JN',
#  'Armas do leste europeu acabam na guerra síria via Arábia Saudita',
#  'Armas do leste europeu acabam na guerra síria via Arábia Saudita',
#  'Armas do leste europeu acabam na guerra síria via Arábia Saudita',
#  'Armas do leste europeu acabam na guerra síria via Arábia Saudita',
#  'Guerra na Síria arrasa locais classificados como património cultural',
#  'Guerra na Síria matou em média uma criança por hora este ano',
#  'Guerra na Síria matou em média uma criança por hora este ano',
#  'Síria - JN',
#  'Síria - JN',
#  'Síria - JN']

# %% [markdown]
# ###### crawledDate

# %%
crawledDate = results[1][0]['crawledDate']
crawledDate
# Out:
# '20130119165527'

# %% [markdown]
# ###### url

# %%
url = results[1][0]['url']
url
# Out:
# 'https://arquivo.pt/wayback/20130119165527/http://publico.pt/cristiano-ronaldo'

# %% [markdown]
# ###### domain

# %%
domain = results[1][0]['domain']
domain
# Out:
# 'publico.pt'

# %% [markdown]
# ##### By Query - Newspaper3k = True

# %% [markdown]
# Instead, we can set `newspaper3k = True`:

# %%
from Time_Matters_Query import Query

max_items=15
offset=0
query = Query(max_items, offset, newspaper3k=True)
domains = ['http://publico.pt/', 'http://www.jn.pt/']
beginDate = '2000'
endDate = '2009'
q = 'guerra na síria'
results = query.arquivo_pt(q,domains, beginDate, endDate)

# %% [markdown]
# The output as previously referred is a list consisting of two positions. The first, is a dictionary with general information regarding the execution time, number of docs retrieved, number of unique domains and list of domains.

# %%
results[0]
# Out:
# {'time': 36.891191720962524,
#  'n_docs': 4,
#  'n_domains': 2,
#  'domains': ['publico.pt', 'www.jn.pt']}

# %% [markdown]
# Based on that, we will have access to the following fields:
# - `fullContentLenght_Newspaper3K`: full text as returned by the newspaper 3k library;
# - `Summary_Newspaper3k`: a summary (kind of snippet) returned by the newspaper 3k library;
# - `snippet`: a short snippet of the text retrieved by the Arquivo.pt API;
# - `crawledDate`: crawling date time of Arquivo.pt;
# - `title`: title of the web page retrieved by the Arquivo.pt API;
# - `url`: url of the archived web page retrieved by the Arquivo.pt API;
# - `domain`: absolut domain of the web page retrieved by the Arquivo.pt API. For instance `https://arquivo.pt/wayback/20000613173529/http://www.jn.pt/textos/out1061.htm` correponds to `http://www.jn.pt/`.

# %%
results[1][0]
# Out:
# {'fullContentLenght_Newspaper3K': 'Sorry, your browser does not support the iframe tag.',
#  'Summary_Newspaper3k': 'Sorry, your browser does not support the iframe tag.',
#  'snippet': ' ao Iraque Síria denuncia "agressão bárbara" e apela ao fim da guerra Tentando travar vaga de ...   PROJECTOS PÚBLICO Simweb Painel Público/IDC Troféu Público Público na Escola Público/Gradiva 3ª Edição ...  pessoas A manifestação em Lisboa contra a guerra no Iraque, que se iniciou às 15h45 no Marquês de Pombal ... ',
#  'crawledDate': '20030322185522',
#  'title': 'PUBLICO.PT',
#  'url': 'https://arquivo.pt/wayback/20030322185522/http://publico.pt/',
#  'domain': 'publico.pt'}

# %% [markdown]
# ###### fullContentLenght_Newspaper3K

# %%
fullText = results[1][0]['fullContentLenght_Newspaper3K']
fullText
# Out:
# 'Sorry, your browser does not support the iframe tag.'

# %% [markdown]
# Ter acesso à totalidade dos textos é possível com recurso ao seguinte código:

# %%
ListOfTexts = [result['fullContentLenght_Newspaper3K'] for result in results[1]]
# %% [markdown]
# ###### snippet

# %%
snippet = results[1][0]['snippet']
snippet
# Out:
# ' ao Iraque Síria denuncia "agressão bárbara" e apela ao fim da guerra Tentando travar vaga de ...   PROJECTOS PÚBLICO Simweb Painel Público/IDC Troféu Público Público na Escola Público/Gradiva 3ª Edição ...  pessoas A manifestação em Lisboa contra a guerra no Iraque, que se iniciou às 15h45 no Marquês de Pombal ... '

# %% [markdown]
# Ter acesso à totalidade dos snippets é possível com recurso ao seguinte código:

# %%
ListOfTexts = [result['snippet'] for result in results[1]]
ListOfTexts
# Out:
# [' ao Iraque Síria denuncia "agressão bárbara" e apela ao fim da guerra Tentando travar vaga de ...   PROJECTOS PÚBLICO Simweb Painel Público/IDC Troféu Público Público na Escola Público/Gradiva 3ª Edição ...  pessoas A manifestação em Lisboa contra a guerra no Iraque, que se iniciou às 15h45 no Marquês de Pombal ... ',
#  ' partido Baas, foram rompidas em 1980, na sequência da guerra entre Bagdade e Teerão (1980/88), Copyright ... JN Editorial - out1061 Assad faleceu deixando a Síria entregue ao filho O presidente da Síria ...  problemático cenário de guerra e paz que caracteriza o Médio Oriente. O funeral de Estado realiza-se somente ... ',
#  ', luta contra o sionismo com o apoio do Irão e da Síria. O grupo radical xiita foi fundado no Líbano em 1982, durante a guerra civil neste país, com o objectivo de criar uma república islâmica, apesar ...  seu centro de operações no Líbano e comandos permanentes na Europa, África, América do Sul e ... ',
#  ' masculinidade estendeu-se por todo o Planeta. Vigorou no Egipto, na Pérsia, na Síria, na Índia, em África ...  concertada. Advogados aderem ao desafio de poder mudar alguma coisa Luís Filipe Guerra é advogado há nove anos. Ofereceu-se para ser mediador, para "introduzir variedade na actividade profissional", mas ... ']

# %% [markdown]
# ###### title

# %%
title = results[1][0]['title']
title
# Out:
# 'PUBLICO.PT'

# %% [markdown]
# Ter acesso à totalidade dos titles é possível com recurso ao seguinte código:

# %%
ListOfTexts = [result['title'] for result in results[1]]
ListOfTexts
# Out:
# ['PUBLICO.PT',
#  'JN Editorial - out1061',
#  'JN Editorial - out2062',
#  'Jornal de Noticias']

# %% [markdown]
# ###### url

# %%
url = results[1][0]['url']
url
# Out:
# 'https://arquivo.pt/wayback/20030322185522/http://publico.pt/'

# %% [markdown]
# ###### domain

# %%
domain = results[1][0]['domain']
domain
# Out:
# 'publico.pt'

# %% [markdown]
# ##### By URL

# %% [markdown]
# The following code enables one to make use of the Arquivo.pt versionHistory feature (e.g. https://arquivo.pt/textsearch?versionHistory=http://www.abola.pt) assuming its default parameters. Executing this code allows to search by URL, accessing all versions of the preserved web content.

# %%
from Time_Matters_Query.url import URL

url = 'http://www.abola.pt'
results = query.arquivo_pt(url)

# %% [markdown]
# `results` is a list with 2 positions. The first, is a dictionary with general information regarding the execution time, number of docs retrieved, number of unique domains and list of domains. The second, is a list with as much items as the number of texts retrieved by the Arquivo.pt (which in the case of the default parameters, is 50 max_items).

# %% [markdown]
# In addition to this, user's may opt to specify some parameters, in particular:
# - `max_items`: maximum number of items to retrieve (default number is 50, maximum number is 2000);
# - `offset`: the position of the text indices where the search begins (default is 0);
# - `newspaper3k`: flag variable that determines whether to rely on the arquivo.pt API results (default is newspaper3k=False) or on the [newspaper3k](https://newspaper.readthedocs.io/en/latest/) library to extract the contents of a web page (in which case newspaper3k is set to true). The first is quicker. The latter extracts a cleaner text;
# - `beginDate`: Set an initial date for the time span of the search. Format: YYYYMMDDHHMMSS, also accepts a shorter date fotmat, e.g. (YYYY). Default: 1996;
# - `endDate`: Set a end date for the time span of the search. Format: YYYYMMDDHHMMSS, also accepts a shorter date format, for example (YYYY). Default: Current Year-1

# %% [markdown]
# In the following, we aim to obtain 15 results, that is 15 versions of the url  `http://www.abola.pt` ranging from `2000` until `2009`. Setting `newspaper3k` to `False` means that we will rely on the results retrieved by the arquivo.pt API. Also note that the fact that we require 15 items, doesn't necessarily mean that we will get them, as that number of items may not be available in the Arquivo.pt web archive indexes under the conditions set.

# %%
from Time_Matters_Query.url import URL

max_items=15
offset=0
query = URL(max_items, offset, newspaper3k=False)
url = 'http://www.abola.pt'
beginDate = '2000'
endDate = '2009'
results = query.arquivo_pt(url, beginDate, endDate)

# %% [markdown]
# The output as previously referred is a list consisting of two positions. The first, is a dictionary with general information regarding the execution time, number of docs retrieved, number of unique domains and list of domains.

# %%
results[0]
# Out:
# {'time': 1.5312819480895996,
#  'n_docs': 10,
#  'n_domains': 1,
#  'domains': ['www.abola.pt']}

# %% [markdown]
# The second, is a list with as much items as the number of texts set by the user and found by the Arquivo.pt in their indexes. In this code example, we ask for 15 items (per domain).

# %%
len(results[1])
# Out:
# 10

# %% [markdown]
# Each item returned contains a dictionary with the following information:
# - `fullContentLenght_Arquivo`: full text as returned by the Arquivo.pt API;
# - `crawledDate`: crawling date time of the Arquivo.pt API;
# - `title`: title of the web page  by the Arquivo.pt API;
# - `url`: url of the archived web page  by the Arquivo.pt API;
# - `domain`: absolut domain of the web page  by the Arquivo.pt API. For instance `"https://arquivo.pt/textextracted?m=https%3A%2F%2Fwww.abola.pt%2F%2F20181231180031"` correponds to `http://www.abola.pt/`.

# %%
results[1][0]
# Out:
# {'fullContentLenght_Arquivo': 'abola.pt QUINTA-FEIRA, 17-12-2009, ANO 10, N.º 3610 Notícias Nacional Internacional Mais Desporto Motores Selecção Jogo d\'A BOLA BWIN PESQUISA LOGIN REGISTO abola.pt - Últimas Desporto Actualizações a cada 5 minutos. abola.pt - Últimas Outros Mundos MEDIA Já tomou a sua dose diária de "Barba e Cabelo"? É o mais recente sucesso de A BOLA online: Barba e Cabelo, cartoon do humor... 12:30 - 17-12-2009 BENFICA Di Maria e o golo de letra: «Só uso o pé direito para andar...» O jogador do Benfica fala da «rabona», expressão em castelhano para o golo ... 22:49 - 17-12-2009 BENFICA Jorge Jesus: «Ganhámos muitos jogadores para o futuro» Jesus reconheceu algum cansaço nos jogadores menos experientes, mas ficou c... 22:37 - 17-12-2009 LIGA EUROPA Res
DO QUE SE FALA ... Belenenses  Benfica  Boavista  Camacho  Chalana  Cristiano Ronaldo  FC Porto  Fernando Couto  Getafe  Inter  Liga dos Campeões  Liverpool  Manchester United  Parma  Sporting  Taça UEFA  Ténis  «Tag Cloud» dos temas mais mencionados nas últimas 24h  VÍDEOS ÚLTIMAS DOS TRÊS GRANDES \x96 Olenguer cauteloso 11-03-200814:45:03 \x96 «Eliminatória não está ganha» (Laudrup) 11-03-200812:49:02 \x96 Miguel Veloso falha Bolton 11-03-200811:18:41 \x96 Renovação de Polga em andamento 11-03-20089:02:40 \x96 Bosingwa ainda em tratamento 11-03-200812:16:54 \x96 Pinto da Costa considera «lógica» a continuidade Jesualdo 10-03-200823:26:48 CLASSIFICAÇÃO \x96 LIGA Clube Pts J 1. FC Porto 54 22 2. Benfica 40 22 3. V. Guimarães 38 22 4. V. Setúbal 37 22 5. Sporting 34 22 6. Belenenses 32 22 7. Sp. Braga 30 22 8. Marítimo 30 22 9. Nacional 29 22 10. Boavista 28 22 11. E. Amadora 25 22 12. Naval 23 22 13. Académica 22 22 14. Leixões 21 22 15. P. Ferreira 16 22 16. U. Leiria 9 22 Completa  CLASSIFICAÇÃO DOS 3 GRANDES LIGA \x ...

# %% [markdown]
# ###### title

# %%
title = results[1][0]['title']
title
# Out:
# 'abola.pt'

# %% [markdown]
# Ter acesso à totalidade dos titles é possível com recurso ao seguinte código:

# %%
ListOfTexts = [result['title'] for result in results[1]]
ListOfTexts
# Out:
# ['abola.pt',
#  'abola.pt',
#  'abola.pt',
#  'abola.pt',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»']

# %% [markdown]
# ###### crawledDate

# %%
crawledDate = results[1][0]['crawledDate']
crawledDate
# Out:
# '20091217225759'

# %% [markdown]
# ###### url

# %%
url = results[1][0]['url']
url
# Out:
# 'https://arquivo.pt/wayback/20091217225759/http://www.abola.pt/'

# %% [markdown]
# ###### domain

# %%
domain = results[1][0]['domain']
domain
# Out:
# 'www.abola.pt'

# %% [markdown]
# ##### By URL - Newspaper3k = True

# %% [markdown]
# Instead, we can set `newspaper3k = True`:

# %%
from Time_Matters_Query.url import URL

max_items=15
offset=0
query = URL(max_items, offset, newspaper3k=True)
url = 'http://www.abola.pt'
beginDate = '2000'
endDate = '2009'
results = query.arquivo_pt(url, beginDate, endDate)

# %% [markdown]
# Based on that, we will have access to the following fields:

# %% [markdown]
# - `fullContentLenght_Newspaper3K`: full text as returned by the newspaper 3k library;
# - `Summary_Newspaper3k`: a summary (kind of snippet) returned by the newspaper 3k library;
# - `crawledDate`: crawling date time of Arquivo.pt;
# - `title`: title of the web page retrieved by the Arquivo.pt API;
# - `url`: url of the archived web page retrieved by the Arquivo.pt API;
# - `domain`: absolut domain of the web page retrieved by the Arquivo.pt API. For instance `"https://arquivo.pt/textextracted?m=https%3A%2F%2Fwww.abola.pt%2F%2F20181231180031"` correponds to `http://www.abola.pt/`.

# %%
results[1][0]
# Out:
# {'fullContentLenght_Newspaper3K': 'FRANÇA\n\n22:11 - 20-12-2009\n\nO Lyon, com os ex-«portistas» Cissokho e Lisandro a titulares, não conseguiu mais do que empate no principado do Mónaco,...',
#  'Summary_Newspaper3k': 'FRANÇA22:11 - 20-12-2009O Lyon, com os ex-«portistas» Cissokho e Lisandro a titulares, não conseguiu mais do que empate no principado do Mónaco,...',
#  'crawledDate': '20091221061954',
#  'title': 'http://www.abola.pt//',
#  'url': 'https://arquivo.pt/wayback/20091221061954/http://www.abola.pt//',
#  'domain': 'www.abola.pt'}

# %% [markdown]
# ###### fullContentLenght_Newspaper3K

# %%
fullText = results[1][0]['fullContentLenght_Newspaper3K']
fullText
# Out:
# 'FRANÇA\n\n22:11 - 20-12-2009\n\nO Lyon, com os ex-«portistas» Cissokho e Lisandro a titulares, não conseguiu mais do que empate no principado do Mónaco,...'

# %% [markdown]
# Ter acesso à totalidade dos textos é possível com recurso ao seguinte código:

# %%
ListOfTexts = [result['fullContentLenght_Newspaper3K'] for result in results[1]]
ListOfTexts
# Out:
# ['FRANÇA\n\n22:11 - 20-12-2009\n\nO Lyon, com os ex-«portistas» Cissokho e Lisandro a titulares, não conseguiu mais do que empate no principado do Mónaco,...',
#  'LIGA EUROPA\n\n20:33 - 17-12-2009\n\nO Hapoel Telavive recebeu e venceu o Hamburgo por 1-0, apurando-se para os 16 avos-de-final da Liga Europa como primeiro classificado do Grupo C, por troca com a equipa alemã....',
#  'SP. BRAGA\n\n15:31 - 17-12-2009\n\nNão obstante os empates somados nas duas últimas jornadas, Domingos Paciência rejeita que se fale em quebra nas exibições do Sp. Braga. O técnico dos “arsenalistas” torce pelo empate no “clássico” entre Benfica e FC Porto e assume o desejo de reforçar a equipa com um goleador, em Janeiro....',
#  'ITÁLIA\n\n21:50 - 24-09-2009\n\nUm golo do avançado francês David Trezeguet, apontado aos 87 minutos, permitiu à Juventus empatar (2-2) no terreno do Génova, no jogo que encerrou a quinta jornada da Serie A. Equipa de Turim soma agora os mesmos 13 pontos do Inter de Milão no comando da tabela, com vantagem para a equipa de Mourinh...',
#  'ESPANHA\n\n17:11 - 24-09-2009\n\nO médio Xabi Alonso foi esta quinta-feira reintegrado, sem quaisquer limitações, no treino do plantel do Real Madrid, mostrando estar recuperado da contusão contraída na perna direita na partida diante do FC Zurique, para a Liga dos Campeões....',
#  'O presidente do FC Porto congratula-se com os festejos do ‘tetra’ que se têm verificado um pouco por todo o país, festejos esses que quer ver prolongados até ao próximo domingo, com a conquista da Taça de Portugal.\n\nV. Guimarães 25-05-2009 12:48 Cajuda com seis baixas na recepção ao Cruzeiro O plantel do V. Guimarães realizou o último treino da época, para preparar o jogo com os brasileiros do Cruzeiro. O desafio está marcado para as 18 horas e a entrada é livre.',
#  'E. Amadora 20-05-2009 15:44 E. Amadora perde três pontos na secretaria O E. Amadora foi punido com a subtracção de três pontos. O clube passa a ter 31 pontos na tabela classificativa, mantendo-se por isso sem problemas no que diz respeito à manutenção entre os «grandes» do futebol português.',
#  'Futebol InternacionalOlympiakos demite treinador O Olympiakos, segundo classificado da Liga grega, anunciou no seu site oficial a rescisão por mútuo acordo do contrato com o treinador Panagiotis Lemonis.\n11-03-2008 15:58Futebol InternacionalTiago ganha nova oportunidade na Juventus Depois de muito criticado devido às dificuldades de adaptação ao futebol italiano, Tiago prepara-se para voltar a ser aposta do técnico da Juventus, Claudio Ranieri, no próximo encontro do campeonato, sábado diante do Nápoles.\n11-03-2008 15:49FutebolMilosevic assina pelo Rubin O avançado sérvio Savo Milosevic, sem clube desde a saída do Osasuna no final da época passada, assinou por um ano com o Rubin Kazan, anunciou o clube russo sem precisar detalhes financeiros do contrato.\n11-03-2008 15:34Futebol InternacionalHector Cuper assume comando do Parma No dia seguinte à demissão de Domenico di Carlos, o Parma, onde milita o português Fernando Couto, assumiu que o argentino Hector Cuper vai assumir o comando técnico da equipa.',
#  'Porto«Neste momento temos um plantel homogéneo» (Jesualdo Ferreira) Jesualdo Ferreira rodou o plantel e gostou da atitude dos seus jogadores, apesar do empate no Bessa.\n«Agora temos mais soluções do que tínhamos há quatro/cinco meses.»01-03-2008 23:56Futebol«Um ponto importante» (Jaime Pacheco) Jaime Pacheco gostou do «derby» e ficou satisfeito com o ponto conquistado diante do campeão nacional.\nA expulsão de Diakité foi, para o técnico do Boavista, um momento de viragem do jogo.\nPorto«Agora há que pensar no Schalke» (Quaresma) Quaresma está de volta à competição e preparado para «ajudar» a equipa azul e branca, já na quarta-feira, diante dos alemães do Schalke 04.\n01-03-2008 23:32Futebol InternacionalRenteria dá vitória ao Estrasburgo O avançado colombiano Renteria, emprestado pelo FC Porto ao Estrasburgo, voltou esta noite a estar em destaque, apontando o golo solitário na vitória da sua equipa no terreno do Le Mans, em partida da 27.ª jornada do campeonato francês.']

# %% [markdown]
# ###### title

# %%
title = results[1][0]['title']
title
# Out:
# 'http://www.abola.pt//'

# %% [markdown]
# Ter acesso à totalidade dos titles é possível com recurso ao seguinte código:

# %%
ListOfTexts = [result['title'] for result in results[1]]
ListOfTexts
# Out:
# ['http://www.abola.pt//',
#  'abola.pt',
#  'abola.pt',
#  'abola.pt',
#  'abola.pt',
#  'abola.pt - «A BOLA on-line»',
#  'http://www.abola.pt/',
#  'abola.pt - «A BOLA on-line»',
#  'http://www.abola.pt/',
#  'http://www.abola.pt/',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»',
#  'abola.pt - «A BOLA on-line»',
#  'http://www.abola.pt/?sid=af80c0266468ac2de9ea71b1498f2919']

# %% [markdown]
# ###### crawledDate

# %%
crawledDate = results[1][0]['crawledDate']
crawledDate
# Out:
# '20091221061954'

# %% [markdown]
# ###### url

# %%
url = results[1][0]['url']
url
# Out:
# 'https://arquivo.pt/wayback/20091221061954/http://www.abola.pt//'

# %% [markdown]
# ###### domain

# %%
domain = results[1][0]['domain']
domain
# Out:
# 'www.abola.pt'

# %% [markdown]
# ## Time-Matters (Multiple Docs)

# %% [markdown]
# If you want to use Time-Matters please refer to the installation instructions [here](https://github.com/LIAAD/Time-Matters#How-to-Install-Time-Matters) defined. A more detailed explanation of Time-Matters is also available [here](http://www.ccc.ipt.pt/~ricardo/APIs_Packages/TemporalTaggers/3time-matters.html)

# %% [markdown]
# Once we have the texts collected, we can now send them for Time-Matters (Multiple Docs) to execute.

# %% [markdown]
# In the following, we will make use of some texts related to "guerra na síria" collected fo

# %%
from Time_Matters_Query import Query

max_items=15
offset=0
query = Query(max_items, offset, newspaper3k=False)
domains = ['http://publico.pt/', 'http://www.jn.pt/']
beginDate = '2009'
endDate = '2020'
q = 'guerra na síria'
results = query.arquivo_pt(q,domains, beginDate, endDate)

ListOfTexts = [result['fullContentLenght_Arquivo'] for result in results[1]]
ListOfTexts
# Out:
# ['A guerra na Síria - PÚBLICO Saltar para a navegação principal Saltar para o conteúdo × Este site utiliza cookies. Ao navegar no site, está a consentir a sua utilização. Saiba mais sobre o uso de cookies. Público Serviços Saltar para o conteúdo Edição Impressa Loja Imobiliário Serviços Meteorologia Emprego Jogos TV Classificados Iniciativas Classificados Lisboa 21 ° C Alterar localização Localidade Definir Iniciar sessão Entrar com o Facebook Entrar com o Twitter Ou Palavra-chave Lembrar-se de mim Esqueceu-se da sua palavra-chave? Registar Pesquisa: Pesquisar Secções Saltar para o conteúdo Portugal Portugal Economia Economia Mundo Mundo Cultura-Ípsilon Cultura-Ípsilon Desporto Desporto Ciência Ciência Tecnologia Tecnologia Opinião Opinião Multimédia Multimédia Mais Mais A guerra na Síria Todos os tópicos Dois aviões russos aterram na Síria, com os EUA a acusar Moscovo de ajudar Assad Por AFP 18:19 Anúncio feito por agência oficial, quando se multiplicam suspeitas sobre o papel russo na guerra síria. Dois aviões russos aterram na Síria, com os EUA a acusar Moscovo de ajudar Assad Por AFP 18:19 Anúncio feito por agência oficial, quando se multiplicam suspeitas sobre o papel russo na guerra síria. Polícia turca detém suspeitos do naufrágio de Alan Kurdi Por PÚBLICO 10/09/2015 Dois homens ficaram detidos e um terceiro libertado após o pagamento de caução. EUA vão receber dez mil refugiados sírios Por PÚBLICO 10/09/2015 América e Austrália fazem ofertas para receber alguns dos sírios que estão a chegar à Europa, em fuga da guerra. A Europa e a sua insuficiente união Por Direcção Editorial 10/09/2015 O forte apelo de Juncker pode ser insuficiente para a Europa se unir no acolhimento aos refugiados. Rússia critica "histeria" face a suspeitas sobre reforço militar na Síria Por Ana Fonseca Pereira 09/09/2015 Moscovo confirmou presença de especialistas para apoiar forças de Assad a usar armas. Fontes libanesas dizem que há tropas russas a combater. Da Grécia à Hungria, os obstáculos multiplicam-se para milhares de refugiados Por Clara Barata 08/09/2015 É preciso mudar a política europeia de asilo, afirma a Alemanha, que acha possível continuar a receber meio milhões de refugiados nos próximos anos. ACNUR alerta sobre novas leis húngaras. França envia aviões contra EI, mas a guerra na Síria não tem fim à vista Por Ana Fonseca Pereira 07/09/2015 Crise dos refugiados pressiona líderes europeus a agir contra radicais. ONU diz que beligerantes têm meios para manter guerra durante "vários mais anos". Ajudem-nos! Por João Ferreira da Cruz 07/09/2015 Refugiados: a tragédia maior está a acontecer no Médio Oriente Por Liz Sly (Al-Minya, Líbano ) 06/09/2015 Os refugiados sírios que estão a chegar à Europa são apenas uma pequena percentagem d
ataque a Khan Sheikhun Síria Confirmado uso de gás sarin antes do ataque a Khan Sheikhun Ataque aéreo matou 20 civis que fugiam de combates na Síria Guerra Hospitais na Síria fechados devido à intensificação dos ataques Ataque aéreo matou 20 civis que fugiam de combates na Síria Síria Rússia confirma morte de general em ataque do Estado Islâmico Síria Vitória militar está ao alcance do regime de Damasco O ministro dos Negócios Estrangeiros da Síria, Walid al Mualem, disse nas Nações Unidas que "a vitória está ao alcance" do regime de Bashar al-Assad. Rússia adverte EUA de que tem tropas especiais na cidade síria de Deir Ezzor Internet Controlo da violência no YouTube pode "apagar" guerra na Síria Ataque aéreo matou 20 civis que fugiam de combates na Síria Síria Aliança árabe-curda recupera cidade velha de Raqa aos jiadistas A aliança árabe-curda apoiada por Washington recuperou esta sexta-feira ao grupo Estado Islâmico a cidade velha de Raqa, aproximando-se da área mais fortificada pelos jiadistas. Síria Assad desloca-se a uma festa muçulmana fora de Damasco Síria ONG acusa jiadistas de deterem jovens para os obrigar a lutar O grupo Estado Islâmico deteve dezenas de jovens nas últimas 48 horas na província de Deir al-Zur, no nordeste da Síria, para os obrigar a lutar nas suas fileiras. Controlo da violência no YouTube pode "apagar" guerra na Síria Imagens Primeira página em 60 segundos: Em outubro ardeu mais do que em anos inteiros Gritam "juntos somos mais fortes" pela reflorestação do Pinhal de Leiria Músicos dão concerto para angariar bens para as vítimas dos incêndios Vidas adiadas pelo fogo O dia em 60 segundos: Mortes nos fogos pesam na consciência de Costa A densidade populacional e o envelhecimento em Portugal "Uma vírgula pode mudar a História" Meio dia em 60 segundos: Armamento de guerra encontrado na Chamusca Despertar em 60 segundos: Mais de cem milhões em prejuízos no Centro Primeira página em 60 segundos: Incêndios destroem fábricas e empregos "Escritaria" espalha obra de Miguel Sousa Tavares pelas ruas de Penafiel Disco "Back in Town" é o "grito de libertação" de Mimicat "Pensámos que a aldeia ia arder toda, que íamos ficar sem nada" Forças sírias limpam Raqa após anúncio de vitória sobre Estado Islâmico O dia em 60 segundos: Incêndios de domingo fizeram 41 mortos Finalistas universitários com três mil vagas em Feira de Emprego Idris Elba e Kate Winslet protagonizam "A montanha entre nós" Catalunha manifesta-se contra a prisão de doi ...

# %% [markdown]
# ### Score

# %% [markdown]
# The structure of the score depends on the type of extraction considered: `ByCorpus`, `ByDoc` or `ByDocSentence`.

# %% [markdown]
# #### ByCorpus

# %% [markdown]
# Getting temporal scores by a corpus of documents is possible through the following code: `results = Time_Matters_MultipleDocs(ListOfTexts)`. This configuration assumes "py_heideltime" as the default temporal tagger (more about this [here](https://github.com/LIAAD/wiki/How-to-use-Time-Matters-MultipleDocs#Temporal-Expressions)), "ByCorpus" as the default score_type and the default parameters of time_matters. In this configuration, a single score will be retrieved for a temporal expression regardless it occurs in different documents.

# %% [markdown]
# Running this code, however, will take a considerable amount of time (depending on the PC used) as Heideltime temporal tagger will be running on top of a number of texts. If you want a quicker solution (though not effective) you should use a rule-based approach instead (more about this on the Optional Parameters section).

# %%
from Time_Matters_MultipleDocs import Time_Matters_MultipleDocs
results = Time_Matters_MultipleDocs(ListOfTexts, temporal_tagger=['py_heideltime', 'Portuguese', 'year', 'news'])

#rule-based approach
#results = Time_Matters_MultipleDocs(ListOfTexts, temporal_tagger=['rule_based', 'year'])

# %% [markdown]
# The output is a dictionary where the key is the normalized temporal expression and the value is a list with two positions. The first is the score of the temporal expression. The second is a dictionary of the instances of the temporal expression (as they were found in each document). Example: `{'2011-01-12': [1.0, {0: ['2011-01-12', '12 January 2011'], 6: ['2011-01-12']}]}`, means that the normalized temporal expression `2011-01-12` has a score of 1 and occurs twice (the first time as `2011-01-12`, and the second time as `12 January 2011`) in document 0 and one time (as '2011-01-12') in document 6.

# %%
Score = results[0]
Score
# Out:
# {'1998': [0.848, {8: ['1998']}],
#  '2015': [0.826,
#   {0: ['10/09/2015',
#     '10/09/2015',
#     '10/09/2015',
#     '09/09/2015',
#     '08/09/2015',
#     '07/09/2015',
#     '07/09/2015',
#     '06/09/2015',
#     '06/09/2015',
#     '2015'],
#    1: ['27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '24/07/2015',
#     '23/07/2015',
#     '22/07/2015',
#     '2015'],
#    2: ['28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '2015'],
#    3: ['28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '24/07/2015',
#     '2015'],
#    4: ['28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '24/07/2015',
#     '2015'],
#    5: ['02/08/2015',
#     '02/08/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '2015'],
#    6: ['02/08/2015',
#     '02/08/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '2015'],
#    7: ['28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '24/07/2015',
#     '2015'],
#    8: ['02/08/2015',
#     '02/08/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '2015'],
#    9: ['28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '24/07/2015',
#     '2015'],
#    10: ['02/08/2015',
#     '02/08/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '28/07/2015',
#     '27/07/2015',
#     '27/07/2015',
#     '26/07/2015',
#     '26/07/2015',
#     '25/07/2015',
#     '24/07/2015',
#     '2015'],
#    11: ['12/09/2015',
#     '12/09/2015',
#     '12/09/2015',
#     '10/09/2015',
#     '10/09/2015',
#     '10/09/2015',
#     '09/09/2015',
#     '08/09/2015',
#     '07/09/2015',
#     '07/09/2015',
#     '06/09/2015',
#     '2015'],
#    12: ['13/09/2015',
#     '12/09/2015',
#     '12/09/2015',
#     '10/09/2015',
#     '10/09/2015',
#     '10/09/2015',
#     '09/09/2015',
#     '08/09/2015',
#     '07/09/2015',
#     '2015'],
#    13: ['14/09/2015',
#     '13/09/2015',
#     '12/09/2015',
#     '12/09/2015',
#     '10/09/2015',
#     '10/09/2015',
#     '10/09/2015',
#     '09/09/2015',
#     '2015'],
#    14: ['16/09/2015',
#     '16/09/2015',
#     '15/09/2015',
#     '15/09/2015',
#     '14/09/2015',
#     '13/09/2015',
#     '12/09/2015',
#     '12/09/2015',
#     '10/09/2015',
#     '2015'],
#    15: ['05/09/2015'],
#    16: ['2015'],
#    17: ['2015'],
#    18: ['2015'],
#    19: ['2015']}],
#  '1648': [0.706, {14: ['1648']}],
#  '2011': [0.325,
#   {15: ['2011'],
#    21: ['2011'],
#    22: ['2011'],
#    23: ['2011', '2011'],
#    24: ['2011', '2011']}],
#  '2018': [0.32, {21: ['2018', '2018'], 22: ['2018', '2018']}],
#  '2017': [0.284, {23: ['2017'], 24: ['2017'], 25: ['2017']}],
#  '1435': [0.283, {23: ['1435'], 24: ['1435']}],
#  '2012': [0.249,
#   {13: ['2012'],
#    14: ['2012'],
#    16: ['2012', '2012'],
#    17: ['2012', '2012'],
#    18: ['2012', '2012'],
#    19: ['2012', '2012']}],
#  '2013': [0.22,
#   {16: ['2013'],
#    17: ['2013'],
#    18: ['2013'],
#    19: ['2013'],
#    21: ['2013'],
#    22: ['2013']}],
#  '2016': [0.199,
#   {16: ['2016', '2016', '2016', '2016'],
#    17: ['2016', '2016', '2016', '2016'],
#    20: ['2016']}],
#  '1415': [0.168, {17: ['1415']}]}

# %% [markdown]
# If you are only interested in accessing the keys and the scores run the following code:

# %%
for TempExpr in Score:
    print(f'{TempExpr}; {Score[TempExpr][0]}')
# Out:
# 1998; 0.848
# 2015; 0.826
# 1648; 0.706
# 2011; 0.325
# 2018; 0.32
# 2017; 0.284
# 1435; 0.283
# 2012; 0.249
# 2013; 0.22
# 2016; 0.199
# 1415; 0.168

# %% [markdown]
# #### ByDoc

# %% [markdown]
# Getting temporal scores by document is possible through the following code. This configuration is set to consider "py_heideltime" as the default temporal tagger (more about this [here](https://github.com/LIAAD/wiki/How-to-use-Time-Matters-MultipleDocs#Temporal-Expressions)), "ByDoc" as the score_type and the default parameters of time_matters. In this configuration, multiple occurrences of a temporal expression in different documents, will return multiple (eventually different) scores (e.g., 0.92 for the occurrence of 2019 in sentence 1 of document 1; and 0.77 for the occurrence of 2019 in sentence 2 of document 1). Once again, we apply the `year` granularity to avoid getting too many fine-grained temporal expressions. Yet, you are more than welcome to alternatively run the following code: `results = Time_Matters_MultipleDocs(ListOfTexts, score_type='ByDoc')`.

# %%
results = Time_Matters_MultipleDocs(ListOfTexts, score_type='ByDoc', temporal_tagger=['py_heideltime', 'Portuguese', 'year', 'news'])

#rule-based approach
#results = Time_Matters_MultipleDocs(ListOfTexts, score_type='ByDoc', temporal_tagger=['rule_based', 'year'])

# %% [markdown]
# The output is a dictionary where the key is the normalized temporal expression and the value is a dictionary (where the key is the DocID and the value is a list with two positions. The first is the score of the temporal expression in that particular document. The second is a list of the instances of the temporal expression (as they were found in the text in that particular document). Example: `{'2010': {1: [0.2, ['2010']], 5: [0.983, ['2010', '2010']]}}`, means that the normalized temporal expression `2010` has a score of 0.2 in the document with ID 1, and a score of 0.983 in the document with ID 5 (where it occurs two times).

# %%
Score = results[0]
Score
# Out:
# {'2007': {3: [1.0, ['24 de Novembro de 2007']],
#   4: [1.0, ['24 de Novembro de 2007']]},
#  '1001': {28: [0.731, ['1001']], 30: [1.0, ['1001']]},
#  '2018': {13: [0.991, ['2018']]},
#  '2016': {48: [0.942, ['2016', '2016']]},
#  '1985': {3: [0.933, ['1985']], 45: [0.172, ['1985']]},
#  '2011': {1: [0.875, ['2011-02-05 07:39:24', '2011-02-05 07:39:24']]},
#  '2019': {26: [0.712, ['2019', '2019', '2019', '2019', '2019']],
#   29: [0.712, ['2019', '2019', '2019', '2019', '2019']],
#   31: [0.616, ['2019', '2019', '2019', '2019', '2019', '2019']],
#   32: [0.74, ['2019', '2019', '2019', '2019', '2019', '2019']],
#   33: [0.673, ['2019', '2019', '2019', '2019', '2019']],
#   34: [0.54, ['2019', '2019', '2019', '2019', '2019', '2019']],
#   35: [0.712, ['2019', '2019', '2019', '2019', '2019']],
#   37: [0.807, ['2019', '2019', '2019', '2019', '2019', '2019']],
#   38: [0.673, ['2019', '2019', '2019', '2019', '2019']],
#   39: [0.673, ['2019', '2019', '2019', '2019', '2019']],
#   40: [0.616, ['2019', '2019', '2019', '2019', '2019', '2019']],
#   42: [0.712, ['2019', '2019', '2019', '2019', '2019']],
#   44: [0.54, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#  '2017': {12: [0.114, ['2017']],
#   16: [0.751, ['2017']],
#   45: [0.216, ['2017', '2017']]},
#  '2009': {17: [0.609, ['2009']],
#   18: [0.205, ['12 de Junho de 2009']],
#   19: [0.43, ['22 de Janeiro de 2009']],
#   27: [0.43, ['22 de Janeiro de 2009']]},
#  '2008': {15: [0.159, ['10 de Fevereiro de 2008']],
#   24: [0.488, ['2008']],
#   25: [0.488, ['2008']]},
#  '2006': {5: [0.199, ['1 de Agosto de 2006']],
#   7: [0.065,
#    ['21 de Setembro de 2006',
#     '21 de Setembro de 2006',
#     '21 de Setembro de 2006']]}}

# %% [markdown]
# If you are only interested in accessing the keys and the scores run the following code:

# %%
for TempExpr in Score:
    print(f'{TempExpr}')
    for docID in Score[TempExpr]:
        print(f'\t docID = {docID}; score = {Score[TempExpr][docID][0]}')
# Out:
# 2007
# 	 docID = 3; score = 1.0
# 	 docID = 4; score = 1.0
# 1001
# 	 docID = 28; score = 0.731
# 	 docID = 30; score = 1.0
# 2018
# 	 docID = 13; score = 0.991
# 2016
# 	 docID = 48; score = 0.942
# 1985
# 	 docID = 3; score = 0.933
# 	 docID = 45; score = 0.172
# 2011
# 	 docID = 1; score = 0.875
# 2019
# 	 docID = 26; score = 0.712
# 	 docID = 29; score = 0.712
# 	 docID = 31; score = 0.616
# 	 docID = 32; score = 0.74
# 	 docID = 33; score = 0.673
# 	 docID = 34; score = 0.54
# 	 docID = 35; score = 0.712
# 	 docID = 37; score = 0.807
# 	 docID = 38; score = 0.673
# 	 docID = 39; score = 0.673
# 	 docID = 40; score = 0.616
# 	 docID = 42; score = 0.712
# 	 docID = 44; score = 0.54
# 2017
# 	 docID = 12; score = 0.114
# 	 docID = 16; score = 0.751
# 	 docID = 45; score = 0.216
# 2009
# 	 docID = 17; score = 0.609
# 	 docID = 18; score = 0.205
# 	 docID = 19; score = 0.43
# 	 docID = 27; score = 0.43
# 2008
# 	 docID = 15; score = 0.159
# 	 docID = 24; score = 0.488
# 	 docID = 25; score = 0.488
# 2006
# 	 docID = 5; score = 0.199
# 	 docID = 7; score = 0.065

# %% [markdown]
# Or the following code if, for each temporal expression found, you want to reverse order by score:

# %%
for TempExpr in Score:
    print(f'{TempExpr}')
    for item in sorted(Score[TempExpr].items(), key = lambda x: x[1][0],reverse=True):
        print(f'\t docID = {item[0]}; score = {item[1][0]}')
# Out:
# 2007
# 	 docID = 3; score = 1.0
# 	 docID = 4; score = 1.0
# 1001
# 	 docID = 30; score = 1.0
# 	 docID = 28; score = 0.731
# 2018
# 	 docID = 13; score = 0.991
# 2016
# 	 docID = 48; score = 0.942
# 1985
# 	 docID = 3; score = 0.933
# 	 docID = 45; score = 0.172
# 2011
# 	 docID = 1; score = 0.875
# 2019
# 	 docID = 37; score = 0.807
# 	 docID = 32; score = 0.74
# 	 docID = 26; score = 0.712
# 	 docID = 29; score = 0.712
# 	 docID = 35; score = 0.712
# 	 docID = 42; score = 0.712
# 	 docID = 33; score = 0.673
# 	 docID = 38; score = 0.673
# 	 docID = 39; score = 0.673
# 	 docID = 31; score = 0.616
# 	 docID = 40; score = 0.616
# 	 docID = 34; score = 0.54
# 	 docID = 44; score = 0.54
# 2017
# 	 docID = 16; score = 0.751
# 	 docID = 45; score = 0.216
# 	 docID = 12; score = 0.114
# 2009
# 	 docID = 17; score = 0.609
# 	 docID = 19; score = 0.43
# 	 docID = 27; score = 0.43
# 	 docID = 18; score = 0.205
# 2008
# 	 docID = 24; score = 0.488
# 	 docID = 25; score = 0.488
# 	 docID = 15; score = 0.159
# 2006
# 	 docID = 5; score = 0.199
# 	 docID = 7; score = 0.065

# %% [markdown]
# #### ByDocSentence

# %% [markdown]
# Getting temporal scores by document & sentence is possible through the following code. This configuration is set to consider "py_heideltime" as the default temporal tagger (more about this [here](https://github.com/LIAAD/wiki/How-to-use-Time-Matters-MultipleDocs#Temporal-Expressions)), "ByDoc&Sentence" as the score_type and the default parameters of time_matters. In this configuration, multiple occurrences of a temporal expression in different sentences of a given document, will return multiple (eventually different) scores (e.g., 0.2 for its occurrence in document 1; and 0.982 for its occurrence in document 2). Once again, we apply the `year` granularity to avoid getting too many fine-grained temporal expressions. Yet, you are more than welcome to alternatively run the following code: `results = Time_Matters_MultipleDocs(ListOfTexts, score_type='ByDocSentence')`.

# %%
#results = Time_Matters_MultipleDocs(ListOfTexts, score_type='ByDocSentence', temporal_tagger=['py_heideltime', 'Portuguese', 'year', 'news'])

#rule-based approach
results = Time_Matters_MultipleDocs(ListOfTexts, score_type='ByDocSentence', temporal_tagger=['rule_based', 'year'])

# %% [markdown]
# The output is a dictionary where the key is the normalized temporal expression and the value is a dictionary (where the key is the DocID and the value is a new dictionary (where the key is the sentenceID and the value is list with two positions. The first is the score of the temporal expression in that particular sentence. The second is a list of the instances of the temporal expression (as they were found in the text in that particular setencent of that document)). Example: `{'2011': {0: {5: [0.983, ['2010', '2010']], {6: [0.183, ['2010']]}}`, means that the normalized temporal expression `2011` has a score of 0.983 in the sentence with ID 5 (where it occurs twice) of docID 0, and a score of 0.183 in the sentence with ID 6 of docID 0.

# %%
Score = results[0]
Score
# Out:
# {'2007': {3: {0: [1.0, ['2007']]}, 4: {0: [0.971, ['2007']]}},
#  '2006': {5: {1: [1.0, ['2006']]}, 7: {1: [0.974, ['2006', '2006']]}},
#  '1001': {28: {0: [0.983, ['1001']]}, 30: {0: [1.0, ['1001']]}},
#  '2018': {13: {0: [0.991, ['2018']]}},
#  '2019': {26: {0: [0.987, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#   29: {0: [0.976, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#   31: {0: [0.96, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#   32: {0: [0.806, ['2019']],
#    1: [0.964, ['2019', '2019', '2019', '2019', '2019']]},
#   33: {0: [0.96, ['2019', '2019', '2019', '2019', '2019']]},
#   34: {0: [0.971, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#   35: {0: [0.976, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#   37: {0: [0.987, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#   38: {0: [0.977, ['2019', '2019', '2019', '2019', '2019']]},
#   39: {0: [0.977, ['2019', '2019', '2019', '2019', '2019']]},
#   40: {0: [0.96, ['2019', '2019', '2019', '2019', '2019', '2019']]},
#   42: {0: [0.974, ['2019', '2019', '2019', '2019', '2019']]},
#   44: {0: [0.971, ['2019', '2019', '2019', '2019', '2019', '2019']]}},
#  '2017': {12: {0: [0.984, ['2017']]},
#   16: {1: [0.862, ['2017']]},
#   45: {0: [0.868, ['2017', '2017']]}},
#  '2011': {1: {0: [0.982, ['2011-02-05', '2011-02-05']]}},
#  '2008': {15: {0: [0.913, ['2008']]},
#   24: {0: [0.972, ['2008']]},
#   25: {0: [0.972, ['2008']]}},
#  '1985': {3: {3: [0.97, ['1985']]}, 45: {0: [0.904, ['1985']]}},
#  '2004': {22: {3: [0.959, ['11.10.2004']]}},
#  '2016': {48: {0: [0.956, ['2016', '2016']]}},
#  '2009': {17: {1: [0.695, ['2009']]},
#   18: {0: [0.891, ['2009']]},
#   19: {1: [0.923, ['2009']]},
#   27: {1: [0.923, ['2009']]}}}

# %% [markdown]
# If you are only interested in accessing the keys and the scores run the following code:

# %%
for TempExpr in Score:
    print(f'{TempExpr}')
    for docID in Score[TempExpr]:
        print(f'\t docID = {docID}')
        for sentenceID in Score[TempExpr][docID]:
            print(f'\t\t sentenceID = {sentenceID}; score = {Score[TempExpr][docID][sentenceID][0]}')
# Out:
# 2007
# 	 docID = 3
# 		 sentenceID = 0; score = 1.0
# 	 docID = 4
# 		 sentenceID = 0; score = 0.971
# 2006
# 	 docID = 5
# 		 sentenceID = 1; score = 1.0
# 	 docID = 7
# 		 sentenceID = 1; score = 0.974
# 1001
# 	 docID = 28
# 		 sentenceID = 0; score = 0.983
# 	 docID = 30
# 		 sentenceID = 0; score = 1.0
# 2018
# 	 docID = 13
# 		 sentenceID = 0; score = 0.991
# 2019
# 	 docID = 26
# 		 sentenceID = 0; score = 0.987
# 	 docID = 29
# 		 sentenceID = 0; score = 0.976
# 	 docID = 31
# 		 sentenceID = 0; score = 0.96
# 	 docID = 32
# 		 sentenceID = 0; score = 0.806
# 		 sentenceID = 1; score = 0.964
# 	 docID = 33
# 		 sentenceID = 0; score = 0.96
# 	 docID = 34
# 		 sentenceID = 0; score = 0.971
# 	 docID = 35
# 		 sentenceID = 0; score = 0.976
# 	 docID = 37
# 		 sentenceID = 0; score = 0.987
# 	 docID = 38
# 		 sentenceID = 0; score = 0.977
# 	 docID = 39
# 		 sentenceID = 0; score = 0.977
# 	 docID = 40
# 		 sentenceID = 0; score = 0.96
# 	 docID = 42
# 		 sentenceID = 0; score = 0.974
# 	 docID = 44
# 		 sentenceID = 0; score = 0.971
# 2017
# 	 docID = 12
# 		 sentenceID = 0; score = 0.984
# 	 docID = 16
# 		 sentenceID = 1; score = 0.862
# 	 docID = 45
# 		 sentenceID = 0; score = 0.868
# 2011
# 	 docID = 1
# 		 sentenceID = 0; score = 0.982
# 2008
# 	 docID = 15
# 		 sentenceID = 0; score = 0.913
# 	 docID = 24
# 		 sentenceID = 0; score = 0.972
# 	 docID = 25
# 		 sentenceID = 0; score = 0.972
# 1985
# 	 docID = 3
# 		 sentenceID = 3; score = 0.97
# 	 docID = 45
# 		 sentenceID = 0; score = 0.904
# 2004
# 	 docID = 22
# 		 sentenceID = 3; score = 0.959
# 2016
# 	 docID = 48
# 		 sentenceID = 0; score = 0.956
# 2009
# 	 docID = 17
# 		 sentenceID = 1; score = 0.695
# 	 docID = 18
# 		 sentenceID = 0; score = 0.891
# 	 docID = 19
# 		 sentenceID = 1; score = 0.923
# 	 docID = 27
# 		 sentenceID = 1; score = 0.923

# %% [markdown]
# Or the following code if, for each temporal expression found, you want to reverse order by score:

# %%
for TempExpr in Score:
    print(f'{TempExpr}')
    for docID in Score[TempExpr]:
        print(f'\t docID = {docID}')
        for item in sorted(Score[TempExpr][docID].items(), key = lambda x: x[1][0],reverse=True):
            print(f'\t \t sentenceID = {item[0]}; score = {item[1][0]}')
# Out:
# 2007
# 	 docID = 3
# 	 	 sentenceID = 0; score = 1.0
# 	 docID = 4
# 	 	 sentenceID = 0; score = 0.971
# 2006
# 	 docID = 5
# 	 	 sentenceID = 1; score = 1.0
# 	 docID = 7
# 	 	 sentenceID = 1; score = 0.974
# 1001
# 	 docID = 28
# 	 	 sentenceID = 0; score = 0.983
# 	 docID = 30
# 	 	 sentenceID = 0; score = 1.0
# 2018
# 	 docID = 13
# 	 	 sentenceID = 0; score = 0.991
# 2019
# 	 docID = 26
# 	 	 sentenceID = 0; score = 0.987
# 	 docID = 29
# 	 	 sentenceID = 0; score = 0.976
# 	 docID = 31
# 	 	 sentenceID = 0; score = 0.96
# 	 docID = 32
# 	 	 sentenceID = 1; score = 0.964
# 	 	 sentenceID = 0; score = 0.806
# 	 docID = 33
# 	 	 sentenceID = 0; score = 0.96
# 	 docID = 34
# 	 	 sentenceID = 0; score = 0.971
# 	 docID = 35
# 	 	 sentenceID = 0; score = 0.976
# 	 docID = 37
# 	 	 sentenceID = 0; score = 0.987
# 	 docID = 38
# 	 	 sentenceID = 0; score = 0.977
# 	 docID = 39
# 	 	 sentenceID = 0; score = 0.977
# 	 docID = 40
# 	 	 sentenceID = 0; score = 0.96
# 	 docID = 42
# 	 	 sentenceID = 0; score = 0.974
# 	 docID = 44
# 	 	 sentenceID = 0; score = 0.971
# 2017
# 	 docID = 12
# 	 	 sentenceID = 0; score = 0.984
# 	 docID = 16
# 	 	 sentenceID = 1; score = 0.862
# 	 docID = 45
# 	 	 sentenceID = 0; score = 0.868
# 2011
# 	 docID = 1
# 	 	 sentenceID = 0; score = 0.982
# 2008
# 	 docID = 15
# 	 	 sentenceID = 0; score = 0.913
# 	 docID = 24
# 	 	 sentenceID = 0; score = 0.972
# 	 docID = 25
# 	 	 sentenceID = 0; score = 0.972
# 1985
# 	 docID = 3
# 	 	 sentenceID = 3; score = 0.97
# 	 docID = 45
# 	 	 sentenceID = 0; score = 0.904
# 2004
# 	 docID = 22
# 	 	 sentenceID = 3; score = 0.959
# 2016
# 	 docID = 48
# 	 	 sentenceID = 0; score = 0.956
# 2009
# 	 docID = 17
# 	 	 sentenceID = 1; score = 0.695
# 	 docID = 18
# 	 	 sentenceID = 0; score = 0.891
# 	 docID = 19
# 	 	 sentenceID = 1; score = 0.923
# 	 docID = 27
# 	 	 sentenceID = 1; score = 0.923

# %% [markdown]
# ### Temporal Expressions

# %% [markdown]
# - <b>TempExpressions</b>:  A dictionary, where the key is the docID and the value is a list of tuples, each having two positions. The first is the normalized temporal expression. The second is the temporal expression as it was found in the text. The order in which the elements appear in the list, reflect the order of the temporal expressions in the text. Example: `{0: [('1975-02-11TAF', 'the afternoon of February 11, 1975'),..]}`.

# %%
TempExpressions = results[1]
TempExpressions
# Out:
# {0: [],
#  1: [('2011', '2011-02-05'), ('2011', '2011-02-04')],
#  2: [],
#  3: [('2007', '2007'), ('1985', '1985')],
#  4: [('2007', '2007')],
#  5: [('2006', '2006')],
#  6: [],
#  7: [('2006', '2006'), ('2006', '2006')],
#  8: [],
#  9: [],
#  10: [],
#  11: [],
#  12: [('2017', '2017')],
#  13: [('2018', '2018')],
#  14: [],
#  15: [('2008', '2008')],
#  16: [('2017', '2017')],
#  17: [('2009', '2009')],
#  18: [('2009', '2009')],
#  19: [('2009', '2009')],
#  20: [],
#  21: [],
#  22: [('2004', '11.10.2004')],
#  23: [],
#  24: [('2008', '2008')],
#  25: [('2008', '2008')],
#  26: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  27: [('2009', '2009')],
#  28: [('1001', '1001')],
#  29: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  30: [('1001', '1001')],
#  31: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  32: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  33: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  34: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  35: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  36: [],
#  37: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  38: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  39: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  40: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  41: [],
#  42: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  43: [],
#  44: [('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019'),
#   ('2019', '2019')],
#  45: [('2017', '2017'), ('2017', '2017'), ('1985', '1985')],
#  46: [],
#  47: [],
#  48: [('2016', '2016'), ('2016', '2016')],
#  49: []}

# %% [markdown]
# ### Relevant Keywords

# %% [markdown]
# - <b>RelevantKWs</b>: a dictionary where the key is the docID and the value is a dictionary of the relevant keywords (and corresponding scores). In our algorithm, keywords are detected by [YAKE!](https://github.com/LIAAD/yake). If you want to know more about the role of YAKE! in Time-Matters, please refer to the following [link](https://github.com/LIAAD/Time-Matters#Text-Representation). Example: `{0: {'haiti': 0.03, 'haiti earthquake': 0.07}}` means that the tokens `haiti` and `haiti earthquake` were determined as relevant keywords by YAKE! keyword extractor with the scores 0.03 and 0.07 (the lower the score the more relevant the keyword is) in docID 0.

# %%
RelevantKWs = results[2]
RelevantKWs
# Out:
# {0: {'sapo': 0.046969944886361546,
#   'perfil': 0.05565546370445849,
#   'público': 0.05565546370445849,
#   'cristiano': 0.06689913088461949,
#   'ronaldo': 0.06689913088461949,
#   'verão': 0.06689913088461949,
#   'universo': 0.0711573375153331,
#   'blogs': 0.08114358817357717,
#   'companhia': 0.08426404457475574,
#   'portuguesa': 0.19936150948604098},
#  1: {'cristiano': 0.027192731953726307,
#   'ronaldo': 0.027192731953726307,
#   'blogs': 0.04215818539420242,
#   'sapo': 0.04674945938726905,
#   'perfil': 0.05525216724846367,
#   'público': 0.05525216724846367,
#   'publicado': 0.14214793329894973,
#   'ler': 0.18193477052071755,
#   'universo': 0.19238915281611643,
#   'rubrica': 0.19238915281611643},
#  2: {'cristiano': 0.026843949568312042,
#   'ronaldo': 0.034993336214078005,
#   'facebook': 0.06352443348012651,
#   'playlist': 0.06451389312838214,
#   'create': 0.07742438899079719,
#   'fullscreen': 0.07742438899079719,
#   'chat': 0.07742438899079719,
#   'tweet': 0.07742438899079719,
#   'remove': 0.08873154725396284,
#   'page': 0.10900640994396935},
#  3: {'ronaldo': 0.052189867375833573,
#   'cristiano': 0.06451442583919223,
#   'sábado': 0.07215217244110889,
#   'attention': 0.07215217244110889,
#   'novembro': 0.08670879544302955,
#   'portuguese': 0.17501095594423155,
#   'translation': 0.17687437429119535,
#   'english': 0.17687437429119535,
#   'funchal': 0.30160498672590774,
#   'february': 0.30160498672590774},
#  4: {'ronaldo': 0.04108409306174711,
#   'cristiano': 0.04957479901963369,
#   'sábado': 0.07407368321993234,
#   'attention': 0.07407368321993234,
#   'novembro': 0.0864513431609159,
#   'english': 0.1377013113867819,
#   'portuguese': 0.19023152240241925,
#   'translation': 0.201251486911623,
#   'home': 0.278355023340194,
#   'idol': 0.3315881340955713},
#  5: {'cristiano': 0.026498554687455742,
#   'ronaldo': 0.032350669999186774,
#   'blog': 0.08228021549935714,
#   'informações': 0.08228021549935714,
#   'moranguita': 0.13889827495201196,
#   'texto': 0.22167621871704501,
#   'agosto': 0.237447683652198,
#   'história': 0.237447683652198,
#   'kaulitz': 0.237447683652198,
#   'terça-feira': 0.33241250909360953},
#  6: {'wikipédia': 0.018796570808388428,
#   'início': 0.06295532167170864},
#  48: {'portugal': 0.04871873447671616,
#   'real': 0.05028148870617453,
#   'cristiano': 0.06524824228677512,
#   'ronaldo': 0.06524824228677512,
#   'contact': 0.06579859770750046,
#   'madrid': 0.07789293669618462,
#   'live': 0.09129782615596549,
#   'full': 0.12229475091414897,
#   'score': 0.14944149167520399,
#   'january': 0.15100908149290848},
#  49: {'cristiano': 0.017732691429917003,
#   'ronaldo': 0.02263477107472869,
#   'blog': 0.07612335116561549,
#   'vídeos': 0.13528791277972665,
#   'fotos': 0.1696755245786087,
#   'entrevistas': 0.1696755245786087,
#   'dedicado': 0.20548439168269064,
#   'melhor': 0.20548439168269064,
#   'jogador': 0.20548439168269064,
#   'português': 0.20548439168269064}}

# %% [markdown]
# ### Text Normalized

# %% [markdown]
# - <b>TextNormalized</b>: A normalized version of the text, a dictionary, where the key is the docID and the value is a string, where temporal expressions are marked with the tag `<d>` and relevant keywords with the tag `<kw>`. Example: `{0: 'As of <d>2010</d> (see 1500 photos here), the following major earthquakes have been recorded in <kw>haiti</kw>.'}`

# %%
TextNormalized = results[3]
TextNormalized
# Out:
# {0: '<kw>blogs</kw> do <kw>sapo</kw>: <kw>perfil</kw> <kw>público</kw> <kw>sapo</kw> <kw>blogs</kw> Os Meus <kw>blogs</kw> <kw>perfil</kw> <kw>público</kw> *Cristiano <kw>ronaldo</kw> 9* didothebest@live.it TV <kw>universo</kw>: A <kw>companhia</kw> para o <kw>verão</kw>! http://tvuniverso.blogs.sapo.pt <kw>blog</kw> que fala sobre tudo o que se passa no <kw>mundo</kw> da Televisão <kw>portuguesa</kw>. Outros Autores: bvale Tv <kw>universo</kw>: Ve aqui ... ',
#  1: '<kw>blogs</kw> do <kw>sapo</kw>: <kw>perfil</kw> <kw>público</kw> <kw>sapo</kw> <kw>blogs</kw> Os Meus <kw>blogs</kw> <kw>perfil</kw> <kw>público</kw> *Cristiano <kw>ronaldo</kw> 9 ... (...) <kw>publicado</kw> por *Cristiano <kw>ronaldo</kw> 9* às <d>2011</d> 07:39:24 » <kw>ler</kw> mais « <kw>ler</kw> menos TV <kw>universo</kw>: Agora também no Twitter <kw>rubrica</kw>: "Analise do(...) <kw>publicado</kw> por *Cristiano <kw>ronaldo</kw> 9* às <d>2011</d> 22:27:03 ... ',
#  2: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>create</kw> your <kw>page</kw> here <kw>fullscreen</kw> player <kw>chat</kw> <kw>tweet</kw> this <kw>page</kw> share on <kw>facebook</kw> ...  More <kw>remove</kw> the <kw>playlist</kw> <kw>cristiano</kw> <kw>ronaldo</kw> Penalty <kw>remove</kw> the <kw>playlist</kw> Motivational <kw>videos</kw> <kw>remove</kw> the <kw>playlist</kw> <kw>cristiano</kw> <kw>ronaldo</kw> Lifestyle <kw>remove</kw> the <kw>playlist</kw> <kw>cristiano</kw> <kw>ronaldo</kw> Injury <kw>remove</kw> the <kw>playlist</kw> ... ',
#  3: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>sábado</kw>, 24 de <kw>novembro</kw> de <d>2007</d> <kw>cristiano</kw> <kw>ronaldo</kw>  <kw>attention</kw>!! <kw>translation</kw> exists in <kw>english</kw> / <kw>portuguese</kw>! <kw>cristiano</kw> <kw>ronaldo</kw>!!!! AN <kw>idol</kw> alone World Soccer / Um ...  <kw>english</kw> (<kw>translation</kw> for <kw>portuguese</kw> more ahead) <kw>cristiano</kw> <kw>ronaldo</kw> (<kw>funchal</kw>, <kw>february</kw> 5, <d>1985</d>) it is a ... ',
#  4: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>home</kw> <kw>sábado</kw>, 24 de <kw>novembro</kw> de <d>2007</d> <kw>cristiano</kw> <kw>ronaldo</kw>  <kw>attention</kw>!! <kw>translation</kw> exists in <kw>english</kw> / <kw>portuguese</kw>! <kw>cristiano</kw> <kw>ronaldo</kw>!!!! AN <kw>idol</kw> ...  Historial: !!! !!! In <kw>english</kw> (<kw>translation</kw> for <kw>portuguese</kw> more ahead) <kw>cristiano</kw> <kw>ronaldo</kw> (<kw>funchal</kw> ... ',
#  5: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> COM TODAS AS <kw>informações</kw> SOBRE O <kw>cristiano</kw> <kw>ronaldo</kw>! <kw>terça-feira</kw>, 1 de <kw>agosto</kw> de <d>2006</d> <kw>cristiano</kw> <kw>ronaldo</kw> E A SUA <kw>história</kw> A <kw>moranguita</kw> <kw>kaulitz</kw> enviou um excelente <kw>texto</kw> sobre o <kw>cristiano</kw> <kw>ronaldo</kw>. Muito obrigado <kw>moranguita</kw> Aqui fica o <kw>texto</kw> sobre este ... ',
#  6: '<kw>cristiano</kw> <kw>ronaldo</kw> – <kw>wikipédia</kw>, a <kw>enciclopédia</kw> <kw>livre</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>origem</kw>: <kw>wikipédia</kw>, a <kw>enciclopédia</kw> <kw>livre</kw>. Ir para: navegação , <kw>pesquisa</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>oih</kw> • <kw>goih</kw> • <kw>mmnsc</kw> <kw>cristiano</kw> <kw>ronaldo</kw> atuando pelo <kw>real</kw> <kw>madrid</kw> <kw>informações</kw> pessoais Nome completo <kw>cristiano</kw> <kw>ronaldo</kw> dos <kw>santos</kw> <kw>aveiro</kw> Data de ... ',
#  7: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> COM TODAS AS <kw>informações</kw> SOBRE O <kw>cristiano</kw> <kw>ronaldo</kw>! <kw>quinta-feira</kw>, 21 de <kw>setembro</kw> de <d>2006</d> Mais <kw>fotos</kw> de <kw>cristiano</kw> <kw>ronaldo</kw> Mais algumas <kw>fotos</kw> daquele excelente ...  | adicionar aos favoritos <kw>terça-feira</kw>, 1 de <kw>agosto</kw> de <d>2006</d> <kw>cristiano</kw> <kw>ronaldo</kw> e a sua <kw>história</kw> A ... ',
#  8: '<kw>cristiano</kw> <kw>ronaldo</kw>. O <kw>melhor</kw> <kw>jogador</kw> de <kw>futebol</kw> do <kw>mundo</kw>.  Forum  <kw>fan</kw> club  <kw>biografia</kw> ...  namoradas <kw>sejam</kw> benvindos ao novo <kw>site</kw> <kw>dedicado</kw> a <kw>cristiano</kw> <kw>ronaldo</kw>. Aqui teremos tudo o que sempre quis saber sobe <kw>ronaldo</kw>.  Pauleta web <kw>site</kw> <kw>cristiano</kw> <kw>ronaldo</kw> em discurso directo : «Ser escolhido ... ',
#  9: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>skip</kw> to <kw>main</kw> | <kw>skip</kw> to <kw>sidebar</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>noticias</kw>, <kw>fotos</kw>, <kw>vídeos</kw> e muito mais sobre <kw>cristiano</kw> <kw>ronaldo</kw>. O <kw>melhor</kw> <kw>jogador</kw> do <kw>mundo</kw>! <kw>cristiano</kw> <kw>ronaldo</kw> Namoradas <kw>ronaldo</kw> Miguel Veloso Mourinho <kw>gold</kw> Publicada por Webmaster | 9:01 PM | 0 comentários » <kw>cristiano</kw> <kw>ronaldo</kw> is a <kw>gold</kw> ... ',
#  10: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>skip</kw> to <kw>main</kw> | <kw>skip</kw> to <kw>sidebar</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>noticias</kw>, <kw>fotos</kw>, <kw>vídeos</kw> e muito mais sobre <kw>cristiano</kw> <kw>ronaldo</kw>. O <kw>melhor</kw> <kw>jogador</kw> do <kw>mundo</kw>! <kw>cristiano</kw> <kw>ronaldo</kw> Namoradas <kw>ronaldo</kw> Miguel Veloso Mourinho <kw>gold</kw> Publicada por Webmaster | 9:01 PM | 0 comentários » <kw>cristiano</kw> <kw>ronaldo</kw> is a <kw>gold</kw> ... ',
#  11: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>download</kw> Help <kw>change</kw> <kw>currency</kw>: <kw>rol</kw> select <kw>currency</kw> <kw>romanian</kw> <kw>leu</kw> (<kw>rol</kw>) U.S. ...  your PC » <kw>wallpapers</kw> » <kw>athletes</kw> <kw>cristiano</kw> <kw>ronaldo</kw> Program Information 1 Screenshot Add your opinion ...  of <kw>portugal</kw> and <kw>manchester</kw> United” <kw>cristiano</kw> <kw>ronaldo</kw> is the young star of the <kw>portuguese</kw> national ... ',
#  12: '<kw>cristiano</kw> <kw>ronaldo</kw> - Welcome to my Official Website <kw>latest</kw> <kw>career</kw> <kw>stats</kw> Down My <kw>team</kw> <kw>downloads</kw>  <kw>latest</kw> <kw>career</kw> <kw>stats</kw> My <kw>team</kw> <kw>downloads</kw> <kw>facebook</kw> Twitter Google Plus Youtube <kw>instagram</kw> © <d>2017</d> <kw>polaris</kw> <kw>sports</kw> / <kw>cristiano</kw> <kw>ronaldo</kw>  Available on the Available on the by BranditNext Terms and Conditions ... ',
#  13: '<kw>cristiano</kw> <kw>ronaldo</kw> - Welcome to my Official Website <kw>latest</kw> <kw>career</kw> <kw>stats</kw> Down My <kw>team</kw> <kw>downloads</kw>  <kw>latest</kw> <kw>career</kw> <kw>stats</kw> My <kw>team</kw> <kw>downloads</kw> <kw>facebook</kw> Twitter Google Plus Youtube <kw>instagram</kw> © <d>2018</d> <kw>polaris</kw> <kw>sports</kw> / <kw>cristiano</kw> <kw>ronaldo</kw>  Available on the Available on the by BranditNext Terms and Conditions ... ',
#  14: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>videos</kw> <kw>comicos</kw> <kw>videos</kw> <kw>comicos</kw> <kw>videos</kw> <kw>comicos</kw> <kw>cheios</kw> de <kw>humor</kw>. Os <kw>videos</kw>, <kw>imagem</kw> ...  <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> é um dos <kw>futebolistas</kw> do Momento Este <kw>jogador</kw> <kw>português</kw> de <kw>futebol</kw> de seu nome <kw>cristiano</kw> <kw>ronaldo</kw> é uma das estrelas mundiais deste desporto e será muito provavelmente nos ... ',
#  15: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>fotos</kw> <kw>loucas</kw> <kw>fotos</kw> <kw>loucas</kw> <kw>fotos</kw> <kw>loucas</kw>, <kw>foto</kw> <kw>louca</kw>, <kw>imagens</kw>, <kw>fotos</kw> <kw>engraçadas</kw> ...  » <kw>domingo</kw>, 10 de <kw>fevereiro</kw> de <d>2008</d> <kw>cristiano</kw> <kw>ronaldo</kw> Ver Mais <kw>fotos</kw> <kw>cristiano</kw> <kw>ronaldo</kw> tags: anedotas , apanhados , <kw>blog</kw> , <kw>blogs</kw> , bola , comedia , <kw>cristiano</kw> <kw>ronaldo</kw> , curiosidades , desporto , engracada ... ',
#  16: '<kw>cristiano</kw> <kw>ronaldo</kw> – <kw>wikipédia</kw>, a <kw>enciclopédia</kw> <kw>livre</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>origem</kw>: <kw>wikipédia</kw>, a <kw>enciclopédia</kw> <kw>livre</kw>. Ir para: navegação , <kw>pesquisa</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> em <d>2017</d>, pela <kw>seleção</kw> <kw>portuguesa</kw> . <kw>informações</kw> pessoais Nome completo <kw>cristiano</kw> <kw>ronaldo</kw> dos <kw>santos</kw> <kw>aveiro</kw> Data de nasc. 5 ... ',
#  17: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>pictures</kw> <kw>skip</kw> to <kw>main</kw> | <kw>skip</kw> to <kw>sidebar</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>pictures</kw> <kw>blog</kw> with many <kw>pictures</kw> of <kw>cristiano</kw> <kw>ronaldo</kw>. Photos of <kw>ronaldo</kw> playng <kw>football</kw>, like model, of his girl friends, sensual photos of the great <kw>portuguese</kw> player <kw>friday</kw>, <kw>june</kw> 12, <d>2009</d> <kw>cristiano</kw> <kw>ronaldo</kw> and <kw>paris</kw> ... ',
#  18: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>skip</kw> to <kw>main</kw> | <kw>skip</kw> to <kw>sidebar</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> <kw>dedicado</kw> ao <kw>jogador</kw> <kw>português</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>sexta-feira</kw>, 12 de <kw>junho</kw> de <d>2009</d> <kw>cristiano</kw> <kw>ronaldo</kw> com <kw>paris</kw> <kw>hilton</kw> <kw>cristiano</kw> ...  Angeles, cidade onde está de férias. <kw>cristiano</kw> <kw>ronaldo</kw> e <kw>paris</kw> <kw>hilton</kw> trocaram carícias durante boa ... ',
#  19: '<kw>fotos</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>skip</kw> to <kw>main</kw> | <kw>skip</kw> to <kw>sidebar</kw> <kw>fotos</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> com <kw>muitas</kw> <kw>fotografias</kw> de <kw>cristiano</kw> <kw>ronaldo</kw>. <kw>fotos</kw> de <kw>ronaldo</kw> a <kw>jogar</kw> <kw>futebol</kw>, como modelo, das suas reais e possiveis namoradas, <kw>fotos</kw> sensuais .. <kw>quinta-feira</kw>, 22 de Janeiro de <d>2009</d> <kw>cristiano</kw> <kw>ronaldo</kw> regressa às ... ',
#  20: '<kw>cristiano</kw> <kw>ronaldo</kw> — <kw>blogs</kw>, <kw>imagens</kw>, e mais no WordPress Nome de <kw>utilizador</kw> <kw>password</kw> <kw>iniciar</kw> <kw>sessão</kw> ...  Sobre Nós Avançadas <kw>blogs</kw> sobre : <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> em Destaque Os problemas de <kw>queiroz</kw> ...  outro: <kw>carriço</kw> … mais → Era capaz de viver na Bombonera <kw>cristiano</kw> <kw>ronaldo</kw> do dia Laura escreveu 3 days ... ',
#  21: 'Sou Fã de <kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw>   <kw>biografia</kw>  <kw>cristiano</kw> <kw>ronaldo</kw> dos <kw>santos</kw> <kw>aveiro</kw> ...  <kw>cristiano</kw> <kw>ronaldo</kw> ingressa no <kw>manchester</kw> <kw>united</kw>. Guia da <kw>madeira</kw>  <kw>flores</kw> da <kw>madeira</kw>  Ilha da <kw>madeira</kw> ...  <kw>ronaldo</kw> começa à porta de casa, na Quinta do Falcão em <kw>santo</kw> António (<kw>madeira</kw>). Pelo aniversário ... ',
#  22: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>blogthis</kw>! <kw>cristiano</kw> <kw>ronaldo</kw> 2.5.2005 <kw>kem</kw> é que faz 20 <kw>aninhuhx</kw>? Ah puxe! Parabêns ...  Espectacologicazinha @ 2:30 AM  0 comments <d>2004</d> <kw>noticias</kw>... <kw>cristiano</kw> <kw>ronaldo</kw> foi nomeado o <kw>melhor</kw> <kw>jogador</kw> ...  <kw>cristiano</kw> <kw>ronaldo</kw>, em que passou na <kw>madeira</kw> e não no <kw>brasil</kw> como dizia a <kw>maria</kw>... o <kw>tiago</kw> estava fora dos ... ',
#  23: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> <kw>dedicado</kw> ao <kw>melhor</kw> <kw>jogador</kw> <kw>português</kw> do momento.Muitas <kw>fotos</kw>, <kw>vídeos</kw>, <kw>entrevistas</kw> de <kw>cristiano</kw> <kw>ronaldo</kw>. Os golos de <kw>cristiano</kw> <kw>ronaldo</kw>, as namoradas de <kw>cristiano</kw> <kw>ronaldo</kw>, a família de <kw>cristiano</kw> <kw>ronaldo</kw> ... enfim tudo sobre <kw>cristiano</kw> <kw>ronaldo</kw> <kw>quinta-feira</kw>, 11 ... ',
#  24: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> com <kw>notícias</kw> e <kw>videos</kw> do <kw>jogador</kw> de <kw>futebol</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>thursday</kw>, <kw>july</kw> 24, <d>2008</d> <kw>cristiano</kw> <kw>ronaldo</kw> fica no <kw>manchester</kw> O avançado <kw>português</kw> <kw>cristiano</kw> ...  <kw>cristiano</kw> <kw>ronaldo</kw>, de 23 anos, continuará a <kw>jogar</kw> em Inglaterra pelo menos por mais uma época. <kw>ler</kw> mais ... ',
#  25: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> com <kw>notícias</kw> e <kw>videos</kw> do <kw>jogador</kw> de <kw>futebol</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>thursday</kw>, <kw>july</kw> 24, <d>2008</d> <kw>cristiano</kw> <kw>ronaldo</kw> fica no <kw>manchester</kw> O avançado <kw>português</kw> <kw>cristiano</kw> ...  <kw>cristiano</kw> <kw>ronaldo</kw>, de 23 anos, continuará a <kw>jogar</kw> em Inglaterra pelo menos por mais uma época. <kw>ler</kw> mais ... ',
#  26: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>calendarios</kw> <d>2019</d> <kw>ayuda</kw> | <kw>pago</kw> y envío | <kw>enmarcación</kw> | <kw>contacto</kw> | <kw>créalas</kw> tu mismo | <kw>blog</kw> es pt Calendário <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz ... ',
#  27: '<kw>fotos</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>skip</kw> to <kw>main</kw> | <kw>skip</kw> to <kw>sidebar</kw> <kw>fotos</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> com <kw>muitas</kw> <kw>fotografias</kw> de <kw>cristiano</kw> <kw>ronaldo</kw>. <kw>fotos</kw> de <kw>ronaldo</kw> a <kw>jogar</kw> <kw>futebol</kw>, como modelo, das suas reais e possiveis namoradas, <kw>fotos</kw> sensuais .. <kw>quinta-feira</kw>, 22 de Janeiro de <d>2009</d> <kw>cristiano</kw> <kw>ronaldo</kw> regressa às ... ',
#  28: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>makeover</kw> - <kw>jogos</kw> para <kw>meninas</kw> - <d>1001</d> <kw>jogos</kw> Agora estás a <kw>jogar</kw> <kw>cristiano</kw> <kw>ronaldo</kw> ...  <kw>jogos</kw> para <kw>meninas</kw> <kw>celebridades</kw> Mais <kw>celebridades</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>makeover</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>makeover</kw> ...  <kw>cristiano</kw> <kw>ronaldo</kw> <kw>estilo</kw> <kw>fantasia</kw> para rapaz <kw>futebol</kw> <kw>jogos</kw> de Vestir Maquilhagem Moda Mudar de <kw>imagem</kw> ... ',
#  29: 'Calendario <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> - EuroPosters.it <kw>aiuto</kw> | <kw>pagamento</kw> e <kw>spedizione</kw> | <kw>incorniciatura</kw> | <kw>contatti</kw> | <kw>personalizzate</kw> | <kw>blog</kw> it eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz Kalendář <d>2019</d> ... ',
#  30: "<kw>cristiano</kw> <kw>ronaldo</kw> <kw>makeover</kw> - <kw>jogos</kw> para <kw>meninas</kw> - <d>1001</d> <kw>jogos</kw> Agora estás a <kw>jogar</kw> <kw>cristiano</kw> <kw>ronaldo</kw> ...  <kw>jogos</kw> para <kw>meninas</kw> <kw>celebridades</kw> Mais <kw>celebridades</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>makeover</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>makeover</kw> ... . Bean <kw>dressup</kw> Shakira's <kw>makeover</kw> Famous <kw>couples</kw> 12 <kw>amy</kw> Winehouse <kw>makeover</kw> <kw>cristiano</kw> <kw>ronaldo</kw> Dress Up ... ",
#  31: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>kalender</kw> <d>2019</d> | <kw>kjøp</kw> hos Europosters <kw>hjelp</kw> | <kw>betaling</kw> og levering | <kw>innramming</kw> | <kw>kontakt</kw> | <kw>lag</kw> din egen | <kw>blog</kw> no eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz Kalendář <d>2019</d> ... ',
#  32: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>naptár</kw> <d>2019</d> az <kw>europosters.hu</kw> <kw>infocentrum</kw> | <kw>szállítás</kw> és fizetés | <kw>keretezés</kw> | <kw>kapcsolat</kw> | <kw>készítse</kw> el sajátját! | <kw>blog</kw> hu eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz Kalendář <d>2019</d> ... ',
#  33: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>kalendáre</kw> <d>2019</d> na Posters.sk <kw>infocentrum</kw> | <kw>platba</kw> a doprava tovaru | <kw>rámovanie</kw> obrazov | <kw>kontakt</kw> | <kw>vytvorte</kw> si vlastný | <kw>blog</kw> sk eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz Kalendář <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> es ... ',
#  34: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>calendars</kw> <d>2019</d> on UKposters/EuroPosters Help | <kw>payment</kw> & <kw>delivery</kw> | <kw>framing</kw> | <kw>contact</kw> | <kw>create</kw> your own | <kw>blog</kw> eu gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz Kalendář <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> es <kw>calendar</kw> <d>2019</d> ... ',
#  35: 'Calendário <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> em Europosters.pt <kw>ajuda</kw> | <kw>transporte</kw> e <kw>pagamento</kw> | <kw>molduras</kw> | <kw>contactos</kw> | <kw>crie</kw> o seu | <kw>blog</kw> pt es <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> ... ',
#  36: '<kw>wszystkie</kw> <kw>samochody</kw> <kw>cristiano</kw> <kw>ronaldo</kw> - <kw>ofsajd</kw> <kw>ofsajd</kw> <kw>ofsajd</kw> <kw>szukaj</kw> <kw>redakcja</kw> poleca <kw>david</kw> <kw>beckham</kw> z ...  skrytce za sztucznÄ\x85 Å\x9bcianÄ\x85 <kw>ofsajd</kw> â\x80º <kw>faceci</kw> 27 lis, 14:50 <kw>wszystkie</kw> <kw>samochody</kw> <kw>cristiano</kw> <kw>ronaldo</kw> Jak wiadomo, <kw>cristiano</kw> <kw>ronaldo</kw> jest fanem drogich i szybkich samochodÃ³w. W swoim garaÅ¼u ma juÅ ... ',
#  37: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalenteri</kw> <d>2019</d> - tilaa netistä Europosters.fi <kw>faq</kw> | <kw>toimitus</kw> ja maksu | <kw>kehystys</kw> | <kw>yhteys</kw> | <kw>luo</kw> oma | <kw>blog</kw> fi se <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> dk <kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalender</kw> <d>2019</d> eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> ... ',
#  38: 'Bestel een <kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalender</kw> <d>2019</d> op EuroPosters.nl <kw>infocentrum</kw> | <kw>betaling</kw> en levering | <kw>inlijsten</kw> | <kw>contact</kw> | <kw>maak</kw> jouw eigen | <kw>blog</kw> nl fr <kw>cristiano</kw> <kw>ronaldo</kw> <kw>calendrier</kw> <d>2019</d> be <kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalender</kw> <d>2019</d> eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> ... ',
#  39: 'Bestel een <kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalender</kw> <d>2019</d> op EuroPosters.be <kw>infocentrum</kw> | <kw>betaling</kw> en levering | <kw>inlijsten</kw> | <kw>contact</kw> | <kw>maak</kw> jouw eigen | <kw>blog</kw> be fr <kw>cristiano</kw> <kw>ronaldo</kw> <kw>calendrier</kw> <d>2019</d> nl <kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalender</kw> <d>2019</d> eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> ... ',
#  40: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>calendrier</kw> <d>2019</d> | <kw>acheter-le</kw> <kw>sur</kw> <kw>europosters.fr</kw> × <kw>code</kw> <kw>promotionnel</kw>: 1WB3Y3 ...  | Encadrement | <kw>contact</kw> | Créez la vôtre | <kw>blog</kw> fr nl <kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalender</kw> <d>2019</d> be <kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalender</kw> <d>2019</d> eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> ... ',
#  41: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>encontra</kw> aqui tudo sobre o <kw>cristiano</kw> <kw>ronaldo</kw> ...  sobre a tua <kw>estrela</kw> de <kw>futebol</kw>. <kw>recentes</kw> <kw>cristiano</kw> <kw>ronaldo</kw> é <kw>eleit</kw>... Cristinao <kw>ronaldo</kw> igual a ...  mediação d... <kw>cristiano</kw> <kw>ronaldo</kw> <kw>wallpap</kw>... <kw>manchester</kw> <kw>united</kw> esmaga ... <kw>manchester</kw> <kw>united</kw> partici ... ',
#  42: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>kalendar</kw> <d>2019</d> - plakat, poster, slika na Europosteri.hr <kw>info</kw> | <kw>dostava</kw> i plaćanje | <kw>uokvirivanje</kw> | <kw>kontakt</kw> | <kw>napravite</kw> vlastite | <kw>blog</kw> hr eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz ... ',
#  43: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>encontra</kw> aqui tudo sobre o <kw>cristiano</kw> <kw>ronaldo</kw> ...  sobre a tua <kw>estrela</kw> de <kw>futebol</kw>. <kw>recentes</kw> <kw>cristiano</kw> <kw>ronaldo</kw> é <kw>eleit</kw>... Cristinao <kw>ronaldo</kw> igual a ...  mediação d... <kw>cristiano</kw> <kw>ronaldo</kw> <kw>wallpap</kw>... <kw>manchester</kw> <kw>united</kw> esmaga ... <kw>manchester</kw> <kw>united</kw> partici ... ',
#  44: '<kw>cristiano</kw> <kw>ronaldo</kw> - <kw>calendars</kw> <d>2019</d> on UKposters/Abposters.com Help | <kw>payment</kw> & <kw>delivery</kw> | <kw>framing</kw> | <kw>contact</kw> | <kw>create</kw> your own | <kw>blog</kw> usa eu <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> gb <kw>calendar</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> de <kw>kalender</kw> <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> sk Kalendár <d>2019</d> <kw>cristiano</kw> <kw>ronaldo</kw> cz Kalendář <d>2019</d> ... ',
#  45: '\ufeff <kw>cristiano</kw> <kw>ronaldo</kw> - CR7 - <kw>real</kw> <kw>madrid</kw> | <kw>portugal</kw> | <d>2017</d> <kw>live</kw> <kw>score</kw> :: About us :: <kw>contact</kw> <kw>full</kw> ...  JohnnyBet <kw>live</kw> <kw>cristiano</kw> <kw>ronaldo</kw> - CR7 <kw>fan</kw> <kw>site</kw> <kw>tweet</kw> [ <kw>february</kw> 06, <d>2017</d> ] 7 reasons for <kw>real</kw> <kw>madrid</kw> to ... : <kw>cristiano</kw> <kw>ronaldo</kw> dos <kw>santos</kw> <kw>aveiro</kw> Birth Date: 5th of <kw>february</kw>, <d>1985</d> Birth Place: <kw>madeira</kw>, <kw>portugal</kw> ... ',
#  46: 'Home-Cristiano <kw>ronaldo</kw> <kw>fanclub</kw> <kw>home</kw> Fanclube/Ofertas <kw>news</kw> <kw>contacto</kw> <kw>pesquisa</kw> <kw>mapa</kw> do <kw>site</kw> ...  termos da sua <kw>pesquisa</kw> Enviar formulário de <kw>pesquisa</kw> <kw>cristiano</kw> <kw>ronaldo</kw> na vitória de <kw>portugal</kw> 12 ...  inaugural, contudo Hugo Almeida (13 minutos), <kw>cristiano</kw> <kw>ronaldo</kw> (18) e Pepe (22), único a acertar na ... ',
#  47: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>tribute</kw> | index <kw>cristiano</kw> <kw>ronaldo</kw> <kw>tribute</kw> <kw>sporting</kw>, <kw>manchester</kw> <kw>united</kw>, <kw>real</kw> <kw>madrid</kw> & <kw>portugal</kw> // <kw>url</kw>: cr7.no.sapo.pt <kw>início</kw> <kw>home</kw> <kw>perfil</kw> Profile Prémios Awards Títulos Titles Carreira <kw>career</kw> Desktop <kw>downloads</kw> Multimédia Multimedia Ligações Links Mensagens Messages Carreira | <kw>career</kw> ... ',
#  48: '\ufeff <kw>cristiano</kw> <kw>ronaldo</kw> - CR7 - <kw>real</kw> <kw>madrid</kw> & <kw>portugal</kw> | <d>2016</d> <kw>live</kw> <kw>score</kw> :: About us :: <kw>contact</kw> <kw>full</kw> ...  Trending <kw>live</kw> <kw>cristiano</kw> <kw>ronaldo</kw> - CR7 <kw>fan</kw> <kw>site</kw> <kw>tweet</kw> Section: <kw>news</kw> » [ <kw>january</kw> 31, <d>2016</d> ] <kw>real</kw> <kw>madrid</kw> 6-0 ...  West Ham Ronaldo7.net Sitemap / Privacy <kw>skip</kw>  <kw>full</kw> name: <kw>cristiano</kw> <kw>ronaldo</kw> dos <kw>santos</kw> <kw>aveiro</kw> Birth ... ',
#  49: '<kw>cristiano</kw> <kw>ronaldo</kw> <kw>cristiano</kw> <kw>ronaldo</kw> <kw>blog</kw> <kw>dedicado</kw> ao <kw>melhor</kw> <kw>jogador</kw> <kw>português</kw> do momento.Muitas <kw>fotos</kw>, <kw>vídeos</kw>, <kw>entrevistas</kw> de <kw>cristiano</kw> <kw>ronaldo</kw>. Os golos de <kw>cristiano</kw> <kw>ronaldo</kw>, as namoradas de <kw>cristiano</kw> <kw>ronaldo</kw>, a família de <kw>cristiano</kw> <kw>ronaldo</kw> ... enfim tudo sobre <kw>cristiano</kw> <kw>ronaldo</kw> <kw>quinta-feira</kw>, 11 ... '}

# %% [markdown]
# ### Text Tokens

# %% [markdown]
# - <b>TextTokens</b>: A dictionary where the key is the docID and the value is a list of the text tokens. Tokens that are temporal expressions are marked with the tag `<d>`, whereas relevant keywords are marked with the tag `<kw>`. Example: `{0: ['As', 'of', '<d>2010</d>', 'see', '1500',...]}`.

# %%
TextTokens = results[4]
TextTokens
# Out:
# {0: ['PUBLICO',
#   'PT',
#   'S',
#   'bado',
#   '22',
#   'de',
#   'Mar',
#   'o',
#   'de',
#   '<d>2003</d>',
#   '18',
#   '56',
#   'p',
#   'blico',
#   '<kw>pdf</kw>',
#   'alertas',
#   'pesquisas',
#   '<kw>newsletters</kw>',
#   'edi',
#   'o',
#   '<kw>impressa</kw>',
#   'ltima',
#   'hora',
#   'dossiers',
#   'guia',
#   'do',
#   'lazer',
#   'cinecartaz',
#   'tvzine',
#   'ABCed',
#   'rio',
#   '<kw>dvd</kw>',
#   's',
#   'rie',
#   'Y',
#   'mil',
#   '<kw>folhas</kw>',
#   '2',
#   'emprego',
#   'tempo',
#   'LOGIN',
#   'Nome',
#   'de',
#   'utilizador',
#   'Palavra',
#   'chave',
#   'REGISTO',
#   'EDI',
#   'O',
#   '<kw>impressa</kw>',
#   'Sec',
#   'es',
#   '1',
#   'P',
#   'gina',
#   'Destaque',
#   'Nacional',
#   'Mundo',
#   'Espa',
#   'o',
#   'P',
#   'blico',
#   'Sociedade',
#   'Educa',
#   'o',
#   'Ci',
#   'ncias',
#   'Cultura',
#   'Desporto',
#   'Economia',
#   'Media',
#   'Local',
#   'Porto',
#   'ltima',
#   'P',
#   'gina',
#   'Suplementos',
#   'Computadores',
#   'Economia',
#   'Y',
#   'Mil',
#   '<kw>folhas</kw>',
#   'Fugas',
#   'ESPECIAL',
#   '<kw>iraque</kw>',
#   'ltimos',
#   '<d>P7D</d>',
#   'S',
#   'bado',
#   '<d>2013</d>',
#   '<d>2013</d>',
#   '<d>2013</d>',
#   'Ter',
#   'a',
#   '<d>2013</d>',
#   '<d>2013</d>',
#   'P',
#   'BLICO',
#   'em',
#   'HTML',
#   'e',
#   '<kw>pdf</kw>',
#   'CANAIS',
#   'Edi',
#   'o',
#   '<kw>impressa</kw>',
#   'ltima',
#   'Hora',
#   'ltima',
#   'Hora',
#   'UL',
#   'Mil',
#   '<kw>folhas</kw>',
#   '2',
#   'Desporto',
#   '<kw>dvd</kw>',
#   'S',
#   'rie',
#   'Y',
#   'ABCed',
#   'rio',
#   'Guia',
#   'do',
#   'Lazer',
#   'Cinecartaz',
#   'TVzine',
#   'R',
#   'dio',
#   'Emprego',
#   'Imobili',
#   'rio',
#   'Dossiers',
#   'Ecosfera',
#   'Banda',
#   'Desenhada',
#   'Calvin',
#   'Bartoon',
#   'P',
#   'BLICO',
#   'PLUS',
#   'Registo',
#   'P',
#   'blico',
#   'em',
#   '<kw>pdf</kw>',
#   '<kw>newsletters</kw>',
#   '<kw>pesquisa</kw>',
#   'CANAIS',
#   'INTERACTIVOS',
#   'Inqu',
#   'ritos',
#   'Tr',
#   'nsito',
#   'Ebook',
#   'Hor',
#   'scopos',
#   'F',
#   'runs',
#   'SERVI',
#   'OS',
#   'Meteorologia',
#   'Lotarias',
#   'Di',
#   'rio',
#   'da',
#   'Rep',
#   'blica',
#   'Motores',
#   'de',
#   '<kw>pesquisa</kw>',
#   'PROJECTOS',
#   'P',
#   'BLICO',
#   'Simweb',
#   'Painel',
#   'P',
#   'blico',
#   'IDC',
#   'Trof',
#   'u',
#   'P',
#   'blico',
#   'P',
#   'blico',
#   'na',
#   'Escola',
#   'P',
#   'blico',
#   'Gradiva',
#   '3',
#   'Edi',
#   'o',
#   'Fuga',
#   '<d>2013</d>',
#   'Guias',
#   'de',
#   'Cidades',
#   'Passatempo',
#   '<kw>dvd</kw>',
#   'Serie',
#   'Y',
#   'N',
#   's',
#   'Ficha',
#   'T',
#   'cnica',
#   'Mapa',
#   'do',
#   'Site',
#   'Livro',
#   'de',
#   'Estilo',
#   'Provedor',
#   'do',
#   'Leitor',
#   'Assinaturas',
#   'Publicidade',
#   'GALERIA',
#   'Arte',
#   'Viagens',
#   'Leil',
#   'es',
#   'NOT',
#   'CIAS',
#   'Pol',
#   'cia',
#   'avan',
#   'a',
#   '35',
#   'mil',
#   'organiza',
#   'o',
#   'fala',
#   'em',
#   '90',
#   'mil',
#   'Manifesta',
#   'o',
#   'em',
#   '<kw>lisboa</kw>',
#   're',
#   'ne',
#   'dezenas',
#   'de',
#   'milhares',
#   'de',
#   'pessoas',
#   'A',
#   'manifesta',
#   'o',
#   'em',
#   '<kw>lisboa</kw>',
#   'contra',
#   'a',
#   'guerra',
#   'no',
#   '<kw>iraque</kw>',
#   'que',
#   'se',
#   'iniciou',
#   's',
#   '15h45',
#   'no',
#   'Marqu',
#   's',
#   'de',
#   'Pombal',
#   'levou',
#   'entre',
#   '35',
#   'e',
#   '90',
#   'mil',
#   'pessoas',
#   'segundo',
#   'os',
#   'n',
#   'meros',
#   'da',
#   'pol',
#   'cia',
#   'e',
#   'da',
#   'organiza',
#   'o',
#   'a',
#   'descerem',
#   'a',
#   'Avenida',
#   'da',
#   'Liberdade',
#   'at',
#   'ao',
#   'Rossio',
#   'Forte',
#   'explos',
#   'o',
#   'em',
#   'Bagdad',
#   'Uma',
#   'forte',
#   'explos',
#   'o',
#   'foi',
#   'registada',
#   'ao',
#   'in',
#   'cio',
#   'da',
#   'noite',
#   'na',
#   'parte',
#   'Oeste',
#   'de',
#   'Bagdad',
#   'O',
#   'rebentamento',
#   'ouvido',
#   's',
#   '19h21',
#   'locais',
#   '14h21',
#   'em',
#   '<kw>lisboa</kw>',
#   'provocou',
#   'uma',
#   'enorme',
#   'coluna',
#   'de',
#   'fumo',
#   'vis',
#   'vel',
#   'a',
#   'v',
#   'rios',
#   'quil',
#   'metros',
#   'ATAQUE',
#   'AO',
#   '<kw>iraque</kw>',
#   'Video',
#   'Fotos',
#   'INFOGRAFIA',
#   'ltimas',
#   'not',
#   'cias',
#   'Dossier',
#   '<kw>iraque</kw>',
#   '<kw>iraque</kw>',
#   'p',
#   's',
#   'Saddam',
#   'Armas',
#   'Aliadas',
#   'Armas',
#   'iraquianas',
#   'Ataque',
#   'ao',
#   '<kw>iraque</kw>',
#   'S',
#   'ria',
#   'denuncia',
#   'agress',
#   'o',
#   'b',
#   'rbara',
#   'e',
#   'apela',
#   'ao',
#   'fim',
#   'da',
#   'guerra',
#   'Tentando',
#   'travar',
#   'vaga',
#   'de',
#   'refugiados',
#   'Tropas',
#   'turcas',
#   'v',
#   'o',
#   'entrar',
#   'no',
#   '<kw>iraque</kw>',
#   'para',
#   'prevenir',
#   'actividades',
#   'terroristas',
#   'For',
#   'as',
#   'iraquianas',
#   'ter',
#   'o',
#   'incendiado',
#   'petr',
#   'leo',
#   'em',
#   'torno',
#   'da',
#   'capital',
#   'Bagdad',
#   'rodeada',
#   'de',
#   'trincheiras',
#   'em',
#   'chamas',
#   'GUIA',
#   'DO',
#   'LAZER',
#   'M',
#   'sica',
#   'Cid',
#   'Campos',
#   'Teatro',
#   'Jimmy',
#   'Cr',
#   'ture',
#   'de',
#   'R',
#   've',
#   'Dan',
#   'a',
#   'Ballet',
#   'Gulbenkian',
#   'CINECARTAZ',
#   'Estreia',
#   'da',
#   'Semana',
#   'Longe',
#   'do',
#   'Para',
#   'so',
#   'Recomendamos',
#   'As',
#   'Confiss',
#   'es',
#   'de',
#   'Schmidt',
#   'Ciclo',
#   'Transforma',
#   'es',
#   'Muta',
#   'es',
#   'DOSSIERS',
#   'Come',
#   'ou',
#   'a',
#   'guerra',
#   '<kw>iraque</kw>',
#   'debaixo',
#   'de',
#   'fogo',
#   'scares',
#   '<d>2003</d>',
#   'Pr',
#   'mios',
#   'da',
#   'Academia',
#   's',
#   'o',
#   'entregues',
#   'a',
#   '23',
#   'de',
#   'Mar',
#   'o',
#   'Doping',
#   'no',
#   'desporto',
#   '<kw>portugal</kw>',
#   'quer',
#   'liderar',
#   'aplica',
#   'o',
#   'do',
#   'c',
#   'digo',
#   'mundial',
#   'O',
#   'ltimo',
#   'voo',
#   'do',
#   'Columbia',
#   'NASA',
#   'procura',
#   'explica',
#   'es',
#   'para',
#   'o',
#   'acidente',
#   'Excis',
#   'o',
#   'feminina',
#   'O',
#   'holocausto',
#   'silencioso',
#   'das',
#   'mulheres',
#   'a',
#   'quem',
#   'continuam',
#   'a',
#   'extrair',
#   'o',
#   'cl',
#   'toris',
#   'Pedofilia',
#   'As',
#   'deten',
#   'es',
#   'que',
#   'abalaram',
#   '<kw>portugal</kw>',
#   'Caso',
#   'Felgueiras',
#   'Minist',
#   'rio',
#   'P',
#   'blico',
#   'atribui',
#   'a',
#   'F',
#   'tima',
#   'Felgueiras',
#   'a',
#   'pr',
#   'tica',
#   'de',
#   'dezenas',
#   'de',
#   'crimes',
#   'Moderna',
#   'o',
#   'caso',
#   'As',
#   'rela',
#   'es',
#   'jogos',
#   'e',
#   'lutas',
#   'de',
#   'poder',
#   'P',
#   'blico500',
#   'As',
#   'maiores',
#   'empresas',
#   'n',
#   'o',
#   'financeiras',
#   'de',
#   '<kw>portugal</kw>',
#   'LTIMAS',
#   'Internacional',
#   'Marines',
#   'americanos',
#   'vencem',
#   'batalha',
#   'a',
#   'Oeste',
#   'de',
#   'Bassor',
#   'Internacional',
#   'EUA',
#   'v',
#   'o',
#   'investigar',
#   'queda',
#   'de',
#   'm',
#   'ssil',
#   'no',
#   'Ir',
#   'o',
#   'Desporto',
#   'C',
#   'sar',
#   'Peixoto',
#   'e',
#   'Pedro',
#   'Emanuel',
#   'viajam',
#   'para',
#   'a',
#   'Madeira',
#   'Internacional',
#   'Brit',
#   'nicos',
#   'manifestam',
#   'se',
#   'contra',
#   'a',
#   'guerra',
#   'Internacional',
#   'Manifesta',
#   'o',
#   'em',
#   '<kw>lisboa</kw>',
#   're',
#   'ne',
#   'dezenas',
#   'de',
#   'milhares',
#   'de',
#   'pessoas',
#   '10',
#   'LTIMAS',
#   '10',
#   'LTIMAS',
#   'DESPORTO',
#   'O',
#   'TEMPO',
#   's',
#   '17h00',
#   '<kw>lisboa</kw>',
#   'Muito',
#   'nublado',
#   '18',
#   'C',
#   'Porto',
#   'Muito',
#   'nublado',
#   '16',
#   'C',
#   'Faro',
#   'Pouco',
#   'nublado',
#   '18',
#   'C',
#   'Funchal',
#   'Pouco',
#   'nublado',
#   '18',
#   'C',
#   'Ponta',
#   'Delgada',
#   '14',
#   'C',
#   'INQU',
#   'RITOS',
#   'O',
#   'que',
#   'vai',
#   'acontecer',
#   'a',
#   'Saddam',
#   'Hussein',
#   '1',
#   'Ser',
#   'capturado',
#   'pelos',
#   'EUA',
#   '2',
#   'Vai',
#   'fugir',
#   '3',
#   'Vai',
#   'morrer',
#   'em',
#   'combate',
#   '4',
#   'Vai',
#   'vencer',
#   'a',
#   'guerra',
#   'Sorry',
#   'your',
#   'browser',
#   'does',
#   'not',
#   'support',
#   'the',
#   'iframe',
#   'tag'],
#  1: ['JN',
#   '<kw>editorial</kw>',
#   'out1061',
#   '<kw>assad</kw>',
#   '<kw>faleceu</kw>',
#   'deixando',
#   'a',
#   'S',
#   'ria',
#   'entregue',
#   'ao',
#   'filho',
#   'O',
#   '<kw>presidente</kw>',
#   'da',
#   'S',
#   'ria',
#   'Hafez',
#   '<kw>al-assad</kw>',
#   '<kw>faleceu</kw>',
#   '<d>2013</d>',
#   'pelas',
#   '<d>PT11H</d>',
#   'vitimado',
#   'por',
#   'um',
#   'ataque',
#   'do',
#   'cora',
#   'o',
#   'As',
#   'reac',
#   'es',
#   'de',
#   'consterna',
#   'o',
#   'n',
#   'o',
#   'se',
#   'fizeram',
#   'esperar',
#   'no',
#   'mundo',
#   'rabe',
#   'embora',
#   'Israel',
#   'e',
#   'muitos',
#   'estados',
#   'do',
#   'Ocidente',
#   'tenham',
#   'igualmente',
#   'proferido',
#   '<kw>palavras</kw>',
#   'de',
#   'profundo',
#   'pesar',
#   'pela',
#   '<kw>morte</kw>',
#   'de',
#   'um',
#   '<kw>presidente</kw>',
#   'quase',
#   'esf',
#   'ngico',
#   'no',
#   'problem',
#   'tico',
#   'cen',
#   'rio',
#   'de',
#   'guerra',
#   'e',
#   'paz',
#   'que',
#   'caracteriza',
#   'o',
#   'M',
#   'dio',
#   'Oriente',
#   'O',
#   'funeral',
#   'de',
#   '<kw>estado</kw>',
#   'realiza',
#   'se',
#   'somente',
#   'depois',
#   'de',
#   'amanh',
#   '<kw>assad</kw>',
#   'j',
#   'sofria',
#   'h',
#   'algum',
#   'tempo',
#   'de',
#   'problemas',
#   'do',
#   'cora',
#   'o',
#   'e',
#   'de',
#   'diabetes',
#   'Os',
#   'rumores',
#   'da',
#   'sua',
#   '<kw>morte</kw>',
#   'iminente',
#   'j',
#   'circulavam',
#   'h',
#   '<d>PXY</d>',
#   'mas',
#   'o',
#   '<kw>presidente</kw>',
#   'liban',
#   's',
#   'Emile',
#   'Lahoud',
#   'disse',
#   'que',
#   'tinha',
#   'falado',
#   'sem',
#   'dificuldade',
#   'com',
#   '<kw>assad</kw>',
#   'na',
#   'madrugada',
#   'de',
#   '<d>2013</d>',
#   'As',
#   'suas',
#   'ltimas',
#   '<kw>palavras</kw>',
#   'foram',
#   'O',
#   'nosso',
#   'destino',
#   'construir',
#   '<d>FUTURE_REF</d>',
#   'melhor',
#   'para',
#   'os',
#   'nossos',
#   'pa',
#   'ses',
#   'Seguiu',
#   'se',
#   'um',
#   'sil',
#   'ncio',
#   'e',
#   'senti',
#   'que',
#   'algo',
#   'tinha',
#   'acontecido',
#   'disse',
#   'Lahoud',
#   'numa',
#   'carta',
#   'enviada',
#   'ao',
#   'filho',
#   'de',
#   '<kw>assad</kw>',
#   'e',
#   'seu',
#   'sucessor',
#   'Bashar',
#   '<kw>al-assad</kw>',
#   'que',
#   'ali',
#   's',
#   'a',
#   'leu',
#   'perante',
#   'as',
#   'c',
#   'maras',
#   'de',
#   'TV',
#   'Pouco',
#   'ap',
#   's',
#   'o',
#   'an',
#   'ncio',
#   'da',
#   'trag',
#   'dia',
#   'o',
#   'Parlamento',
#   's',
#   'rio',
#   'reuniu',
#   'e',
#   'entre',
#   'l',
#   'grimas',
#   'derramadas',
#   'pelos',
#   'deputados',
#   'a',
#   'Constitui',
#   'o',
#   'foi',
#   'emendada',
#   'num',
#   'artigo',
#   'que',
#   'determinava',
#   'os',
#   '40',
#   '<d>PXY</d>',
#   'como',
#   'idade',
#   'm',
#   'nima',
#   'para',
#   'assumir',
#   'a',
#   'chefia',
#   'do',
#   '<kw>estado</kw>',
#   'Sendo',
#   'assim',
#   'os',
#   '34',
#   '<d>PXY</d>',
#   'de',
#   'Bashar',
#   'deixaram',
#   'de',
#   'ser',
#   'um',
#   'impedimento',
#   'para',
#   'a',
#   'sucess',
#   'o',
#   'imediata',
#   'do',
#   'seu',
#   'pai',
#   'Salim',
#   'Hosse',
#   'primeiro',
#   'ministro',
#   'liban',
#   's',
#   'pa',
#   's',
#   'que',
#   'decretou',
#   '<d>P7D</d>',
#   'de',
#   'luto',
#   'considerou',
#   'que',
#   'a',
#   '<kw>morte</kw>',
#   'de',
#   'Hafez',
#   '<kw>al-assad</kw>',
#   'constitui',
#   'uma',
#   'terr',
#   'vel',
#   'cat',
#   'strofe',
#   'para',
#   'o',
#   'L',
#   'bano',
#   'De',
#   'Israel',
#   'al',
#   'm',
#   'das',
#   '<kw>palavras</kw>',
#   'de',
#   'pesar',
#   'veio',
#   'a',
#   'garantia',
#   'de',
#   'que',
#   'o',
#   'pa',
#   's',
#   'vai',
#   'continuar',
#   'a',
#   'trabalhar',
#   'em',
#   'prol',
#   'da',
#   'paz',
#   'no',
#   'M',
#   'dio',
#   'Oriente',
#   'O',
#   '<kw>presidente</kw>',
#   'da',
#   'Autoridade',
#   'Palestiniana',
#   'Yasser',
#   'Arafat',
#   'apresentou',
#   'as',
#   'condol',
#   'ncias',
#   'ao',
#   'povo',
#   's',
#   'rio',
#   'e',
#   'decretou',
#   'tr',
#   's',
#   'dias',
#   'de',
#   'luto',
#   'nacional',
#   'nos',
#   'territ',
#   'rios',
#   'palestinianos',
#   'O',
#   '<kw>presidente</kw>',
#   'norte',
#   'americano',
#   'Bill',
#   'Clinton',
#   'manifestou',
#   'se',
#   'entristecido',
#   'com',
#   'a',
#   'not',
#   'cia',
#   'e',
#   'em',
#   'Moscovo',
#   'as',
#   'autoridades',
#   'russas',
#   'consideraram',
#   'no',
#   'como',
#   'um',
#   'grande',
#   'estadista',
#   'e',
#   'amigo',
#   'da',
#   'R',
#   'ssia',
#   'De',
#   'Bagdade',
#   'veio',
#   'a',
#   'frieza',
#   'com',
#   'a',
#   'r',
#   'dio',
#   'iraquiana',
#   'a',
#   'anunciar',
#   'sem',
#   'quaisquer',
#   'coment',
#   'rios',
#   'a',
#   '<kw>morte</kw>',
#   'de',
#   '<kw>assad</kw>',
#   'As',
#   'rela',
#   'es',
#   'entre',
#   'o',
#   '<kw>iraque</kw>',
#   'e',
#   'a',
#   'S',
#   'ria',
#   'pa',
#   'ses',
#   'governados',
#   'por',
#   'alas',
#   'rivais',
#   'do',
#   'partido',
#   'Baas',
#   'foram',
#   'rompidas',
#   'em',
#   '<d>1980</d>',
#   'na',
#   'sequ',
#   'ncia',
#   'da',
#   'guerra',
#   'entre',
#   'Bagdade',
#   'e',
#   'Teer',
#   'o',
#   '<d>1980</d>',
#   '88',
#   'Copyright',
#   '<d>2000</d>',
#   'Empresa',
#   'do',
#   'Jornal',
#   'de',
#   'Not',
#   'cias',
#   'S',
#   'A',
#   'Reservados',
#   'todos',
#   'os',
#   'Direitos'],
#  2: ['JN',
#   '<kw>editorial</kw>',
#   'out2062',
#   '<kw>marchar</kw>',
#   'contra',
#   'os',
#   'sionistas',
#   'em',
#   'nome',
#   'de',
#   'Al',
#   'O',
#   'sequestro',
#   'de',
#   'tr',
#   's',
#   'soldados',
#   'israelitas',
#   'a',
#   'ltima',
#   'ac',
#   'o',
#   'de',
#   'envergadura',
#   'do',
#   'grupo',
#   '<kw>xiita</kw>',
#   '<kw>hezbollah</kw>',
#   'que',
#   'desde',
#   'a',
#   'sua',
#   'cria',
#   'o',
#   'h',
#   '<d>P18Y</d>',
#   'luta',
#   'contra',
#   'o',
#   'sionismo',
#   'com',
#   'o',
#   'apoio',
#   'do',
#   'Ir',
#   'o',
#   'e',
#   'da',
#   'S',
#   'ria',
#   'O',
#   'grupo',
#   'radical',
#   '<kw>xiita</kw>',
#   'foi',
#   'fundado',
#   'no',
#   'L',
#   'bano',
#   'em',
#   '<d>1982</d>',
#   'durante',
#   'a',
#   'guerra',
#   'civil',
#   'neste',
#   'pa',
#   's',
#   'com',
#   'o',
#   'objectivo',
#   'de',
#   'criar',
#   'uma',
#   'rep',
#   'blica',
#   'isl',
#   'mica',
#   'apesar',
#   'de',
#   'a',
#   'sua',
#   'ideologia',
#   'se',
#   'resumir',
#   'a',
#   'um',
#   'forte',
#   'sentimento',
#   'anti',
#   'israelita',
#   'e',
#   'anti',
#   'ocidental',
#   'Aliado',
#   'do',
#   'Ir',
#   'o',
#   'que',
#   'lhe',
#   'fornece',
#   'apoio',
#   'econ',
#   'mico',
#   'e',
#   'pol',
#   'tico',
#   'o',
#   '<kw>hezbollah</kw>',
#   'preconiza',
#   'a',
#   'cria',
#   'o',
#   'de',
#   'uma',
#   'rep',
#   'blica',
#   'de',
#   'cariz',
#   'isl',
#   'mico',
#   'pr',
#   'iraniano',
#   'e',
#   'a',
#   'elimina',
#   'o',
#   'de',
#   'qualquer',
#   'tipo',
#   'de',
#   'presen',
#   'a',
#   'n',
#   'o',
#   'mu',
#   'ulmana',
#   'no',
#   'L',
#   'bano',
#   'Tem',
#   'o',
#   'seu',
#   'centro',
#   'de',
#   'opera',
#   'es',
#   'no',
#   'L',
#   'bano',
#   'e',
#   'comandos',
#   'permanentes',
#   'na',
#   'Europa',
#   'frica',
#   'Am',
#   'rica',
#   'do',
#   'Sul',
#   'e',
#   'Estados',
#   'Unidos',
#   'O',
#   'seu',
#   'atentado',
#   'mais',
#   'brutal',
#   'custou',
#   'a',
#   'vida',
#   'a',
#   '241',
#   'marines',
#   'norte',
#   'americanos',
#   'e',
#   '58',
#   'p',
#   'ra',
#   'quedistas',
#   'franceses',
#   'em',
#   'Beirute',
#   'no',
#   '<d>1983</d>',
#   'Em',
#   '<d>2013</d>',
#   'deste',
#   'ano',
#   'o',
#   '<kw>hezbollah</kw>',
#   'estabeleceu',
#   'uma',
#   'alian',
#   'a',
#   'inspirada',
#   'pelo',
#   'Ir',
#   'o',
#   'com',
#   'o',
#   '<kw>movimento</kw>',
#   'da',
#   'Resist',
#   'ncia',
#   'Isl',
#   'mica',
#   'Hamas',
#   'e',
#   'a',
#   'Jihad',
#   'Isl',
#   'mica',
#   'O',
#   '<kw>movimento</kw>',
#   'tem',
#   'cerca',
#   'de',
#   '800',
#   'combatentes',
#   'bem',
#   'treinados',
#   'e',
#   'possui',
#   'armamento',
#   'moderno',
#   'O',
#   '<kw>hezbollah</kw>',
#   'algo',
#   'mais',
#   'que',
#   'um',
#   '<kw>movimento</kw>',
#   'guerrilheiro',
#   'que',
#   'aspira',
#   'a',
#   'destruir',
#   'o',
#   '<kw>estado</kw>',
#   'judeu',
#   'Trata',
#   'se',
#   'de',
#   'um',
#   'partido',
#   'pol',
#   'tico',
#   'que',
#   'tem',
#   'sete',
#   'deputados',
#   'no',
#   'Parlamento',
#   'de',
#   'Beirute',
#   'Copyright',
#   '<d>2000</d>',
#   'Empresa',
#   'do',
#   'Jornal',
#   'de',
#   'Not',
#   'cias',
#   'S',
#   'A',
#   'Reservados',
#   'todos',
#   'os',
#   'Direitos'],
#  3: ['Jornal',
#   'de',
#   'Noticias',
#   'Edi',
#   'o',
#   'de',
#   '<d>2001</d>',
#   'ltima',
#   'actualiza',
#   'o',
#   '0',
#   '23',
#   '<kw>portugal</kw>',
#   'ltimas',
#   '7',
#   'edi',
#   'es',
#   'Arquivo',
#   'F',
#   'runs',
#   'Sec',
#   'es',
#   'do',
#   'leitor',
#   'Dossiers',
#   'Sec',
#   'es',
#   'semanais',
#   'Iniciativas',
#   '<kw>classificados</kw>',
#   'ltimas',
#   'not',
#   'cias',
#   'em',
#   'foco',
#   'grande',
#   'plano',
#   'tema',
#   'de',
#   'semana',
#   '<kw>portugal</kw>',
#   'doce',
#   'grande',
#   'porto',
#   'grande',
#   '<kw>lisboa</kw>',
#   'pol',
#   'tica',
#   'opini',
#   'o',
#   'sociedade',
#   'economia',
#   'mundo',
#   'pa',
#   's',
#   'cultura',
#   'palco',
#   'desporto',
#   'ltima',
#   'ficha',
#   't',
#   'cnica',
#   'fale',
#   'connosco',
#   'Outras',
#   '<kw>paginas</kw>',
#   '<d>2001</d>',
#   'Barriga',
#   'nariz',
#   'e',
#   'sexo',
#   'estorvam',
#   '<kw>portugueses</kw>',
#   'Estudo',
#   'in',
#   'dito',
#   'em',
#   '<kw>portugal</kw>',
#   'revela',
#   'os',
#   'grandes',
#   'dramas',
#   'dos',
#   'homens',
#   'DOMINGOS',
#   'DE',
#   'ANDRADE',
#   'Um',
#   'andrologista',
#   'fez',
#   'medi',
#   'es',
#   'e',
#   'descobriu',
#   'o',
#   'cabo',
#   'dos',
#   'trabalhos',
#   'da',
#   'generalidade',
#   'dos',
#   'homens',
#   '<kw>portugueses</kw>',
#   'Que',
#   'queimam',
#   'os',
#   'neur',
#   'nios',
#   'a',
#   'tentar',
#   'esconder',
#   'a',
#   'barriga',
#   'a',
#   'disfar',
#   'ar',
#   'o',
#   'nariz',
#   'ou',
#   'a',
#   'enclausurar',
#   'o',
#   'p',
#   'nis',
#   'Quest',
#   'o',
#   'de',
#   'ra',
#   'a',
#   '<kw>portugueses</kw>',
#   's',
#   'o',
#   'mais',
#   'bem',
#   'dotados',
#   'do',
#   'que',
#   'americanos',
#   'brasileiros',
#   'e',
#   'espanh',
#   'is',
#   'DOMINGOS',
#   'DE',
#   'ANDRADE',
#   'Nuno',
#   'Monteiro',
#   'Pereira',
#   'meteu',
#   'm',
#   'os',
#   'obra',
#   'quando',
#   'reparou',
#   'que',
#   'at',
#   '<d>2013</d>',
#   'em',
#   '<kw>portugal</kw>',
#   'nunca',
#   'se',
#   'fez',
#   'a',
#   'defini',
#   'o',
#   'de',
#   'uma',
#   'norma',
#   'morfom',
#   'trica',
#   'peniana',
#   'Ora',
#   'o',
#   'conhecimento',
#   'desses',
#   'valores',
#   'porque',
#   'de',
#   'tamanhos',
#   'que',
#   'se',
#   'trata',
#   'importante',
#   'para',
#   'a',
#   'avalia',
#   'o',
#   'objectiva',
#   'das',
#   'queixas',
#   'dismorf',
#   'bicas',
#   'dos',
#   'doentes',
#   'e',
#   'das',
#   'indica',
#   'es',
#   'para',
#   'eventuais',
#   't',
#   'cnicas',
#   'de',
#   'correc',
#   'o',
#   'cosm',
#   'tica',
#   'do',
#   'tamanho',
#   'do',
#   'p',
#   'nis',
#   'nomeadamente',
#   'as',
#   'cirurgias',
#   'Representa',
#   'es',
#   'hist',
#   'ricas',
#   'Se',
#   '<d>2013</d>',
#   'muita',
#   'gente',
#   'considera',
#   'indecente',
#   'e',
#   'obsceno',
#   'o',
#   'acto',
#   'de',
#   'mostrar',
#   'um',
#   'falo',
#   'noutros',
#   'tempos',
#   'isso',
#   'era',
#   'sagrado',
#   'Para',
#   'os',
#   'gregos',
#   'o',
#   'falo',
#   'representava',
#   'a',
#   'for',
#   'a',
#   'da',
#   'Primavera',
#   'e',
#   'a',
#   'fecundidade',
#   'da',
#   'terra',
#   'que',
#   'protegia',
#   'a',
#   'vida',
#   'contra',
#   'as',
#   'for',
#   'as',
#   'malignas',
#   'que',
#   'pudessem',
#   'amea',
#   'la',
#   'pelo',
#   'que',
#   'era',
#   'considerado',
#   'um',
#   'objecto',
#   'de',
#   'culto',
#   'm',
#   'stico',
#   'e',
#   'at',
#   'religioso',
#   'Esse',
#   's',
#   'mbolo',
#   'da',
#   'masculinidade',
#   'estendeu',
#   'se',
#   'por',
#   'todo',
#   'o',
#   'Planeta',
#   'Vigorou',
#   'no',
#   'Egipto',
#   'na',
#   'P',
#   'rsia',
#   'na',
#   'S',
#   'ria',
#   'na',
#   'ndia',
#   'em',
#   'frica',
#   'nas',
#   'am',
#   'ricas',
#   'Tamanho',
#   'para',
#   'agradar',
#   's',
#   'mulheres',
#   'Nuno',
#   'Monteiro',
#   'Pereira',
#   'considera',
#   'serem',
#   'sete',
#   'as',
#   'raz',
#   'es',
#   'espec',
#   'ficas',
#   'para',
#   'um',
#   'homem',
#   'querer',
#   'aumentar',
#   'a',
#   'dimens',
#   'o',
#   'do',
#   'seu',
#   'rg',
#   'o',
#   'sexual',
#   'A',
#   'primeira',
#   'e',
#   'fundamental',
#   'por',
#   'possu',
#   'rem',
#   'um',
#   'micro',
#   'p',
#   'nis',
#   'ou',
#   'um',
#   'p',
#   'nis',
#   'pequeno',
#   'gerador',
#   'de',
#   'insatisfa',
#   'o',
#   'e',
#   'baixa',
#   'auto',
#   'estima',
#   'acompanhado',
#   'ou',
#   'n',
#   'o',
#   'de',
#   'dificuldade',
#   'em',
#   'estabelecer',
#   'e',
#   'manter',
#   'um',
#   'relacionamento',
#   'sentimental',
#   'amoroso',
#   'Art',
#   'fices',
#   'da',
#   'paz',
#   'aliviam',
#   'a',
#   'Justi',
#   'a',
#   'Mediadores',
#   'ajudam',
#   'cidad',
#   'os',
#   'a',
#   'resolver',
#   'conflitos',
#   'PEDRO',
#   'OLAVO',
#   'SIM',
#   'ES',
#   'A',
#   'voz',
#   'sobe',
#   'de',
#   'tom',
#   'O',
#   'sr',
#   'Xavier',
#   'agrediu',
#   'verbalmente',
#   'a',
#   'minha',
#   'mulher',
#   'Insultou',
#   'a',
#   'do',
#   'piorio',
#   'Coisa',
#   'corrente',
#   'neste',
#   '<kw>portugal</kw>',
#   'de',
#   'l',
#   'ngua',
#   'desenfreada',
#   'mas',
#   'bizarra',
#   'para',
#   'o',
#   'observador',
#   'O',
#   'sr',
#   'Xavier',
#   'em',
#   'causa',
#   'uma',
#   'mulher',
#   'nada',
#   'ali',
#   'engana',
#   'tal',
#   'como',
#   'o',
#   'sr',
#   'Daniel',
#   'cuja',
#   'esposa',
#   'teve',
#   'a',
#   'dignidade',
#   'enxovalhada',
#   'S',
#   'o',
#   'mediadoras',
#   'que',
#   'ser',
#   'o',
#   'colocadas',
#   'nos',
#   'futuros',
#   'julgados',
#   'de',
#   'paz',
#   'em',
#   'plena',
#   'ac',
#   'o',
#   'formativa',
#   'ensaiando',
#   'com',
#   'o',
#   'poss',
#   'vel',
#   'rigor',
#   'dram',
#   'tico',
#   'aquilo',
#   'que',
#   'as',
#   'espera',
#   'quando',
#   'forem',
#   'para',
#   'o',
#   'terreno',
#   'promover',
#   'justos',
#   'acordos',
#   'sem',
#   'recurso',
#   'pesadaJusti',
#   'a',
#   'No',
#   'es',
#   'Julgado',
#   'de',
#   'paz',
#   'Meio',
#   'de',
#   'resolu',
#   'o',
#   'alternativa',
#   'de',
#   'lit',
#   'gios',
#   'destinado',
#   'a',
#   'resolver',
#   'causas',
#   'c',
#   'veis',
#   'de',
#   'menor',
#   'complexidade',
#   'com',
#   'rapidez',
#   'simplicidade',
#   'e',
#   'baixos',
#   'custos',
#   'Antes',
#   'de',
#   'o',
#   'juiz',
#   'decidir',
#   'dada',
#   's',
#   'partes',
#   'oportunidade',
#   'para',
#   'que',
#   'se',
#   'entendam',
#   'de',
#   'forma',
#   'amig',
#   'vel',
#   'e',
#   'concertada',
#   'Advogados',
#   'aderem',
#   'ao',
#   'desafio',
#   'de',
#   'poder',
#   'mudar',
#   'alguma',
#   'coisa',
#   'Lu',
#   's',
#   'Filipe',
#   'Guerra',
#   'advogado',
#   'h',
#   '<d>P9Y</d>',
#   'Ofereceu',
#   'se',
#   'para',
#   'ser',
#   'mediador',
#   'para',
#   'introduzir',
#   'variedade',
#   'na',
#   'actividade',
#   'profissional',
#   'mas',
#   'tamb',
#   'm',
#   'por',
#   'ades',
#   'o',
#   'filosofia',
#   'inerente',
#   'media',
#   'o',
#   'de',
#   'conflitos',
#   'Sabe',
#   'que',
#   'o',
#   'esperam',
#   'porventura',
#   'casos',
#   'dif',
#   'ceis',
#   'envolvendo',
#   'gente',
#   'mais',
#   'quezilenta',
#   'ou',
#   'at',
#   'violenta',
#   'mas',
#   'isso',
#   'n',
#   'o',
#   'o',
#   'preocupa',
#   'minimamente',
#   'Gosto',
#   'do',
#   'contacto',
#   'com',
#   'as',
#   'pessoas',
#   'e',
#   'de',
#   'ver',
#   'atr',
#   's',
#   'dessa',
#   'exalta',
#   'o',
#   'a',
#   'sua',
#   'gra',
#   'a',
#   'Falta',
#   'de',
#   'tempo',
#   'leva',
#   'ao',
#   'abandono',
#   'O',
#   'estudo',
#   'efectuado',
#   'por',
#   'M',
#   'rio',
#   'Laje',
#   'sustenta',
#   'que',
#   'a',
#   'maioria',
#   'dos',
#   'volunt',
#   'rios',
#   's',
#   'o',
#   'do',
#   'sexo',
#   'masculino',
#   'com',
#   'idades',
#   'compreendidas',
#   'entre',
#   'os',
#   '35',
#   'e',
#   'os',
#   '44',
#   '<d>PXY</d>',
#   'Este',
#   'grupo',
#   'constitu',
#   'do',
#   'predominantemente',
#   'por',
#   'homens',
#   'de',
#   'forma',
#   'o',
#   'acad',
#   'mica',
#   'seguidores',
#   'sobretudo',
#   'de',
#   'uma',
#   'religi',
#   'o',
#   'n',
#   'o',
#   'crist',
#   'Sampaio',
#   'pede',
#   'a',
#   '<kw>portugueses</kw>',
#   'para',
#   'serem',
#   'mais',
#   'volunt',
#   'rios',
#   'Apenas',
#   '12',
#   '7',
#   'j',
#   'estiveram',
#   'envolvidos',
#   'em',
#   'ac',
#   'es',
#   'de',
#   'ajuda',
#   'DINA',
#   'MARGATO',
#   'A',
#   'participa',
#   'o',
#   'dos',
#   '<kw>portugueses</kw>',
#   'em',
#   'ac',
#   'es',
#   'de',
#   'voluntariado',
#   'escassa',
#   'de',
#   'acordo',
#   'com',
#   'a',
#   'an',
#   'lise',
#   'apresentada',
#   'por',
#   'M',
#   'rio',
#   'Laje',
#   'no',
#   'Congresso',
#   'Nacional',
#   'de',
#   'Volunt',
#   'rios',
#   'que',
#   '<d>2013</d>',
#   'decorreu',
#   'em',
#   '<kw>lisboa</kw>',
#   'Apenas',
#   '12',
#   '7',
#   'dos',
#   'cidad',
#   'os',
#   'nacionais',
#   'j',
#   'estiveram',
#   'envolvidos',
#   'em',
#   'ac',
#   'es',
#   'desta',
#   'natureza',
#   'cerca',
#   'de',
#   '80',
#   'nunca',
#   'foram',
#   'volunt',
#   'rios',
#   'indicou',
#   'a',
#   'sondagem',
#   'desenvolvida',
#   'pela',
#   'Universidade',
#   'Cat',
#   'lica',
#   'A',
#   'iniciativa',
#   'permitiu',
#   'a',
#   'divulga',
#   'o',
#   'de',
#   'um',
#   'aut',
#   'ntico',
#   'diagn',
#   'stico',
#   'do',
#   'que',
#   '<d>2013</d>',
#   'a',
#   'realidade',
#   'do',
#   'voluntariado',
#   'nacional',
#   'Guterres',
#   'recusa',
#   'profissionaliza',
#   'o',
#   'O',
#   'voluntariado',
#   'tem',
#   'um',
#   'papel',
#   'decisivo',
#   'no',
#   'refor',
#   'o',
#   'da',
#   'coes',
#   'o',
#   'e',
#   'no',
#   'combate',
#   'ao',
#   'd',
#   'fice',
#   'da',
#   'vida',
#   'comunit',
#   'ria',
#   'e',
#   'de',
#   'cidadania',
#   'As',
#   '<kw>palavras</kw>',
#   's',
#   'o',
#   'do',
#   'primeiro',
#   'ministro',
#   'Ant',
#   'nio',
#   'Guterres',
#   'que',
#   'falava',
#   'durante',
#   'a',
#   'abertura',
#   'do',
#   'Congresso',
#   'Nacional',
#   'dos',
#   'Volunt',
#   'rios',
#   'ocasi',
#   'o',
#   'em',
#   'que',
#   'lan',
#   'ou',
#   'um',
#   'apelo',
#   'presen',
#   'a',
#   'de',
#   'mais',
#   'volunt',
#   'rios',
#   '<kw>portugueses</kw>',
#   'nos',
#   'cen',
#   'rios',
#   'internacionais',
#   'Soprar',
#   'no',
#   'bal',
#   'o',
#   'para',
#   'saber',
#   'limites',
#   'Preven',
#   'o',
#   'lan',
#   'a',
#   'desafio',
#   'juventude',
#   'para',
#   'que',
#   'n',
#   'o',
#   'receie',
#   'descobrir',
#   'os',
#   'efeitos',
#   'da',
#   'alcoolemia',
#   'CARLOS',
#   'GOMES',
#   'Est',
#   'a',
#   'ser',
#   'poss',
#   'vel',
#   'soprar',
#   'o',
#   'bal',
#   'o',
#   's',
#   'para',
#   'fazer',
#   'o',
#   'teste',
#   'do',
#   'lcool',
#   'e',
#   'conhecer',
#   'os',
#   'limites',
#   'no',
#   'tocante',
#   'ingest',
#   'o',
#   'de',
#   'bebidas',
#   'alco',
#   'licas',
#   '<d>2013</d>',
#   'aconteceu',
#   'em',
#   'Coimbra',
#   'e',
#   '<kw>lisboa</kw>',
#   'Na',
#   'pr',
#   'xima',
#   '<d>2013</d>',
#   'ser',
#   'em',
#   'Faro',
#   'Porto',
#   'e',
#   'Matosinhos',
#   'Dentro',
#   'de',
#   '<d>P15D</d>',
#   'tocar',
#   'a',
#   'vez',
#   'a',
#   'Braga',
#   'Sida',
#   'matou',
#   '20',
#   'milh',
#   'es',
#   'em',
#   'duas',
#   'd',
#   'cadas',
#   'O',
#   'primeiro',
#   'ministro',
#   'portugu',
#   's',
#   'Ant',
#   'nio',
#   'Guterres',
#   'defendeu',
#   '<d>2013</d>',
#   'que',
#   'a',
#   'luta',
#   'contra',
#   'o',
#   'flagelo',
#   'da',
#   'sida',
#   'exigir',
#   'de',
#   'todos',
#   'os',
#   '<kw>portugueses</kw>',
#   'uma',
#   'maior',
#   'cultura',
#   'de',
#   'solidariedade',
#   'e',
#   'uma',
#   'atitude',
#   'cada',
#   'vez',
#   'mais',
#   'determinada',
#   'e',
#   'empenhada',
#   'A',
#   'posi',
#   'o',
#   'do',
#   'chefe',
#   'do',
#   'Governo',
#   'consta',
#   'de',
#   'um',
#   'depoimento',
#   'feito',
#   'para',
#   'a',
#   'Comiss',
#   'o',
#   'Nacional',
#   'de',
#   'Luta',
#   'contra',
#   'a',
#   'Sida',
#   'entidade',
#   'que',
#   'ele',
#   'elogia',
#   'pelo',
#   'trabalho',
#   'de',
#   'dedica',
#   'o',
#   'e',
#   'de',
#   'destacado',
#   'sentido',
#   'humanista',
#   ...]}

# %% [markdown]
# ### Sentences Normalized

# %% [markdown]
# - <b>SentencesNormalized</b>: A dictionary, where the key is the docID and the value is a list of the normalized version of the sentence text (position 0 of the list corresponds to sentence 0, etc). Temporal expressions found in the text are marked with the tag `<d>` while relevant keywords are marked with the tag `<kw>`; Example: `{0: [..., 'As of <d>2010</d> (see 1500 photos here), the following major earthquakes have been recorded in <kw>haiti</kw>.',...]}`.

# %%
SentencesNormalized = results[5]
SentencesNormalized
# Out:
# {0: ['PUBLICO.PT S�bado, 22 de Mar�o de <d>2003</d> 18:56 p�blico <kw>pdf</kw> alertas pesquisas <kw>newsletters</kw> edi��o <kw>impressa</kw> �ltima hora dossiers guia do lazer cinecartaz tvzine ABCed�rio <kw>dvd</kw> s�rie Y mil <kw>folhas</kw> 2 emprego tempo LOGIN Nome de utilizador Palavra-chave REGISTO EDI��O <kw>impressa</kw> Sec��es: 1� P�gina Destaque Nacional Mundo Espa�o P�blico Sociedade Educa��o Ci�ncias Cultura Desporto Economia Media Local Porto �ltima P�gina ------------- Suplementos: Computadores Economia Y Mil <kw>folhas</kw> Fugas ESPECIAL <kw>iraque</kw> ------------- �ltimos <d>P7D</d>: S�bado <d>2013</d> <d>2013</d> <d>2013</d> Ter�a <d>2013</d> <d>2013</d> ------------- P�BLICO em HTML e <kw>pdf</kw> CANAIS Edi��o <kw>impressa</kw> �ltima Hora �ltima Hora UL Mil <kw>folhas</kw> 2 Desporto <kw>dvd</kw> S�rie Y ABCed�rio Guia do Lazer Cinecartaz TVzine R�dio Emprego Imobili�rio Dossiers Ecosfera Banda Desenhada Calvin Bartoon P�BLICO PLUS Registo P�blico em <kw>pdf</kw> <kw>newsletters</kw> <kw>pesquisa</kw> CANAIS INTERACTIVOS Inqu�ritos Tr�nsito Ebook Hor�scopos F�runs SERVI�OS Meteorologia Lotarias Di�rio da Rep�blica Motores de <kw>pesquisa</kw> PROJECTOS P�BLICO Simweb Painel P�blico/IDC Trof�u P�blico P�blico na Escola P�blico/Gradiva 3� Edi��o Fuga <d>2013</d> Guias de Cidades Passatempo <kw>dvd</kw> Serie Y N�s Ficha T�cnica Mapa do Site Livro de Estilo Provedor do Leitor Assinaturas Publicidade GALERIA Arte Viagens Leil�es NOT�CIAS Pol�cia avan�a 35 mil, organiza��o fala em 90 mil Manifesta��o em <kw>lisboa</kw> re�ne dezenas de milhares de pessoas A manifesta��o em <kw>lisboa</kw> contra a guerra no <kw>iraque</kw>, que se iniciou �s 15h45 no Marqu�s de Pombal, levou entre 35 e 90 mil pessoas - segundo os n�meros da pol�cia e da organiza��o - a descerem a Avenida da Liberdade at� ao Rossio.',
#   'Forte explos�o em Bagdad Uma forte explos�o foi registada ao in�cio da noite na parte Oeste de Bagdad.',
#   'O rebentamento, ouvido �s 19h21 locais (14h21 em <kw>lisboa</kw>), provocou uma enorme coluna de fumo, vis�vel a v�rios quil�metros.',
#   '"As suas �ltimas <kw>palavras</kw> foram: \'O nosso destino � construir <d>FUTURE_REF</d> melhor para os nossos pa�ses\'.',
#   'Seguiu-se um sil�ncio e senti que algo tinha acontecido", disse Lahoud numa carta enviada ao filho de <kw>assad</kw> e seu sucessor, Bashar <kw>al-assad</kw>, que ali�s a leu perante as c�maras de TV.',
#   'Pouco ap�s o an�ncio da trag�dia, o Parlamento s�rio reuniu e, entre l�grimas derramadas pelos deputados, a Constitui��o foi emendada num artigo que determinava os 40 <d>PXY</d> como idade m�nima para assumir a chefia do <kw>estado</kw>.',
#   'Sendo assim, os 34 <d>PXY</d> de Bashar deixaram de ser um impedimento para a sucess�o imediata do seu pai.',
#   'Salim Hosse, primeiro-ministro liban�s, pa�s que decretou <d>P7D</d> de luto, considerou que a <kw>morte</kw> de Hafez <kw>al-assad</kw> constitui uma "terr�vel cat�strofe" para o L�bano.',
#   'De Israel, al�m das <kw>palavras</kw> de pesar, veio a garantia de que o pa�s vai continuar a trabalhar em prol da paz no M�dio Oriente.',
#   'O <kw>presidente</kw> da Autoridade Palestiniana, Yasser Arafat, apresentou as condol�ncias ao povo s�rio e decretou tr�s dias de luto nacional nos territ�rios palestinianos.',
#   'O <kw>presidente</kw> norte-americano, Bill Clinton, manifestou-se "entristecido" com a not�cia e, em Moscovo, as autoridades russas consideraram-no como "um grande estadista e amigo da R�ssia".',
#   'De Bagdade veio a frieza, com a r�dio iraquiana a anunciar, sem quaisquer coment�rios, a <kw>morte</kw> de <kw>assad</kw>.',
#   'As rela��es entre o <kw>iraque</kw> e a S�ria, pa�ses governados por alas rivais do partido Baas, foram rompidas em <d>1980</d>, na sequ�ncia da guerra entre Bagdade e Teer�o (<d>1980</d>/88), Copyright � <d>2000</d> Empresa do Jornal de Not�cias S.A. Reservados todos os Direitos.'],
#  2: ['JN <kw>editorial</kw> - out2062 <kw>marchar</kw> contra os sionistas em nome de Al� O sequestro de tr�s soldados israelitas � a �ltima ac��o de envergadura do grupo <kw>xiita</kw> <kw>hezbollah</kw>, que desde a sua cria��o, h� <d>P18Y</d>, luta contra o sionismo com o apoio do Ir�o e da S�ria.',
#   'O grupo radical <kw>xiita</kw> foi fundado no L�bano em <d>1982</d>, durante a guerra civil neste pa�s, com o objectivo de criar uma rep�blica isl�mica, apesar de a sua ideologia se resumir a um forte sentimento anti-israelita e anti-ocidental.',
#   'Aliado do Ir�o, que lhe fornece apoio econ�mico e pol�tico, o <kw>hezbollah</kw> preconiza a cria��o de uma rep�blica de cariz isl�mico pr�-iraniano e a elimina��o de qualquer tipo de presen�a n�o-mu�ulmana no L�bano.',
#   'Tem o seu centro de opera��es no L�bano e comandos permanentes na Europa, �frica, Am�rica do Sul e Estados Unidos.',
#   'O seu atentado mais brutal custou a vida a 241 "marines" norte-americanos e 58 p�ra-quedistas franceses em Beirute, no <d>1983</d>.',
#   'Em <d>2013</d> deste ano, o <kw>hezbollah</kw> estabeleceu uma alian�a inspirada pelo Ir�o com o <kw>movimento</kw> da Resist�ncia Isl�mica Hamas e a Jihad Isl�mica.',
#   'O <kw>movimento</kw> tem cerca de 800 combatentes bem treinados e possui armamento moderno.',
#   'O <kw>hezbollah</kw> � algo mais que um <kw>movimento</kw> guerrilheiro que aspira a destruir o <kw>estado</kw> judeu.',
#   'Trata-se de um partido pol�tico que tem sete deputados no Parlamento de Beirute.',
#   'Copyright � <d>2000</d> Empresa do Jornal de Not�cias S.A. Reservados todos os Direitos.'],
#  3: ['Jornal de Noticias Edi��o de <d>2001</d> �ltima actualiza��o - 0:23 (<kw>portugal</kw>) �ltimas 7 edi��es Arquivo F�runs Sec��es do leitor Dossiers Sec��es semanais Iniciativas <kw>classificados</kw> �ltimas not�cias em foco grande plano tema de semana <kw>portugal</kw> doce grande porto grande <kw>lisboa</kw> pol�tica opini�o sociedade economia mundo pa�s cultura/palco desporto �ltima ficha t�cnica fale connosco Outras <kw>paginas</kw> <d>2001</d> Barriga, nariz e sexo estorvam <kw>portugueses</kw> Estudo in�dito em <kw>portugal</kw> revela os grandes dramas dos homens DOMINGOS DE ANDRADE Um andrologista fez medi��es e descobriu o cabo dos trabalhos da generalidade dos homens <kw>portugueses</kw>.',
#   'Que queimam os neur�nios a tentar esconder a barriga, a disfar�ar o nariz ou a enclausurar o p�nis.',
#   'Quest�o de ra�a <kw>portugueses</kw> s�o mais bem dotados do que americanos, brasileiros e espanh�is DOMINGOS DE ANDRADE Nuno Monteiro Pereira meteu m�os � obra quando reparou que at� <d>2013</d>, em <kw>portugal</kw>, nunca se fez "a defini��o de uma norma morfom�trica peniana".',
#   'Ora, o conhecimento desses valores, porque � de tamanhos que se trata, � importante "para a avalia��o objectiva das queixas dismorf�bicas dos doentes e das indica��es para eventuais t�cnicas de correc��o cosm�tica do tamanho do p�nis, nomeadamente as cirurgias".',
#   'Representa��es hist�ricas Se <d>2013</d> muita gente considera indecente e obsceno o acto de mostrar um falo, noutros tempos isso era sagrado.',
#   'Para os gregos, o falo representava a for�a da Primavera e a fecundidade da terra, que protegia a vida contra as for�as malignas que pudessem amea��-la, pelo que era considerado um objecto de culto, m�stico e at� religioso.',
#   'Esse s�mbolo da masculinidade estendeu-se por todo o Planeta.',
#   'Vigorou no Egipto, na P�rsia, na S�ria, na �ndia, em �frica, nas am�ricas.',
#   'Tamanho para agradar �s mulheres Nuno Monteiro Pereira considera serem sete as raz�es espec�ficas para um homem querer aumentar a dimens�o do seu �rg�o sexual.',
#   'A primeira, e fundamental, � por possu�rem um "micro-p�nis ou um p�nis pequeno, gerador de insatisfa��o e baixa auto-estima, acompanhado ou n�o de dificuldade em estabelecer e manter um relacionamento sentimental amoroso".',
#   'Art�fices da paz aliviam a Justi�a Mediadores ajudam cidad�os a resolver conflitos PEDRO OLAVO SIM�ES A voz sobe de tom: "O sr. Xavier agrediu verbalmente a minha mulher!',
#   'Insultou-a do piorio!".',
#   'Coisa corrente, neste <kw>portugal</kw> de l�ngua desenfreada, mas bizarra para o observador.',
#   'O sr. Xavier em causa � uma mulher, nada ali engana, tal como o sr. Daniel, cuja esposa teve a dignidade enxovalhada.',
#   'S�o mediadoras, que ser�o colocadas nos futuros julgados de paz, em plena ac��o formativa, ensaiando com o poss�vel rigor dram�tico aquilo que as espera quando forem para o terreno: promover justos acordos sem recurso � pesadaJusti�a.',
#   'No��es Julgado de paz Meio de resolu��o alternativa de lit�gios, destinado a resolver causas c�veis de menor complexidade, com rapidez, simplicidade e baixos custos.',
#   'Antes de o juiz decidir, � dada �s partes oportunidade para que se entendam, de forma amig�vel e concertada.',
#   'Advogados aderem ao desafio de poder mudar alguma coisa Lu�s Filipe Guerra � advogado h� <d>P9Y</d>.',
#   'Ofereceu-se para ser mediador, para "introduzir variedade na actividade profissional", mas tamb�m por "ades�o � filosofia inerente � media��o de conflitos".',
#   'Sabe que o esperam, porventura, casos dif�ceis, envolvendo gente mais quezilenta ou at� violenta, mas isso n�o o preocupa minimamente: "Gosto do contacto com as pessoas e de ver, atr�s dessa exalta��o, a sua gra�a".',
#   'Falta de tempo leva ao abandono O estudo efectuado por M�rio Laje sustenta que a maioria dos volunt�rios s�o do sexo masculino, com idades compreendidas entre os 35 e os 44 <d>PXY</d>.',
#   'Este grupo � constitu�do predominantemente por homens de forma��o acad�mica, seguidores sobretudo de uma religi�o n�o crist�.',
#   'Sampaio pede a <kw>portugueses</kw> para serem mais volunt�rios Apenas 12,7% j� estiveram envolvidos em ac��es de ajuda DINA MARGATO A participa��o dos <kw>portugueses</kw> em ac��es de voluntariado � escassa, de acordo com a an�lise apresentada por M�rio Laje, no Congresso Nacional de Volunt�rios que <d>2013</d> decorreu em <kw>lisboa</kw>.',
#   'Apenas 12,7% dos cidad�os nacionais j� estiveram envolvidos em ac��es desta natureza; cerca de 80% nunca foram volunt�rios, indicou a sondagem desenvolvida pela Universidade Cat�lica.',
#   'A iniciativa permitiu a divulga��o de um aut�ntico diagn�stico do que � <d>2013</d> a realidade do voluntariado nacional.',
#   'Guterres recusa profissionaliza��o O voluntariado tem um "papel decisivo" no refor�o da coes�o e no combate ao d�fice da vida comunit�ria e de cidadania.',
#   'As <kw>palavras</kw> s�o do primeiro-ministro, Ant�nio Guterres, que falava durante a abertura do Congresso Nacional dos Volunt�rios, ocasi�o em que lan�ou um apelo � presen�a de mais volunt�rios <kw>portugueses</kw> nos cen�rios internacionais.',
#   '"Soprar no bal�o" para saber limites Preven��o lan�a desafio � juventude para que n�o receie descobrir os efeitos da alcoolemia CARLOS GOMES Est� a ser poss�vel "soprar o bal�o" s� para fazer o teste do �lcool e conhecer os limites no tocante � ingest�o de bebidas alco�licas.',
#   '<d>2013</d>, aconteceu em Coimbra e <kw>lisboa</kw>.',
#   'Na pr�xima <d>2013</d>, ser� em Faro, Porto e Matosinhos.',
#   'Dentro de <d>P15D</d>, tocar� a vez a Braga.',
#   'Sida matou 20 milh�es em duas d�cadas O primeiro-ministro portugu�s, Ant�nio Guterres, defendeu <d>2013</d> que a luta contra o flagelo da sida exigir� de todos os <kw>portugueses</kw> uma maior cultura de solidariedade e uma atitude cada vez mais determinada e empenhada.',
# ### Sentences Tokens

# %% [markdown]
# - <b>SentencesTokens</b>:  A dictionary, where the key is the docID and the value is a list of the text tokens by sentence, that is a list of lists (position 0 of the list gives the tokens of sentence 0, etc). Tokens that are temporal expressions are marked with the tag `<d>`, whereas relevant keywords are marked with the tag `<kw>`. Example: `{0: [[...,..], ['As', 'of', '<d>2010</d>', 'see', '1500',...], [...,..],]}`.

# %%
SentencesTokens = results[6]
SentencesTokens
# Out:
# {0: [['PUBLICO',
#    'PT',
#    'S',
#    'bado',
#    '22',
#    'de',
#    'Mar',
#    'o',
#    'de',
#    '<d>2003</d>',
#    '18',
#    '56',
#    'p',
#    'blico',
#    '<kw>pdf</kw>',
#    'alertas',
#    'pesquisas',
#    '<kw>newsletters</kw>',
#    'edi',
#    'o',
#    '<kw>impressa</kw>',
#    'ltima',
#    'hora',
#    'dossiers',
#    'guia',
#    'do',
#    'lazer',
#    'cinecartaz',
#    'tvzine',
#    'ABCed',
#    'rio',
#    '<kw>dvd</kw>',
#    's',
#    'rie',
#    'Y',
#    'mil',
#    '<kw>folhas</kw>',
#    '2',
#    'emprego',
#    'tempo',
#    'LOGIN',
#    'Nome',
#    'de',
#    'utilizador',
#    'Palavra',
#    'chave',
#    'REGISTO',
#    'EDI',
#    'O',
#    '<kw>impressa</kw>',
#    'Sec',
#    'es',
#    '1',
#    'P',
#    'gina',
#    'Destaque',
#    'Nacional',
#    'Mundo',
#    'Espa',
#    'o',
#    'P',
#    'blico',
#    'Sociedade',
#    'Educa',
#    'o',
#    'Ci',
#    'ncias',
#    'Cultura',
#    'Desporto',
#    'Economia',
#    'Media',
#    'Local',
#    'Porto',
#    'ltima',
#    'P',
#    'gina',
#    'Suplementos',
#    'Computadores',
#    'Economia',
#    'Y',
#    'Mil',
#    '<kw>folhas</kw>',
#    'Fugas',
#    'ESPECIAL',
#    '<kw>iraque</kw>',
#    'ltimos',
#    '<d>P7D</d>',
#    'S',
#    'bado',
#    '<d>2013</d>',
#    '<d>2013</d>',
#    '<d>2013</d>',
#    'Ter',
#    'a',
#    '<d>2013</d>',
#    '<d>2013</d>',
#    'P',
#    'BLICO',
#    'em',
#    'HTML',
#    'e',
#    '<kw>pdf</kw>',
#    'CANAIS',
#    'Edi',
#    'o',
#    '<kw>impressa</kw>',
#    'ltima',
#    'Hora',
#    'ltima',
#    'Hora',
#    'UL',
#    'Mil',
#    '<kw>folhas</kw>',
#    '2',
#    'Desporto',
#    '<kw>dvd</kw>',
#    'S',
#    'rie',
#    'Y',
#    'ABCed',
#    'rio',
#    'Guia',
#    'do',
#    'Lazer',
#    'Cinecartaz',
#    'TVzine',
#    'R',
#    'dio',
#    'Emprego',
#    'Imobili',
#    'rio',
#    'Dossiers',
#    'Ecosfera',
#    'Banda',
#    'Desenhada',
#    'Calvin',
#    'Bartoon',
#    'P',
#    'BLICO',
#    'PLUS',
#    'Registo',
#    'P',
#    'blico',
#    'em',
#    '<kw>pdf</kw>',
#    '<kw>newsletters</kw>',
#    '<kw>pesquisa</kw>',
#    'CANAIS',
#    'INTERACTIVOS',
#    'Inqu',
#    'ritos',
#    'Tr',
#    'nsito',
#    'Ebook',
#    'Hor',
#    'scopos',
#    'F',
#    'runs',
#    'SERVI',
#    'OS',
#    'Meteorologia',
#    'Lotarias',
#    'Di',
#    'rio',
#    'da',
#    'Rep',
#    'blica',
#    'Motores',
#    'de',
#    '<kw>pesquisa</kw>',
#    'PROJECTOS',
#    'P',
#    'BLICO',
#    'Simweb',
#    'Painel',
#    'P',
#    'blico',
#    'IDC',
#    'Trof',
#    'u',
#    'P',
#    'blico',
#    'P',
#    'blico',
#    'na',
#    'Escola',
#    'P',
#    'blico',
#    'Gradiva',
#    '3',
#    'Edi',
#    'o',
#    'Fuga',
#    '<d>2013</d>',
#    'Guias',
#    'de',
#    'Cidades',
#    'Passatempo',
#    '<kw>dvd</kw>',
#    'Serie',
#    'Y',
#    'N',
#    's',
#    'Ficha',
#    'T',
#    'cnica',
#    'Mapa',
#    'do',
#    'Site',
#    'Livro',
#    'de',
#    'Estilo',
#    'Provedor',
#    'do',
#    'Leitor',
#    'Assinaturas',
#    'Publicidade',
#    'GALERIA',
#    'Arte',
#    'Viagens',
#    'Leil',
#    'es',
#    'NOT',
#    'CIAS',
#    'Pol',
#    'cia',
#    'avan',
#    'a',
#    '35',
#    'mil',
#    'organiza',
#    'o',
#    'fala',
#    'em',
#    '90',
#    'mil',
#    'Manifesta',
#    'o',
#    'em',
#    '<kw>lisboa</kw>',
#    're',
#    'ne',
#    'dezenas',
#    'de',
#    'milhares',
#    'de',
#    'pessoas',
#    'A',
#    'manifesta',
#    'o',
#    'em',
#    '<kw>lisboa</kw>',
#    'contra',
#    'a',
#    'guerra',
#    'no',
#    '<kw>iraque</kw>',
#    'que',
#    'se',
#    'iniciou',
#    's',
#    '15h45',
#    'no',
#    'Marqu',
#    's',
#    'de',
#    'Pombal',
#    'levou',
#    'entre',
#    '35',
#    'e',
#    '90',
#    'mil',
#    'pessoas',
#    'segundo',
#    'os',
#    'n',
#    'meros',
#    'da',
#    'pol',
#    'cia',
#    'e',
#    'da',
#    'organiza',
#    'o',
#    'a',
#    'descerem',
#    'a',
#    'Avenida',
#    'da',
#    'Liberdade',
#    'at',
#    'ao',
#    'Rossio'],
#   ['Forte',
#    'explos',
#    'o',
#    'em',
#    'Bagdad',
#    'Uma',
#    'forte',
#    'explos',
#    'o',
#    'foi',
#    'registada',
#    'ao',
#    'in',
#    'cio',
#    'da',
#    'noite',
#    'na',
#    'parte',
#    'Oeste',
#    'de',
#    'Bagdad'],
#   ['O',
#    'rebentamento',
#    'ouvido',
#    's',
#    '19h21',
#    'locais',
#    '14h21',
#    'em',
#    '<kw>lisboa</kw>',
#    'provocou',
#    'uma',
#    'enorme',
#    'coluna',
#    'de',
#    'fumo',
#    'vis',
#    'vel',
#    'a',
#    'v',
#    'rios',
#    'quil',
#    'metros'],
#   ['ATAQUE',
#    'AO',
#    '<kw>iraque</kw>',
#    'Video',
#    'Fotos',
#    'INFOGRAFIA',
#    'ltimas',
#    'not',
#    'cias',
#    'Dossier',
#    '<kw>iraque</kw>',
#    '<kw>iraque</kw>',
#    'p',
#    's',
#    'Saddam',
#    'Armas',
#    'Aliadas',
#    'Armas',
#    'iraquianas',
#    'Ataque',
#    'ao',
#    '<kw>iraque</kw>',
#    'S',
#    'ria',
#    'denuncia',
#    'agress',
#    'o',
#    'b',
#    'rbara',
#    'e',
#    'apela',
#    'ao',
#    'fim',
#    'da',
#    'guerra',
#    'Tentando',
#    'travar',
#    'vaga',
#    'de',
#    'refugiados',
#    'Tropas',
#    'turcas',
#    'v',
#    'o',
#    'entrar',
#    'no',
#    '<kw>iraque</kw>',
#    'para',
#    'prevenir',
#    'actividades',
#    'terroristas',
#    'For',
#    'as',
#    'iraquianas',
#    'ter',
#    'o',
#    'incendiado',
#    'petr',
#    'leo',
#    'em',
#    'torno',
#    'da',
#    'capital',
#    'Bagdad',
#    'rodeada',
#    'de',
#    'trincheiras',
#    'em',
#    'chamas',
#    'GUIA',
#    'DO',
#    'LAZER',
#    'M',
#    'sica',
#    'Cid',
#    'Campos',
#    'Teatro',
#    'Jimmy',
#    'Cr',
#    'ture',
#    'de',
#    'R',
#    've',
#    'Dan',
#    'a',
#    'Ballet',
#    'Gulbenkian',
#    'CINECARTAZ',
#    'Estreia',
#    'da',
#    'Semana',
#    'Longe',
#    'do',
#    'Para',
#    'so',
#    'Recomendamos',
#    'As',
#    'Confiss',
#    'es',
#    'de',
#    'Schmidt',
#    'Ciclo',
#    'Transforma',
#    'es',
#    'Muta',
#    'es',
#    'DOSSIERS',
#    'Come',
#    'ou',
#    'a',
#    'guerra',
#    '<kw>iraque</kw>',
#    'debaixo',
#    'de',
#    'fogo',
#    'scares',
#    '<d>2003</d>',
#    'Pr',
#    'mios',
#    'da',
#    'Academia',
#    's',
#    'o',
#    'entregues',
#    'a',
#    '23',
#    'de',
#    'Mar',
#    'o',
#    'Doping',
#    'no',
#    'desporto',
#    '<kw>portugal</kw>',
#    'quer',
#    'liderar',
#    'aplica',
#    'o',
#    'do',
#    'c',
#    'digo',
#    'mundial',
#    'O',
#    'ltimo',
#    'voo',
#    'do',
#    'Columbia',
#    'NASA',
#    'procura',
#    'explica',
#    'es',
#    'para',
#    'o',
#    'acidente',
#    'Excis',
#    'o',
#    'feminina',
#    'O',
#    'holocausto',
#    'silencioso',
#    'das',
#    'mulheres',
#    'a',
#    'quem',
#    'continuam',
#    'a',
#    'extrair',
#    'o',
#    'cl',
#    'toris',
#    'Pedofilia',
#    'As',
#    'deten',
#    'es',
#    'que',
#    'abalaram',
#    '<kw>portugal</kw>',
#    'Caso',
#    'Felgueiras',
#    'Minist',
#    'rio',
#    'P',
#    'blico',
#    'atribui',
#    'a',
#    'F',
#    'tima',
#    'Felgueiras',
#    'a',
#    'pr',
#    'tica',
#    'de',
#    'dezenas',
#    'de',
#    'crimes',
#    'Moderna',
#    'o',
#    'caso',
#    'As',
#    'rela',
#    'es',
#    'jogos',
#    'e',
#    'lutas',
#    'de',
#    'poder',
#    'P',
#    'blico500',
#    'As',
#    'maiores',
#    'empresas',
#    'n',
#    'o',
#    'financeiras',
#    'de',
#    '<kw>portugal</kw>',
#    'LTIMAS',
#    'Internacional',
#    'Marines',
#    'americanos',
#    'vencem',
#    'batalha',
#    'a',
#    'Oeste',
#    'de',
#    'Bassor',
#    'Internacional',
#    'EUA',
#    'v',
#    'o',
#    'investigar',
#    'queda',
#    'de',
#    'm',
#    'ssil',
#    'no',
#    'Ir',
#    'o',
#    'Desporto',
#    'C',
#    'sar',
#    'Peixoto',
#    'e',
#    'Pedro',
#    'Emanuel',
#    'viajam',
#    'para',
#    'a',
#    'Madeira',
#    'Internacional',
#    'Brit',
#    'nicos',
#    'manifestam',
#    'se',
#    'contra',
#    'a',
#    'guerra',
#    'Internacional',
#    'Manifesta',
#    'o',
#    'em',
#    '<kw>lisboa</kw>',
#    're',
#    'ne',
#    'dezenas',
#    'de',
#    'milhares',
#    'de',
#    'pessoas',
#    '10',
#    'LTIMAS',
#    '10',
#    'LTIMAS',
#    'DESPORTO',
#    'O',
#    'TEMPO',
#    's',
#    '17h00',
#    '<kw>lisboa</kw>',
#    'Muito',
#    'nublado',
#    '18',
#    'C',
#    'Porto',
#    'Muito',
#    'nublado',
#    '16',
#    'C',
#    'Faro',
#    'Pouco',
#    'nublado',
#    '18',
#    'C',
#    'Funchal',
#    'Pouco',
#    'nublado',
#    '18',
#    'C',
#    'Ponta',
#    'Delgada',
#    '14',
#    'C',
#    'INQU',
#    'RITOS',
#    'O',
#    'que',
#    'vai',
#    'acontecer',
#    'a',
#    'Saddam',
#    'Hussein'],
#   ['1',
#    'Ser',
#    'capturado',
#    'pelos',
#    'EUA',
#    '2',
#    'Vai',
#    'fugir',
#    '3',
#    'Vai',
#    'morrer',
#    'em',
#    'combate',
#    '4',
#    'Vai',
#    'vencer',
#    'a',
#    'guerra',
#    'Sorry',
#    'your',
#    'browser',
#    'does',
#    'not',
#    'support',
#    'the',
#    'iframe',
#    'tag']],
#  1: [['JN',
#    '<kw>editorial</kw>',
#    'out1061',
#    '<kw>assad</kw>',
#    '<kw>faleceu</kw>',
#    'deixando',
#    'a',
#    'S',
#    'ria',
#    'entregue',
#    'ao',
#    'filho',
#    'O',
#    '<kw>presidente</kw>',
#    'da',
#    'S',
#    'ria',
#    'Hafez',
#    '<kw>al-assad</kw>',
#    '<kw>faleceu</kw>',
#    '<d>2013</d>',
#    'pelas',
#    '<d>PT11H</d>',
#    'vitimado',
#    'por',
#    'um',
#    'ataque',
#    'do',
#    'cora',
#    'o'],
#   ['As',
#    'reac',
#    'es',
#    'de',
#    'consterna',
#    'o',
#    'n',
#    'o',
#    'se',
#    'fizeram',
#    'esperar',
#    'no',
#    'mundo',
#    'rabe',
#    'embora',
#    'Israel',
#    'e',
#    'muitos',
#    'estados',
#    'do',
#    'Ocidente',
#    'tenham',
#    'igualmente',
#    'proferido',
#    '<kw>palavras</kw>',
#    'de',
#    'profundo',
#    'pesar',
#    'pela',
#    '<kw>morte</kw>',
#    'de',
#    'um',
#    '<kw>presidente</kw>',
#    'quase',
#    'esf',
#    'ngico',
#    'no',
#    'problem',
#    'tico',
#    'cen',
#    'rio',
#    'de',
#    'guerra',
#    'e',
#    'paz',
#    'que',
#    'caracteriza',
#    'o',
#    'M',
#    'dio',
#    'Oriente'],
#   ['O',
#    'funeral',
#    'de',
#    '<kw>estado</kw>',
#    'realiza',
#    'se',
#    'somente',
#    'depois',
#    'de',
#    'amanh'],
#   ['<kw>assad</kw>',
#    'j',
#    'sofria',
#    'h',
#    'algum',
#    'tempo',
#    'de',
#    'problemas',
#    'do',
#    'cora',
#    'o',
#    'e',
#    'de',
#    'diabetes'],
#   ['Os',
#    'rumores',
#    'da',
#    'sua',
#    '<kw>morte</kw>',
#    'iminente',
#    'j',
#    'circulavam',
#    'h',
#    '<d>PXY</d>',
#    'mas',
#    'o',
#    '<kw>presidente</kw>',
#    'liban',
#    's',
#    'Emile',
#    'Lahoud',
#    'disse',
#    'que',
#    'tinha',
#    'falado',
#    'sem',
#    'dificuldade',
#    'com',
#    '<kw>assad</kw>',
#    'na',
#    'madrugada',
#    'de',
#    '<d>2013</d>'],
#   ['As',
#    'suas',
#    'ltimas',
#    '<kw>palavras</kw>',
#    'foram',
#    'O',
#    'nosso',
#    'destino',
#    'construir',
#    '<d>FUTURE_REF</d>',
#    'melhor',
#    'para',
#    'os',
#    'nossos',
#    'pa',
#    'ses'],
#   ['Seguiu',
#    'se',
#    'um',
#    'sil',
#    'ncio',
#    'e',
#    'senti',
#    'que',
#    'algo',
#    'tinha',
#    'acontecido',
#    'disse',
#    'Lahoud',
#    'numa',
#    'carta',
#    'enviada',
#    'ao',
#    'filho',
#    'de',
#    '<kw>assad</kw>',
#    'e',
#    'seu',
#    'sucessor',
#    'Bashar',
#    '<kw>al-assad</kw>',
#    'que',
#    'ali',
#    's',
#    'a',
#    'leu',
#    'perante',
#    'as',
#    'c',
#    'maras',
#    'de',
#    'TV'],
#   ['Pouco',
#    'ap',
#    's',
#    'o',
#    'an',
#    'ncio',
#    'da',
#    'trag',
#    'dia',
#    'o',
#    'Parlamento',
#    's',
#    'rio',
#    'reuniu',
#    'e',
#    'entre',
#    'l',
#    'grimas',
#    'derramadas',
#    'pelos',
#    'deputados',
#    'a',
#    'Constitui',
#    'o',
#    'foi',
#    'emendada',
#    'num',
#    'artigo',
#    'que',
#    'determinava',
#    'os',
#    '40',
#    '<d>PXY</d>',
#    'como',
#    'idade',
#    'm',
#    'nima',
#    'para',
#    'assumir',
#    'a',
#    'chefia',
#    'do',
#    '<kw>estado</kw>'],
#   ['Sendo',
#    'assim',
#    'os',
#    '34',
#    '<d>PXY</d>',
#    'de',
#    'Bashar',
#    'deixaram',
#    'de',
#    'ser',
#    'um',
#    'impedimento',
#    'para',
#    'a',
#    'sucess',
#    'o',
#    'imediata',
#    'do',
#    'seu',
#    'pai'],
#   ['Salim',
#    'Hosse',
#    'primeiro',
#    'ministro',
#    'liban',
#    's',
#    'pa',
#    's',
#    'que',
#    'decretou',
#    '<d>P7D</d>',
#    'de',
#    'luto',
#    'considerou',
#    'que',
#    'a',
#    '<kw>morte</kw>',
#    'de',
#    'Hafez',
#    '<kw>al-assad</kw>',
#    'constitui',
#    'uma',
#    'terr',
#    'vel',
#    'cat',
#    'strofe',
#    'para',
#    'o',
#    'L',
#    'bano'],
#   ['De',
#    'Israel',
#    'al',
#    'm',
#    'das',
#    '<kw>palavras</kw>',
#    'de',
#    'pesar',
#    'veio',
#    'a',
#    'garantia',
#    'de',
#    'que',
#    'o',
#    'pa',
#    's',
#    'vai',
#    'continuar',
#    'a',
#    'trabalhar',
#    'em',
#    'prol',
#    'da',
#    'paz',
#    'no',
#    'M',
#    'dio',
#    'Oriente'],
#   ['O',
#    '<kw>presidente</kw>',
#    'da',
#    'Autoridade',
#    'Palestiniana',
#    'Yasser',
#    'Arafat',
#    'apresentou',
#    'as',
#    'condol',
#    'ncias',
#    'ao',
#    'povo',
#    's',
#    'rio',
#    'e',
#    'decretou',
#    'tr',
#    's',
#    'dias',
#    'de',
#    'luto',
#    'nacional',
#    'nos',
#    'territ',
#    'rios',
#    'palestinianos'],
#   ['O',
#    '<kw>presidente</kw>',
#    'norte',
#    'americano',
#    'Bill',
#    'Clinton',
#    'manifestou',
#    'se',
#    'entristecido',
#    'com',
#    'a',
#    'not',
#    'cia',
#    'e',
#    'em',
#    'Moscovo',
#    'as',
#    'autoridades',
#    'russas',
#    'consideraram',
#    'no',
#    'como',
#    'um',
#    'grande',
#    'estadista',
#    'e',
#    'amigo',
#    'da',
#    'R',
#    'ssia'],
#   ['De',
#    'Bagdade',
#    'veio',
#    'a',
#    'frieza',
#    'com',
#    'a',
#    'r',
#    'dio',
#    'iraquiana',
#    'a',
#    'anunciar',
#    'sem',
#    'quaisquer',
#    'coment',
#    'rios',
#    'a',
#    '<kw>morte</kw>',
#    'de',
#    '<kw>assad</kw>'],
#   ['As',
#    'rela',
#    'es',
#    'entre',
#    'o',
#    '<kw>iraque</kw>',
#    'e',
#    'a',
#    'S',
#    'ria',
#    'pa',
#    'ses',
#    'governados',
#    'por',
#    'alas',
#    'rivais',
#    'do',
#    'partido',
#    'Baas',
#    'foram',
#    'rompidas',
#    'em',
#    '<d>1980</d>',
#    'na',
#    'sequ',
#    'ncia',
#    'da',
#    'guerra',
#    'entre',
#    'Bagdade',
#    'e',
#    'Teer',
#    'o',
#    '<d>1980</d>',
#    '88',
#    'Copyright',
#    '<d>2000</d>',
#    'Empresa',
#    'do',
#    'Jornal',
#    'de',
#    'Not',
#    'cias',
#    'S',
#    'A',
#    'Reservados',
#    'todos',
#    'os',
#    'Direitos']],
#  2: [['JN',
#    '<kw>editorial</kw>',
#    'out2062',
#    '<kw>marchar</kw>',
#    'contra',
#    'os',
#    'sionistas',
#    'em',
#    'nome',
#    'de',
#    'Al',
#    'O',
#    'sequestro',
#    'de',
#    'tr',
#    's',
#    'soldados',
#    'israelitas',
#    'a',
#    'ltima',
#    'ac',
#    'o',
#    'de',
#    'envergadura',
#    'do',
#    'grupo',
#    '<kw>xiita</kw>',
#    '<kw>hezbollah</kw>',
#    'que',
#    'desde',
#    'a',
#    'sua',
#    'cria',
#    'o',
#    'h',
#    '<d>P18Y</d>',
#    'luta',
#    'contra',
#    'o',
#    'sionismo',
#    'com',
#    'o',
#    'apoio',
#    'do',
#    'Ir',
#    'o',
#    'e',
#    'da',
#    'S',
#    'ria'],
#   ['O',
#    'grupo',
#    'radical',
#    '<kw>xiita</kw>',
#    'foi',
#    'fundado',
#    'no',
#    'L',
#    'bano',
#    'em',
#    '<d>1982</d>',
#    'durante',
#    'a',
#    'guerra',
#    'civil',
#    'neste',
#    'pa',
#    's',
#    'com',
#    'o',
#    'objectivo',
#    'de',
#    'criar',
#    'uma',
#    'rep',
#    'blica',
#    'isl',
#    'mica',
#    'apesar',
#    'de',
#    'a',
#    'sua',
#    'ideologia',
#    'se',
#    'resumir',
#    'a',
#    'um',
#    'forte',
#    'sentimento',
#    'anti',
#    'israelita',
#    'e',
#    'anti',
#    'ocidental'],
#   ['Aliado',
#    'do',
#    'Ir',
#    'o',
#    'que',
#    'lhe',
#    'fornece',
#    'apoio',
#    'econ',
#    'mico',
#    'e',
#    'pol',
#    'tico',
#    'o',
#    '<kw>hezbollah</kw>',
#    'preconiza',
#    'a',
#    'cria',
#    'o',
#    'de',
#    'uma',
#    'rep',
#    'blica',
#    'de',
#    'cariz',
#    'isl',
#    'mico',
#    'pr',
#    'iraniano',
#    'e',
#    'a',
#    'elimina',
#    'o',
#    'de',
#    'qualquer',
#    'tipo',
#    'de',
#    'presen',
#    'a',
#    'n',
#    'o',
#    'mu',
#    'ulmana',
#    'no',
#    'L',
#    'bano'],
#   ['Tem',
#    'o',
#    'seu',
#    'centro',
#    'de',
#    'opera',
#    'es',
#    'no',
#    'L',
#    'bano',
#    'e',
#    'comandos',
#    'permanentes',
#    'na',
#    'Europa',
#    'frica',
#    'Am',
#    'rica',
#    'do',
#    'Sul',
#    'e',
#    'Estados',
#    'Unidos'],
#   ['O',
#    'seu',
#    'atentado',
#    'mais',
#    'brutal',
#    'custou',
#    'a',
#    'vida',
#    'a',
#    '241',
#    'marines',
#    'norte',
#    'americanos',
#    'e',
#    '58',
#    'p',
#    'ra',
#    'quedistas',
#    'franceses',
#    'em',
#    'Beirute',
#    'no',
#    '<d>1983</d>'],
#   ['Em',
#    '<d>2013</d>',
#    'deste',
#    'ano',
#    'o',
#    '<kw>hezbollah</kw>',
#    'estabeleceu',
#    'uma',
#    'alian',
#    'a',
#    'inspirada',
#    'pelo',
#    'Ir',
#    'o',
#    'com',
#    'o',
#    '<kw>movimento</kw>',
#    'da',
#    'Resist',
#    'ncia',
#    'Isl',
#    'mica',
#    'Hamas',
#    'e',
#    'a',
#    'Jihad',
#    'Isl',
#    'mica'],
#   ['O',
#    '<kw>movimento</kw>',
#    'tem',
#    'cerca',
#    'de',
#    '800',
#    'combatentes',
#    'bem',
#    'treinados',
#    'e',
#    'possui',
#    'armamento',
#    'moderno'],
#   ['O',
#    '<kw>hezbollah</kw>',
#    'algo',
#    'mais',
#    'que',
#    'um',
#    '<kw>movimento</kw>',
#    'guerrilheiro',
#    'que',
#    'aspira',
#    'a',
#    'destruir',
#    'o',
#    '<kw>estado</kw>',
#    'judeu'],
#   ['Trata',
#    'se',
#    'de',
#    'um',
#    'partido',
#    'pol',
#    'tico',
#    'que',
#    'tem',
#    'sete',
#    'deputados',
#    'no',
#    'Parlamento',
#    'de',
#    'Beirute'],
#   ['Copyright',
#    '<d>2000</d>',
#    'Empresa',
#    'do',
#    'Jornal',
#    'de',
#    'Not',
#    'cias',
#    'S',
#    'A',
#    'Reservados',
#    'todos',
#    'os',
#    'Direitos']],
#  3: [['Jornal',
#    'de',
#    'Noticias',
#    'Edi',
#    'o',
#    'de',
#    '<d>2001</d>',
#    'ltima',
#    'actualiza',
#    'o',
#    '0',
#    '23',
#    '<kw>portugal</kw>',
#    'ltimas',
#    '7',
#    'edi',
#    'es',
#    'Arquivo',
#    'F',
#    'runs',
#    'Sec',
#    'es',
#    'do',
#    'leitor',
#    'Dossiers',
#    'Sec',
#    'es',
#    'semanais',
#    'Iniciativas',
#    '<kw>classificados</kw>',
#    'ltimas',
#    'not',
#    'cias',
#    'em',
#    'foco',
#    'grande',
#    'plano',
#    'tema',
#    'de',
#    'semana',
#    '<kw>portugal</kw>',
#    'doce',
#    'grande',
#    'porto',
#    'grande',
#    '<kw>lisboa</kw>',
#    'pol',
#    'tica',
#    'opini',
#    'o',
#    'sociedade',
#    'economia',
#    'mundo',
#    'pa',
#    's',
#    'cultura',
#    'palco',
#    'desporto',
#    'ltima',
#    'ficha',
#    't',
#    'cnica',
#    'fale',
#    'connosco',
#    'Outras',
#    '<kw>paginas</kw>',
#    '<d>2001</d>',
#    'Barriga',
#    'nariz',
#    'e',
#    'sexo',
#    'estorvam',
#    '<kw>portugueses</kw>',
#    'Estudo',
#    'in',
#    'dito',
#    'em',
#    '<kw>portugal</kw>',
#    'revela',
#    'os',
#    'grandes',
#    'dramas',
#    'dos',
#    'homens',
#    'DOMINGOS',
#    'DE',
#    'ANDRADE',
#    'Um',
#    'andrologista',
#    'fez',
#    'medi',
#    'es',
#    'e',
#    'descobriu',
#    'o',
#    'cabo',
#    'dos',
#    'trabalhos',
#    'da',
#    'generalidade',
#    'dos',
#    'homens',
#    '<kw>portugueses</kw>'],
#   ['Que',
#    'queimam',
#    'os',
#    'neur',
#    'nios',
#    'a',
#    'tentar',
#    'esconder',
#    'a',
#    'barriga',
#    'a',
#    'disfar',
#    'ar',
#    'o',
#    'nariz',
#    'ou',
#    'a',
#    'enclausurar',
#    'o',
#    'p',
#    'nis'],
#   ['Quest',
#    'o',
#    'de',
#    'ra',
#    'a',
#    '<kw>portugueses</kw>',
#    's',
#    'o',
#    'mais',
#    'bem',
#    'dotados',
#    'do',
#    'que',
#    'americanos',
#    'brasileiros',
#    'e',
#    'espanh',
#    'is',
#    'DOMINGOS',
#    'DE',
#    'ANDRADE',
#    'Nuno',
#    'Monteiro',
#    'Pereira',
#    'meteu',
#    'm',
#    'os',
#    'obra',
#    'quando',
#    'reparou',
#    'que',
#    'at',
#    '<d>2013</d>',
#    'em',
#    '<kw>portugal</kw>',
#    'nunca',
#    'se',
#    'fez',
#    'a',
#    'defini',
#    'o',
#    'de',
#    'uma',
#    'norma',
#    'morfom',
#    'trica',
#    'peniana'],
#   ['Ora',
#    'o',
#    'conhecimento',
#    'desses',
#    'valores',
#    'porque',
#    'de',
#    'tamanhos',
#    'que',
#    'se',
#    'trata',
#    'importante',
#    'para',
#    'a',
#    'avalia',
#    'o',
#    'objectiva',
#    'das',
#    'queixas',
#    'dismorf',
#    'bicas',
#    'dos',
#    'doentes',
#    'e',
#    'das',
#    'indica',
#    'es',
#    'para',
#    'eventuais',
#    't',
#    'cnicas',
#    'de',
#    'correc',
#    'o',
#    'cosm',
#    'tica',
#    'do',
#    'tamanho',
#    'do',
#    'p',
#    'nis',
#    'nomeadamente',
#    'as',
#    'cirurgias'],
#   ['Representa',
#    'es',
#    'hist',
#    'ricas',
#    'Se',
#    '<d>2013</d>',
#    'muita',
#    'gente',
#    'considera',
#    'indecente',
#    'e',
#    'obsceno',
#    'o',
#    'acto',
#    'de',
#    'mostrar',
#    'um',
#    'falo',
#    'noutros',
#    'tempos',
#    'isso',
#    'era',
#    'sagrado'],
#   ['Para',
#    'os',
#    'gregos',
#    'o',
#    'falo',
#    'representava',
#    'a',
#    'for',
#    'a',
#    'da',
#    'Primavera',
#    'e',
#    'a',
#    'fecundidade',
#    'da',
#    'terra',
#    'que',
#    'protegia',
#    'a',
#    'vida',
#    'contra',
#    'as',
#    'for',
#    'as',
#    'malignas',
#    'que',
#    'pudessem',
#    'amea',
#    'la',
#    'pelo',
#    'que',
#    'era',
#    'considerado',
#    'um',
#    'objecto',
#    'de',
#    'culto',
#    'm',
#    'stico',
#    'e',
#    'at',
#    'religioso'],
#   ['Esse',
#    's',
#    'mbolo',
#    'da',
#    'masculinidade',
#    'estendeu',
#    'se',
#    'por',
#    'todo',
#    'o',
#    'Planeta'],
#   ['Vigorou',
#    'no',
#    'Egipto',
#    'na',
#    'P',
#    'rsia',
#    'na',
#    'S',
#    'ria',
#    'na',
#    'ndia',
#    'em',
#    'frica',
#    'nas',
#    'am',
#    'ricas'],
#   ['Tamanho',
#    'para',
#    'agradar',
#    's',
#    'mulheres',
#    'Nuno',
#    'Monteiro',
#    'Pereira',
#    'considera',
#    'serem',
#    'sete',
#    'as',
#    'raz',
#    'es',
#    'espec',
#    'ficas',
#    'para',
#    'um',
#    'homem',
#    'querer',
#    'aumentar',
#    'a',
#    'dimens',
#    'o',
#    'do',
#    'seu',
#    'rg',
#    'o',
#    'sexual'],
#   ['A',
#    'primeira',
#    'e',
#    'fundamental',
#    'por',
#    'possu',
#    'rem',
#    'um',
#    'micro',
#    'p',
#    'nis',
#    'ou',
#    'um',
#    'p',
#    'nis',
#    'pequeno',
#    'gerador',
#    'de',
#    'insatisfa',
#    'o',
#    'e',
#    'baixa',
#    'auto',
#    'estima',
#    'acompanhado',
#    'ou',
#    'n',
#    'o',
#    'de',
#    'dificuldade',
#    'em',
#    'estabelecer',
#    'e',
#    'manter',
#    'um',
#    'relacionamento',
#    'sentimental',
#    'amoroso'],
#   ['Art',
#    'fices',
#    'da',
#    'paz',
#    'aliviam',
#    'a',
#    'Justi',
#    'a',
#    'Mediadores',
#    'ajudam',
#    'cidad',
#    'os',
#    'a',
#    'resolver',
#    'conflitos',
#    'PEDRO',
#    'OLAVO',
#    'SIM',
#    'ES',
#    'A',
#    'voz',
#    'sobe',
#    'de',
#    'tom',
#    'O',
#    'sr',
#    'Xavier',
#    'agrediu',
#    'verbalmente',
#    'a',
#    'minha',
#    'mulher'],
#   ['Insultou', 'a', 'do', 'piorio'],
#   ['Coisa',
#    'corrente',
#    'neste',
#    '<kw>portugal</kw>',
#    'de',
#    'l',
#    'ngua',
#    'desenfreada',
#    'mas',
#    'bizarra',
#    'para',
#    'o',
#    'observador'],
#   ['O',
#    'sr',
#    'Xavier',
#    'em',
#    'causa',
#    'uma',
#    'mulher',
#    'nada',
#    'ali',
#    'engana',
#    'tal',
#    'como',
#    'o',
#    'sr',
#    'Daniel',
#    'cuja',
#    'esposa',
#    'teve',
#    'a',
#    'dignidade',
#    'enxovalhada'],
#   ['S',
#    'o',
#    'mediadoras',
#    'que',
#    'ser',
#    'o',
#    'colocadas',
#    'nos',
#    'futuros',
#    'julgados',
#    'de',
#    'paz',
#    'em',
#    'plena',
#    'ac',
#    'o',
#    'formativa',
#    'ensaiando',
#    'com',
#    'o',
#    'poss',
#    'vel',
#    'rigor',
#    'dram',
#    'tico',
#    'aquilo',
#    'que',
#    'as',
#    'espera',
#    'quando',
#    'forem',
#    'para',
#    'o',
#    'terreno',
#    'promover',
#    'justos',
#    'acordos',
#    'sem',
#    'recurso',
#    'pesadaJusti',
#    'a'],
#   ['No',
#    'es',
#    'Julgado',
#    'de',
#    'paz',
#    'Meio',
#    'de',
#    'resolu',
#    'o',
#    'alternativa',
#    'de',
#    'lit',
#    'gios',
#    'destinado',
#    'a',
#    'resolver',
#    'causas',
#    'c',
#    'veis',
#    'de',
#    'menor',
#    'complexidade',
#    'com',
#    'rapidez',
#    'simplicidade',
#    'e',
#    'baixos',
#    'custos'],
#   ['Antes',
#    'de',
#    'o',
#    'juiz',
#    'decidir',
#    'dada',
#    's',
#    'partes',
#    'oportunidade',
#    'para',
#    'que',
#    'se',
#    'entendam',
#    'de',
#    'forma',
#    'amig',
#    'vel',
#    'e',
#    'concertada'],
#   ['Advogados',
#    'aderem',
#    'ao',
#    'desafio',
#    'de',
#    'poder',
#    'mudar',
#    'alguma',
#    'coisa',
#    'Lu',
#    's',
#    'Filipe',
#    'Guerra',
#    'advogado',
#    'h',
#    '<d>P9Y</d>'],
#   ['Ofereceu',
#    'se',
#    'para',
#    'ser',
#    'mediador',
#    'para',
#    'introduzir',
#    'variedade',
#    'na',
#    'actividade',
#    'profissional',
#    'mas',
#    'tamb',
#    'm',
#    'por',
#    'ades',
#    'o',
#    'filosofia',
#    'inerente',
#    'media',
#    'o',
#    'de',
#    'conflitos'],
#   ['Sabe',
#    'que',
#    'o',
#    'esperam',
#    'porventura',
#    'casos',
#    'dif',
#    'ceis',
#    'envolvendo',
#    'gente',
#    'mais',
#    'quezilenta',
#    'ou',
#    'at',
#    'violenta',
#    'mas',
#    'isso',
#    'n',
#    'o',
#    'o',
#    'preocupa',
#    'minimamente',
#    'Gosto',
#    'do',
#    'contacto',
#    'com',
#    'as',
#    'pessoas',
#    'e',
#    'de',
#    'ver',
#    'atr',
#    's',
#    'dessa',
#    'exalta',
#    'o',
#    'a',
#    'sua',
#    'gra',
#    'a'],
#   ['Falta',
#    'de',
#    'tempo',
#    'leva',
#    'ao',
#    'abandono',
#    'O',
#    'estudo',
#    'efectuado',
#    'por',
#    'M',
#    'rio',
#    'Laje',
#    'sustenta',
#    'que',
#    'a',
#    'maioria',
#    'dos',
#    'volunt',
#    'rios',
#    's',
#    'o',
#    'do',
#    'sexo',
#    'masculino',
#    'com',
#    'idades',
#    'compreendidas',
#    'entre',
#    'os',
#    '35',
#    'e',
#    'os',
#    '44',
#    '<d>PXY</d>'],
#   ['Este',
#    'grupo',
#    'constitu',
#    'do',
#    'predominantemente',
#    'por',
#    'homens',
#    'de',
#    'forma',
#    'o',
#    'acad',
#    'mica',
#    'seguidores',
#    'sobretudo',
#    'de',
#    'uma',
#    'religi',
#    'o',
#    'n',
#    'o',
#    'crist'],
#   ['Sampaio',
#    'pede',
#    'a',
#    '<kw>portugueses</kw>',
#    'para',
#    'serem',
#    'mais',
#    'volunt',
#    'rios',
#    'Apenas',
#    '12',
#    '7',
#    'j',
#    'estiveram',
#    'envolvidos',
#    'em',
#    'ac',
#    'es',
#    'de',
#    'ajuda',
#    'DINA',
#    'MARGATO',
#    'A',
#    'participa',
#    'o',
#    'dos',
#    '<kw>portugueses</kw>',
#    'em',
#    'ac',
#    'es',
#    'de',
#    'voluntariado',
#    'escassa',
#    'de',
#    'acordo',
#    'com',
#    'a',
#    'an',
#    'lise',
#    'apresentada',
#    'por',
#    'M',
#    'rio',
#    'Laje',
#    'no',
#    'Congresso',
#    'Nacional',
#    'de',
#    'Volunt',
#    'rios',
#    'que',
#    '<d>2013</d>',
#    'decorreu',
#    'em',
#    '<kw>lisboa</kw>'],
#   ['Apenas',
#    '12',
#    '7',
#    'dos',
#    'cidad',
#    'os',
#    'nacionais',
#    'j',
#    'estiveram',
#    'envolvidos',
#    'em',
#    'ac',
#    'es',
#    'desta',
#    'natureza',
#    'cerca',
#    'de',
#    '80',
#    'nunca',
#    'foram',
#    'volunt',
#    'rios',
#    'indicou',
#    'a',
#    'sondagem',
#    'desenvolvida',
#    'pela',
#    'Universidade',
#    'Cat',
#    'lica'],
#   ['A',
#    'iniciativa',
#    'permitiu',
#    'a',
#    'divulga',
#    'o',
#    'de',
#    'um',
#    'aut',
#    'ntico',
#    'diagn',
#    'stico',
#    'do',
#    'que',
#    '<d>2013</d>',
#    'a',
#    'realidade',
#    'do',
#    'voluntariado',
#    'nacional'],
#   ['Guterres',
#    'recusa',
#    'profissionaliza',
#    'o',
#    'O',
#    'voluntariado',
#    'tem',
#    'um',
#    'papel',
#    'decisivo',
#    'no',
#    'refor',
#    'o',
#    'da',
#    'coes',
#    'o',
#    'e',
#    'no',
#    'combate',
#    'ao',
#    'd',
#    'fice',
#    'da',
#    'vida',
#    'comunit',
#    'ria',
#    'e',
#    'de',
#    'cidadania'],
#   ['As',
#    '<kw>palavras</kw>',
#    's',
#    'o',
#    'do',
#    'primeiro',
#    'ministro',
#    'Ant',
#    'nio',
#    'Guterres',
#    'que',
#    'falava',
#    'durante',
#    'a',
#    'abertura',
#    'do',
#    'Congresso',
#    'Nacional',
#    'dos',
#    'Volunt',
#    'rios',
#    'ocasi',
#    'o',
#    'em',
#    'que',
#    'lan',
#    'ou',
#    'um',
#    'apelo',
#    'presen',
#    'a',
#    'de',
#    'mais',
#    'volunt',
#    'rios',
#    '<kw>portugueses</kw>',
#    'nos',
#    'cen',
#    'rios',
#    'internacionais'],
#   ['Soprar',
#    'no',
#    'bal',
#    'o',
#    'para',
#    'saber',
#    'limites',
#    'Preven',
#    'o',
#    'lan',
#    'a',
#    'desafio',
#    'juventude',
#    'para',
#    'que',
#    'n',
#    'o',
#    'receie',
#    'descobrir',
#    'os',
#    'efeitos',
#    'da',
#    'alcoolemia',
#    'CARLOS',
#    'GOMES',
#    'Est',
#    'a',
#    'ser',
#    'poss',
#    'vel',
#    'soprar',
#    'o',
#    'bal',
#    'o',
#    's',
#    'para',
#    'fazer',
#    'o',
#    'teste',
#    'do',
#    'lcool',
#    'e',
#    'conhecer',
#    'os',
#    'limites',
#    'no',
#    'tocante',
#    'ingest',
#    'o',
#    'de',
#    'bebidas',
#    'alco',
#    'licas'],
#   ['<d>2013</d>', 'aconteceu', 'em', 'Coimbra', 'e', '<kw>lisboa</kw>'],
#   ['Na',
#    'pr',
#    'xima',
#    '<d>2013</d>',
#    'ser',
#    'em',
#    'Faro',
#    'Porto',
#    'e',
#    'Matosinhos'],
#   ['Dentro', 'de', '<d>P15D</d>', 'tocar', 'a', 'vez', 'a', 'Braga'],
#   ['Sida',
#    'matou',
#    '20',
#    'milh',
#    'es',
#    'em',
#    'duas',
#    'd',
#    'cadas',
#    'O',
#    'primeiro',
#    'ministro',
#    'portugu',
#    's',
#    'Ant',
#    'nio',
#    'Guterres',
#    'defendeu',
#    '<d>2013</d>',
#    'que',
#    'a',
#    'luta',
#    'contra',
#    'o',
#    'flagelo',
#    'da',
#    'sida',
#    'exigir',
#    'de',
#    'todos',
#    'os',
#    '<kw>portugueses</kw>',
#    'uma',
#    'maior',
#    'cultura',
#    'de',
#    'solidariedade',
#    'e',
#    'uma',
#    'atitude',
#    'cada',
#    'vez',
#    'mais',
#    'determinada',
#    'e',
#    'empenhada'],
#   ['A',
#    'posi',
#    'o',
#    'do',
#    'chefe',
#    'do',
#    'Governo',
#    'consta',
#    'de',
#    'um',
#    'depoimento',
#    'feito',
#    'para',
#    'a',
#    'Comiss',
#    'o',
#    'Nacional',
#    'de',
#    'Luta',
#    'contra',
#    'a',
#    'Sida',
#    'entidade',
#    'que',
#    'ele',
#    'elogia',
#    'pelo',
#    'trabalho',
#    'de',
#    'dedica',
#    'o',
#    'e',
#    'de',
#    'destacado',
#    'sentido',
#    'humanista'],
#   ['Reuni',
#    'es',
#    'e',
#    'desfiles',
#    'de',
#    'todos',
#    'os',
#    'g',
#    'neros',
#    'e',
#    'mensagens',
#    'dos',
#    'dirigentes',
#    'do',
#    'Mundo',
#    'inteiro',
#    'assinalaram',
#    '<d>2013</d>',
#    'o',
#    '14',
#    'Dia',
#    'Mundial',
#    'da',
#    'Sida',
#    'a',
#    'epidemia',
#    'mais',
#    'mort',
#    'fera',
#    'da',
#    'humanidade',
#    'que',
#    'j',
#    'matou',
#    '20',
#    'milh',
#    'es',
#    'de',
#    'pessoas',
#    'em',
#    '<d>P20Y</d>'],
#   ['<d>P1D</d>',
#    'que',
#    'foi',
#    'aproveitado',
#    'pelo',
#    'ministro',
#    'da',
#    'Sa',
#    'de',
#    'italiano',
#    'Girolamo',
#    'Sirchia',
#    'para',
#    'anunciar',
#    'em',
#    'Mil',
#    'o',
#    'que',
#    'a',
#    'It',
#    'lia',
#    'experimentar',
#    'brevemente',
#    'no',
#    'homem',
#    'um',
#    'prot',
#    'tipo',
#    'de',
#    'vacina',
#    'contra',
#    'a',
#    'sida'],
#   ['Chefes',
#    'da',
#    'PSP',
#    'reclamam',
#    'justi',
#    'a',
#    'CARLOS',
#    'GOMES',
#    'Mais',
#    'de',
#    'uma',
#    'centena',
#    'de',
#    'chefes',
#    'de',
#    'pol',
#    'cia',
#    'que',
#    'antes',
#    'do',
#    'novo',
#    'Estatuto',
#    'do',
#    'Pessoal',
#    'da',
#    'PSP',
#    'tinham',
#    'feito',
#    'o',
#    'curso',
#    'de',
#    'promo',
#    'o',
#    'a',
#    'subchefe',
#    'ajudante',
#    'reuniram',
#    'se',
#    '<d>2013</d>',
#    'num',
#    'restaurante',
#    'no',
#    'Entroncamento',
#    'para',
#    'manifestarem',
#    'insatisfa',
#    'o',
#    'relativamente',
#    's',
#    'injusti',
#    'as',
#    'de',
#    'que',
#    'se',
#    'acham',
#    'v',
#    'timas',
#    'resultantes',
#    'da',
#    'reestrutura',
#    'o',
#    'de',
#    'carreiras'],
#   ['Ingest',
#    'o',
#    'de',
#    'lcool',
#    'e',
#    'comportamento',
#    'A',
#    'ingest',
#    'o',
#    'de',
#    'lcool',
#    'tem',
#    'tr',
#    's',
#    'tipos',
#    'de',
#    'efeitos',
#    'sobre',
#    'os',
#    'automobilistas',
#    'no',
#    'comportamento',
#    'na',
#    'percep',
#    'o',
#    'e',
#    'na',
#    'motricidade'],
#   ['Segundo',
#    'estudos',
#    'do',
#    'Centro',
#    'Regional',
#    'de',
#    'Alcoologia',
#    'do',
#    'Porto',
#    'os',
#    'condutores',
#    'alcoolizados',
#    'sofrem',
#    'da',
#    'euforia',
#    'da',
#    'velocidade',
#    'e',
#    'da',
#    'ultrapassagem',
#    'e',
#    'valorizam',
#    'excessivamente',
#    'a',
#    'm',
#    'quina',
#    'e',
#    'as',
#    'capacidades',
#    'do',
#    'condutor'],
#   ['Gravidez',
#    'juvenil',
#    'atinge',
#    '1',
#    '25',
#    'milh',
#    'es',
#    'S',
#    '750',
#    'mil',
#    'adolescentes',
#    'dos',
#    'pa',
#    'ses',
#    'ricos',
#    'ver',
#    'o',
#    'nascer',
#    'as',
#    'crian',
#    'as',
#    'dentro',
#    'de',
#    '<d>P1Y</d>',
#    'Mais',
#    'de',
#    'um',
#    'milh',
#    'o',
#    'de',
#    'adolescentes',
#    'nos',
#    'considerados',
#    'pa',
#    'ses',
#    'ricos',
#    'engravidar',
#    'o',
#    'no',
#    'decurso',
#    'dos',
#    'pr',
#    'ximos',
#    '<d>P1Y</d>'],
#   ['No',
#    'entanto',
#    'somente',
#    '750',
#    '000',
#    'ir',
#    'o',
#    'at',
#    'ao',
#    'final',
#    'da',
#    'gravidez'],
#   ['Detido',
#    'suspeito',
#    'de',
#    'ter',
#    'matado',
#    '49',
#    'pessoas',
#    'Um',
#    'homem',
#    'que',
#    'pode',
#    'estar',
#    'ligado',
#    'ao',
#    'assass',
#    'nio',
#    'de',
#    '49',
#    'mulheres',
#    'na',
#    'sua',
#    'maioria',
#    'crian',
#    'as',
#    'e',
#    'prostitutas',
#    'foi',
#    'detido',
#    'no',
#    '<kw>estado</kw>',
#    'de',
#    'Washington'],
#   ['Os',
#    'crimes',
#    'ter',
#    'o',
#    'sido',
#    'cometidos',
#    'entre',
#    '<d>1982</d>',
#    'e',
#    '<d>1984</d>'],
#   ['Dave',
#    'Richert',
#    '<kw>presidente</kw>',
#    'do',
#    'condado',
#    'de',
#    'King',
#    'informou',
#    'que',
#    'Gary',
#    'Ridgeway',
#    'foiacusado',
#    'gra',
#    'as',
#    'aos',
#    'testes',
#    'de',
#    'ADN',
#    'de',
#    'pelo',
#    'menos',
#    'quatro',
#    'desses',
#    'assass',
#    'nios'],
#   ['Espanh',
#    'is',
#    'contra',
#    'reforma',
#    'do',
#    'ensino',
#    'MIGUEL',
#    'GARCIA',
#    'SANCHO',
#    'CORRESPONDENTE',
#    'EM',
#    'MADRID',
#    'Centenas',
#    'de',
#    'milhares',
#    'de',
#    'estudantes',
#    'e',
#    'professores',
#    'espanh',
#    'is',
#    'dezenas',
#    'de',
#    'milhares',
#    'segundo',
#    'as',
#    'autoridades',
#    'manifestaram',
#    'se',
#    '<d>2013</d>',
#    'em',
#    'Madrid',
#    'para',
#    'pedirem',
#    'a',
#    'retirada',
#    'da',
#    'Lei',
#    'Org',
#    'nica',
#    'de',
#    'Universidades',
#    'que',
#    'o',
#    'Governo',
#    'visa',
#    'aprovar',
#    'antes',
#    'de',
#    'fim',
#    'de',
#    'ano'],
#   ['Faltas',
#    's',
#    'rias',
#    'no',
#    'naufr',
#    'gio',
#    'do',
#    'Koursk',
#    'O',
#    '<kw>presidente</kw>',
#    'Vladimir',
#    'Putin',
#    'demitiu',
#    'das',
#    'suas',
#    'fun',
#    'es',
#    'o',
#    'comandante',
#    'da',
#    'frota',
#    'russa',
#    'do',
#    'Norte',
#    'e',
#    'um',
#    'grupo',
#    'de',
#    'almirantes',
#    'por',
#    'faltas',
#    's',
#    'rias'],
#   ['Uma',
#    'decis',
#    'o',
#    'decorrente',
#    'da',
#    'cada',
#    'vez',
#    'mais',
#    'prov',
#    'vel',
#    'hip',
#    'tese',
#    'que',
#    'imputa',
#    'a',
#    'responsabilidade',
#    'do',
#    'naufr',
#    'gio',
#    'do',
#    'submarino',
#    'Koursk',
#    'a',
#    '12',
#    'de',
#    '<d>2013</d>',
#    'do',
#    'ano',
#    'passado',
#    'aos',
#    'pr',
#    'prios',
#    'militares'],
#   ['inqu',
#    'rito',
#    'Receia',
#    'abrir',
#    'correspond',
#    'ncia',
#    'por',
#    'causa',
#    'do',
#    'Anthrax'],
#   ['Sim',
#    'N',
#    'o',
#    'outros',
#    'inqu',
#    'ritos',
#    'futebol',
#    'biografias',
#    'televis',
#    'o',
#    'c',
#    'mbios',
#    'tempo',
#    'cinemas',
#    'cyber',
#    'utilidades',
#    'turismo',
#    'c',
#    'dentro',
#    'lazer',
#    'estat',
#    'sticas',
#    'Copyright',
#    '<d>2001</d>',
#    'Empresa',
#    'do',
#    'Jornal',
#    'de',
#    'Not',
#    'cias',
#    'S',
#    'A',
#    'Todos',
#    'os',
#    'direitos',
#    'reservados',
#    'Fale',
#    'connosco',
#    'Ficha',
#    't',
#    'cnica']]}

# %% [markdown]
# ### Optional Parameters

# %% [markdown]
# Apart from the *score_type* (ByCorpus, ByDoc and ByDocSentence) there are also parameters regarding the *temporal_tagger* and *time_matters*.

# %% [markdown]
# #### Temporal Tagger

# %% [markdown]
# While 'py_heideltime' is the default temporal tagger, a 'rule_based' approach can be used instead. In the following, we assume the default parameters of the rule-based approach, that is: date_granularity is "full" (highest possible granularity detected will be retrieved), begin_date is 0 and end_date is 2100 which means that all the dates within this range will be retrieved. Instead, we can specify a more fine-grained granularity, such as `year` and a `begin` and `end date` which would result in the following code: `results = Time_Matters_SingleDoc(text, temporal_tagger=['rule_based', 'year', 2000, 2011])`. However, in the following code, we resort to the default parameter values of the rule-based approach.

# %%
results = Time_Matters_MultipleDocs(ListOfTexts, temporal_tagger=['rule_based'])

# %%
Score = results[0]
Score
# Out:
# {'2003': [0.879, {0: ['2003', '2003']}],
#  '1980': [0.752, {1: ['1980']}],
#  '2000': [0.598, {1: ['2000'], 2: ['2000']}],
#  '2001': [0.388, {3: ['2001', '2001', '2001']}],
#  '1984': [0.388, {3: ['1984']}],
#  '1983': [0.362, {2: ['1983']}],
#  '1982': [0.341, {2: ['1982'], 3: ['1982']}]}

# %% [markdown]
# If you are only interested in accessing the keys and the scores run the following code:

# %%
for TempExpr in Score:
    print(f'{TempExpr}; {Score[TempExpr][0]}')
# Out:
# 2003; 0.879
# 1980; 0.752
# 2000; 0.598
# 2001; 0.388
# 1984; 0.388
# 1983; 0.362
# 1982; 0.341

# %% [markdown]
# In addition, a few other parameters (already experienced before) are available to `py_heideltime`, namely:

# %% [markdown]
# - `language`: <b>English</b> - default; <b>Portuguese</b>; <b>Spanish</b>; <b>Germany</b>; <b>Dutch</b>; <b>Italian</b>; and <b>French</b>. To know how to configure py_heideltime for other languages please refer to this [link](https://github.com/JMendes1995/py_heideltime);
# - `date granularity`: <b>"full"</b>  - default (Highest possible granularity detected will be retrieved); <b>"year"</b> (YYYY will be retrieved); <b>"month"</b> (YYYY-MM will be retrieved); <b>"day"</b> (YYYY-MM-DD will be retrieved). Note that this parameter can also be used with the rule_based model.
# - `document type` <b>"news"</b>  - default (news-style documents); <b>"narrative"</b> (narrative-style documents (e.g., Wikipedia articles)); <b>"colloquial"</b> (English colloquial (e.g., Tweets and SMS)); <b>"scientific"</b> (scientific articles (e.g., clinical trails))
# - `document creation time`: in the format <b>YYYY-MM-DD</b>

# %% [markdown]
# #### Time Matters

# %% [markdown]
# - **n-gram**: maximum number of terms a keyword might have. Default value is *1* (but any value > 0 is considered. For instance n = 1 means that single tokens such as "keyword" can be considered; instead n = 2 means that "keyword" but also "keyword extractor" can be considered). More about this [here](https://github.com/LIAAD/Time-Matters#Text-Representation) and [here](https://github.com/LIAAD/Time-Matters#Relevant-Keywords).
# - **num_of_keywords**: number of YAKE! keywords to extract from the text. Default value is *10* (but any value > 0 is considered) meaning that the system will extract 10 relevant keywords from the text. More about this [here](https://github.com/LIAAD/Time-Matters#Text-Representation) and [here](https://github.com/LIAAD/Time-Matters#Relevant-Keywords).
# - **n_contextual_window**: defines the n-contextual window distance. Default value is "*full_document*" when the score type is ByCorpus, or "*full_sentence*" (but a n-window where n > 0 can be considered as alternative) when the score type is ByDoc or ByDocSentence. More about this [here](https://github.com/LIAAD/Time-Matters#Computing-Dice).
# - **N**: size of the context vector for X and Y at InfoSimba. Default value is '10' (but any value > 0 is considered). You can also define 'max' meaning that the context vector should have the maximum number of n-terms co-occurring with X (likewise with Y). This option however will require a huge amount of time (depending on the PC) to execute. More about this [here](https://github.com/LIAAD/Time-Matters#Context-Vectors).
# - **TH**: minimum threshold value from which terms are eligible to the context vector X and Y at InfoSimba. Default value is *0.05* (but any value > 0 is considered) meaning that any terms co-occuring between them with a DICE similarity value > 0.05 are eligible for the n-size vector. More about this [here](https://github.com/LIAAD/Time-Matters#Context-Vectors).

# %% [markdown]
# The following code assumes a score-type of `ByCorpus`, the default parameters of the `temporal_tagger` (such as `py_heideltime`) and specifies the five parameters (also the default ones) for time_matters.

# %%
results = Time_Matters_MultipleDocs(ListOfTexts, time_matters=[1, 10, 'full_document', 10, 0.05])

# %% [markdown]
# More interistingly is that if we consider a different n-gram for the keywords. In the following we consider n = 3.

# %%
results = Time_Matters_MultipleDocs(ListOfTexts, time_matters=[3, 10, 'full_document', 10, 0.05])

# %% [markdown]
# Note (before executing the following code) that in this case, we didn't define the granularity to year, thus we will get a huge number of temporal expressions.

# %%
Score = results[0]
Score
# Out:
# {'1980': [0.833, {1: ['1980', '1980']}],
#  '2000': [0.737, {1: ['2000'], 2: ['2000']}],
#  '1983': [0.493, {2: ['1983']}],
#  '2001': [0.295, {3: ['2001', '2001', '2001']}],
#  '1984': [0.295, {3: ['1984']}],
#  '1982': [0.271, {2: ['1982'], 3: ['1982']}],
#  '2003': [0, {0: ['2003', '2003']}]}

# %%
RelevantKWs = results[2]
RelevantKWs
# Out:
# {0: {'pdf newsletters pesquisa': 6.836857324908459e-05,
#   'folhas fugas especial': 0.0001093383060284537,
#   'cidades passatempo dvd': 0.00012057072841327025},
#  1: {'assad faleceu deixando': 0.002620666570346457,
#   'assad': 0.033360231533556,
#   'ocidente tenham igualmente': 0.03647292789540577,
#   'hafez al-assad constitui': 0.045413374137790126,
#   'presidente': 0.046624774095056734,
#   'faleceu': 0.04778999543952961},
#  2: {'soldados israelitas': 0.018783156805608537,
#   'xiita hezbollah': 0.02931449754207163,
#   'hezbollah': 0.03999682971023942,
#   'editorial': 0.05595436807043946,
#   'marchar': 0.05595436807043946,
#   'forte sentimento anti-israelita': 0.06601676111655719,
#   'radical xiita': 0.06841022580060806},
#  3: {'semana portugal doce': 0.003130120008158237,
#   'semanais iniciativas classificados': 0.004228975603677745,
#   'domingos de andrade': 0.008986523368789278,
#   'leitor dossiers': 0.009737623843023801}}

# %%
TextNormalized = results[3]
TextNormalized
# Out:
# {0: 'PUBLICO.PT S�bado, 22 de Mar�o de <d>2003</d> 18:56 p�blico PDF alertas pesquisas Newsletters edi��o impressa �ltima hora dossiers guia do lazer cinecartaz tvzine ABCed�rio DVD s�rie Y mil folhas 2 emprego tempo LOGIN Nome de utilizador Palavra-chave REGISTO EDI��O IMPRESSA Sec��es: 1� P�gina Destaque Nacional Mundo Espa�o P�blico Sociedade Educa��o Ci�ncias Cultura Desporto Economia Media Local Porto �ltima P�gina ------------- Suplementos: Computadores Economia Y Mil <kw>folhas fugas especial</kw> IRAQUE ------------- �ltimos 7 dias: S�bado Sexta Quinta Quarta Ter�a Segunda Domingo ------------- P�BLICO em HTML e PDF CANAIS Edi��o Impressa �ltima Hora �ltima Hora UL Mil Folhas 2 Desporto DVD S�rie Y ABCed�rio Guia do Lazer Cinecartaz TVzine R�dio Emprego Imobili�rio Dossiers Ecosfera Banda Desenhada Calvin Bartoon P�BLICO PLUS Registo P�blico em <kw>pdf newsletters pesquisa</kw> CANAIS INTERACTIVOS Inqu�ritos Tr�nsito Ebook Hor�scopos F�runs SERVI�OS Meteorologia Lotarias Di�rio da Rep�blica Motores de Pesquisa PROJECTOS P�BLICO Simweb Painel P�blico/IDC Trof�u P�blico P�blico na Escola P�blico/Gradiva 3� Edi��o Fuga de Inverno Guias de <kw>cidades passatempo dvd</kw> Serie Y N�s Ficha T�cnica Mapa do Site Livro de Estilo Provedor do Leitor Assinaturas Publicidade GALERIA Arte Viagens Leil�es NOT�CIAS Pol�cia avan�a 35 mil, organiza��o fala em 90 mil Manifesta��o em Lisboa re�ne dezenas de milhares de pessoas A manifesta��o em Lisboa contra a guerra no Iraque, que se iniciou �s 15h45 no Marqu�s de Pombal, levou entre 35 e
edade na actividade profissional", mas tamb�m por "ades�o � filosofia inerente � media��o de conflitos". Sabe que o esperam, porventura, casos dif�ceis, envolvendo gente mais quezilenta ou at� violenta, mas isso n�o o preocupa minimamente: "Gosto do contacto com as pessoas e de ver, atr�s dessa exalta��o, a sua gra�a". Falta de tempo leva ao abandono O estudo efectuado por M�rio Laje sustenta que a maioria dos volunt�rios s�o do sexo masculino, com idades compreendidas entre os 35 e os 44 anos. Este grupo � constitu�do predominantemente por homens de forma��o acad�mica, seguidores sobretudo de uma religi�o n�o crist�. Sampaio pede a portugueses para serem mais volunt�rios Apenas 12,7% j� estiveram envolvidos em  ...

# %% [markdown]
# ### Debug

# %% [markdown]
# We also offer the user a debug mode where users can access a more detailed version of the results. Thus in addition to the fields already explained before we also make available the InvertedIndex, the DiceMatrix and the ExecutionTime.

# %% [markdown]
# To this regard, we consider the following code with `debug_mode=True`, thus assuming the score_type `ByCorpus`, and the default parameters of `temporal_tagger` (thus with heideltime) and of `time_matters`.

# %%
results = Time_Matters_MultipleDocs(ListOfTexts, debug_mode=True)

#likewise:
#results = Time_Matters_MultipleDocs(ListOfTexts, score_type='ByCorpus', temporal_tagger=['py_heideltime', 'English', 'year', 'news', '2013-04-15'], time_matters=[1, 10, 'full_document', 10, 0.05], debug_mode=True)

# %%
Score = results[0]
Score
# Out:
# {'2003': [0.93, {0: ['2003', '2003']}],
#  '1980': [0.834, {1: ['1980', '1980']}],
#  '1983': [0.507, {2: ['1983']}],
#  '2000': [0.506, {1: ['2000'], 2: ['2000']}],
#  '2001': [0.378, {3: ['2001', '2001', '2001']}],
#  '1984': [0.378, {3: ['1984']}],
#  '1982': [0.304, {2: ['1982'], 3: ['1982']}]}

# %% [markdown]
# #### Inverted Index

# %% [markdown]
# - <b>InvertedIndex</b>: An inverted index of the entire set of documents, most notably of its relevant keywords and temporal expressions. It follows the following dictionary structure: `{'term' : [DF, TotFreq, {DocID : [FreqInDoc, [OffsetsDoc], {SentenceID :  [FreqInSentence, [OffsetsSentence]]}]}]`, where `DF` is the `Document Frequency`, `TotFreq` is the `total frequency` of the term within the entire corpus of documents, `DocID` is the `ID of the document` (knowing that IDs start on 0), `FreqInDoc` is the frequency of the term in the document,  `[OffsetsDoc]` is a list of the document offsets, that is, a list of the position(s) where the term appears in the document, `SentenceID` is the `ID of the sentence`, `FreqInSentence` is the frequency of the term in the sentence, `OffsetsSentence` is a list of the sentence offsets, that is, a list of the position(s) where the term appears in the sentence. For instance, a term with the following structure `'2010': [1, 4, {1 : [4, [6, 13, 20, 27], {0 :  [2, [6, 13]], 1: [2, [20, 27]] }]}]` means that it has 4 occurrences in 1 document, in particular in the document with ID 1, namely in position 6, 13, 20, and 27, the first two occur in sentence ID 0, and the latter in sentence ID 1.

# %%
InvertedIndex = results[7]
InvertedIndex
# Out:
# {'2003': [1, 2, {0: [2, [9, 455], {0: [1, [9]], 3: [1, [455]]}]}],
#  'pdf': [1, 3, {0: [3, [14, 102, 145], {0: [3, [14, 102, 145]]}]}],
#  'newsletters': [1, 2, {0: [2, [17, 146], {0: [2, [17, 146]]}]}],
#  'impressa': [1, 3, {0: [3, [20, 49, 106], {0: [3, [20, 49, 106]]}]}],
#  'dvd': [1, 3, {0: [3, [31, 116, 200], {0: [3, [31, 116, 200]]}]}],
#  'folhas': [1, 3, {0: [3, [36, 81, 113], {0: [3, [36, 81, 113]]}]}],
#  'iraque': [2,
#   9,
#   {0: [8,
#     [84, 258, 341, 349, 350, 360, 385, 450],
#     {0: [2, [84, 258]], 3: [6, [341, 349, 350, 360, 385, 450]]}],
#    1: [1, [392], {14: [1, [392]]}]}],
#  'pesquisa': [1, 2, {0: [2, [147, 170], {0: [2, [147, 170]]}]}],
#  'lisboa': [2,
#   8,
#   {0: [5,
#     [241, 253, 325, 599, 616],
#     {0: [2, [241, 253]], 2: [1, [325]], 3: [2, [599, 616]]}],
#    3: [3, [49, 730, 908], {0: [1, [49]], 22: [1, [730]], 28: [1, [908]]}]}],
#  'portugal': [2,
#   8,
#   {0: [3, [471, 514, 553], {3: [3, [471, 514, 553]]}],
#    3: [5,
#     [16, 44, 85, 166, 421],
#     {0: [3, [16, 44, 85]], 2: [1, [166]], 12: [1, [421]]}]}],
#  'editorial': [2, 2, {1: [1, [1], {0: [1, [1]]}], 2: [1, [1], {0: [1, [1]]}]}],
#  'assad': [1,
#   5,
#   {1: [5,
#     [3, 92, 130, 171, 386],
#     {0: [1, [3]],
#      3: [1, [92]],
#      4: [1, [130]],
#      6: [1, [171]],
#      13: [1, [386]]}]}],
#  'faleceu': [1, 2, {1: [2, [4, 19], {0: [2, [4, 19]]}]}],
#  'presidente': [2,
#   7,
#   {1: [5,
#     [13, 63, 118, 311, 338],
#     {0: [1, [13]],
#      1: [1, [63]],
#      4: [1, [118]],
#      11: [1, [311]],
#      12: [1, [338]]}],
#    3: [2, [1311, 1395], {42: [1, [1311]], 44: [1, [1395]]}]}],
#  'al-assad': [1,
#   3,
#   {1: [3, [18, 176, 271], {0: [1, [18]], 6: [1, [176]], 9: [1, [271]]}]}],
#  'palavras': [2,
#   4,
#   {1: [3, [55, 138, 287], {1: [1, [55]], 5: [1, [138]], 10: [1, [287]]}],
#    3: [1, [811], {26: [1, [811]]}]}],
#  'morte': [1,
#   4,
#   {1: [4,
#     [60, 110, 268, 384],
#     {1: [1, [60]], 4: [1, [110]], 9: [1, [268]], 13: [1, [384]]}]}],
#  'estado': [3,
#   4,
#   {1: [2, [85, 230], {2: [1, [85]], 7: [1, [230]]}],
#    2: [1, [248], {7: [1, [248]]}],
#    3: [1, [1296], {40: [1, [1296]]}]}],
#  '1980': [1, 2, {1: [2, [409, 420], {14: [2, [409, 420]]}]}],
#  '2000': [2,
#   2,
#   {1: [1, [423], {14: [1, [423]]}], 2: [1, [266], {9: [1, [266]]}]}],
#  'marchar': [1, 1, {2: [1, [3], {0: [1, [3]]}]}],
#  'xiita': [1, 2, {2: [2, [26, 54], {0: [1, [26]], 1: [1, [54]]}]}],
#  'hezbollah': [1,
#   4,
#   {2: [4,
#     [27, 109, 199, 236],
#     {0: [1, [27]], 2: [1, [109]], 5: [1, [199]], 7: [1, [236]]}]}],
#  '1982': [2,
#   2,
#   {2: [1, [61], {1: [1, [61]]}], 3: [1, [1306], {41: [1, [1306]]}]}],
#  '1983': [1, 1, {2: [1, [191], {4: [1, [191]]}]}],
#  'movimento': [1,
#   3,
#   {2: [3, [210, 223, 241], {5: [1, [210]], 6: [1, [223]], 7: [1, [241]]}]}],
#  'dezembro': [1, 2, {3: [2, [8, 72], {0: [2, [8, 72]]}]}],
#  '2001': [1, 3, {3: [3, [10, 74, 1485], {0: [2, [10, 74]], 47: [1, [1485]]}]}],
#  'portugueses': [1,
#   7,
#   {3: [7,
#     [80, 110, 137, 679, 702, 845, 960],
#     {0: [2, [80, 110]],
#      2: [1, [137]],
#      22: [2, [679, 702]],
#      26: [1, [845]],
#      31: [1, [960]]}]}],
#  '1984': [1, 1, {3: [1, [1308], {41: [1, [1308]]}]}]}

# %% [markdown]
# #### Dice Matrix

# %% [markdown]
# - <b>DicMatrix</b>: It retrieves (in pandas format) the DICE matrix between each term according to the n-contextual window distance defined. For instance, a DICE similarity of 1 between `prime` and `minister` means that, whenever each of these terms occur, they always occur together. If you want to know more about the role of DICE in our algorithm please refer to this [link](https://github.com/LIAAD/Time-Matters#Computing-Dice).

# %%
DiceMatrix = results[8]
DiceMatrix
# Out:
#                   dvd       pdf    folhas    iraque  impressa    lisboa  \
# dvd                 1         1         1  0.666667         1  0.666667
# pdf                 1         1         1  0.666667         1  0.666667
# folhas              1         1         1  0.666667         1  0.666667
# iraque       0.666667  0.666667  0.666667         1  0.666667       0.5
# impressa            1         1         1  0.666667         1  0.666667
# lisboa       0.666667  0.666667  0.666667       0.5  0.666667         1
# pesquisa            1         1         1  0.666667         1  0.666667
# newsletters         1         1         1  0.666667         1  0.666667
# assad               0         0         0  0.666667         0         0
# presidente          0         0         0       0.5         0       0.5
# faleceu             0         0         0  0.666667         0         0
# editorial           0         0         0       0.5         0         0
# morte               0         0         0  0.666667         0         0
# estado              0         0         0       0.4         0       0.4
# palavras            0         0         0       0.5         0       0.5
# al-assad            0         0         0  0.666667         0         0
# hezbollah           0         0         0         0         0         0
# marchar             0         0         0         0         0         0
# xiita               0         0         0         0         0         0
# movimento           0         0         0         0         0         0
# portugal     0.666667  0.666667  0.666667       0.5  0.666667         1
# dezembro            0         0         0         0         0  0.666667
# portugueses         0         0         0         0         0  0.666667
# 2003                1         1         1  0.666667         1  0.666667
# 1980                0         0         0  0.666667         0         0
# 2000                0         0         0       0.5         0         0
# 1982                0         0         0         0         0       0.5
# 1983                0         0         0         0         0         0
# 2001                0         0         0         0         0  0.666667
# 1984                0         0         0         0         0  0.666667
#
#              pesquisa newsletters     assad presidente    ...     portugal  \
# dvd                 1           1         0          0    ...     0.666667
# pdf                 1           1         0          0    ...     0.666667
# folhas              1           1         0          0    ...     0.666667
# iraque       0.666667    0.666667  0.666667        0.5    ...          0.5
# impressa            1           1         0          0    ...     0.666667
# 2003                0         0         0
# 1980                0         0         0
# 2000         0.666667         0         0
# 1982         0.666667  0.666667  0.666667
# 1983                1         0         0
# 2001                0         1         1
# 1984                0         1         1
#
# [30 rows x 30 columns]

# %% [markdown]
# #### Execution Time

# %% [markdown]
# - <b>ExecutionTime</b>: It retrieves information about the processing times of our algorithm, in particular, of the `TotalTime` required to execute the algorithm, but also of each of its most important components, namely: `heideltime_processing`, `text_normalization`, `YAKE`, `InvertedIndex`, `DICEMatrix` and `GTE`. As it can be observed from the example, most of the time is consumed by the `py_heideltime` component (which entails the heideltime_processing and the text_normalization process, that is, the tagging of the text with the <d> tag).

# %%
ExecutionTime = results[9]
ExecutionTime
# Out:
# {'TotalTime': 21.42533254623413,
#  'heideltime_processing': 20.64427614212036,
#  'py_heideltime_text_normalization': 0.0,
#  'keyword_text_normalization': 0,
#  'YAKE': 0.4374232292175293,
#  'InvertedIndex': 0.015623092651367188,
#  'DICE_Matrix': 0.015619754791259766,
#  'GTE': 0.01562356948852539}

# %% [markdown]
# ## Related Projects

# %% [markdown]
# Please check [py_rule_based](https://github.com/JMendes1995/py_rule_based) if you are interested in extracting dates by means of a rule-based model solution.

# %% [markdown]
# Please check py_heideltime [github package](https://github.com/JMendes1995/py_heideltime) or [docker image](https://hub.docker.com/r/liaad/py_heideltime) if you are interested in extracting temporal expressions using Heideltime Temporal Tagger.

# %% [markdown]
# ## References

# %% [markdown]
# If you use Time-Matters please cite the appropriate paper. In general, this will be:
#
# - Campos, R., Dias, G., Jorge, A. and Nunes, C. (2017). Identifying Top Relevant Dates for Implicit Time Sensitive Queries. In Information Retrieval Journal. Springer, Vol 20(4), pp 363-398 [[pdf]](https://link.springer.com/article/10.1007/s10791-017-9302-1)
#
# Other Time-Matters related papers may be found here:
#
# - Campos, R., Dias, G., Jorge, A. and Nunes, C. (2016). GTE-Rank: a Time-Aware Search Engine to Answer Time-Sensitive Queries. In Information Processing & Management an International Journal. Elsevier, Vol 52(2), pp. 273-298 [[pdf]](https://www.sciencedirect.com/science/article/abs/pii/S0306457315001016)
#
# - Campos, R., Dias, G., Jorge, A., and Nunes, C. (2014). GTE-Cluster: A Temporal Search Interface for Implicit Temporal Queries. In M. de Rijke et al. (Eds.), Lecture Notes in Computer Science - Advances in Information Retrieval - 36th European Conference on Information Retrieval (ECIR2014). Amesterdam, Netherlands, 13 - 16 April. (Vol. 8416-2014, pp. 775 - 779) [[pdf]](https://link.springer.com/chapter/10.1007/978-3-319-06028-6_94#page-1)
#
# - Campos, R., Jorge, A., Dias, G. and Nunes, C. (2012). Disambiguating Implicit Temporal Queries by Clustering Top Relevant Dates in Web Snippets. In Proceedings of The 2012 IEEE/WIC/ACM International Joint Conferences on Web Intelligence and Intelligent Agent Technologies Macau, China, 04 - 07 December, Vol. 1, pp 1 - 8. IEEE Computer Society Press. [[pdf]](https://ieeexplore.ieee.org/document/6511858?tp=&arnumber=6511858&url=http:%2F%2Fieeexplore.ieee.org%2Fxpls%2Fabs_all.jsp%3Farnumber%3D6511858)
